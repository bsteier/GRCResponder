# %%
from pathlib import Path
from chromadb.utils.embedding_functions import SentenceTransformerEmbeddingFunction
from langgraph.graph import MessagesState, StateGraph
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage
from langgraph.prebuilt import ToolNode
from langgraph.graph import END
from langchain_core.documents import Document
import time
import io
from contextlib import redirect_stdout
from datetime import datetime
from pathlib import Path
import json
from typing import List, Dict, Any
import uuid
from qdrant_client import QdrantClient, models
import os
from dotenv import load_dotenv
from retrieval import retrieve, set_collection
from langchain_google_genai import ChatGoogleGenerativeAI
from qdrant_client.http.models import Filter, FieldCondition, MatchAny
import re

# load in environment variables
env_path = "../../.env"
load_dotenv(dotenv_path=env_path)
QDRANT_CONNECT = os.getenv("QDRANT_CONNECT")
COLLECTION_NAME = os.getenv("DOCUMENT_COLLECTION")
GOOGLE_API = os.getenv("GOOGLE_API_KEY")

try:
    qdrant_client = QdrantClient(url=QDRANT_CONNECT)
except Exception as e:
    print(f"Error connecting to Qdrant: {e}")

set_collection(qdrant_client)

# Provided retrieve tool for querying DB, Search Engine Team will write code replacing
# this to allow for query expansion
def set_api_key(api_key_variable: Path):
    os.environ["GOOGLE_API_KEY"] = api_key_variable

def initialize_llm(gemini_model = 'gemini-2.0-flash'):
    set_api_key(GOOGLE_API)
    llm = ChatGoogleGenerativeAI(model=gemini_model, max_tokens=None)
    return llm

llm = initialize_llm()
combine_llm = initialize_llm()

# %%
schema = {
    "type": "object",
    "properties": {
        "subquery":{
            "type": "string",
            "description": "A specific subquery derived from the user query for efficient document retrieval.",
            "examples": "Describe key aspects of Pacific Gas and Electric's (PG&E) 2023 General Rate Case application."
        },
        "search_strings":{
            "type": "array",
            "items": {
                "type": "string",
                "description": "A search string derived from the subquery that will be used to retrieve relevant documents from the vector database. We include multiple in case the subquery involves multiple aspects or entities.",
            },
            "description": "A list of search strings that will be used to retrieve relevant documents from the vector database.",
            "maxItems": 2,
            "minItems": 1
        },
        "proceeding_id":{
            "type": "array",
            "items":{
                "type": "string",
                "description": "The unique identifier for the proceeding related to the subquery extracted from the subquery if available.",
                "examples": ["A.23-03-005", "A.21-06-021"]
            },
            "description": "List of unique identifiers for the proceeding related to the subquery. This field should only be populated if the id of the proceeding is clearly stated in the original user query.",
        }
    }
}

PROMPT = f"""
You are a tool in a retrieval-augmented generation (RAG) system. Your job is to decompose a complex user query into specific and focused subqueries, each paired with relevant search strings. These subqueries will be used to retrieve relevant documents from a vector database.

Important:

- DO NOT answer the user query.

- You are NOT allowed to summarize, explain, or discuss the topic.

- Only return a list of JSON objects in the schema format below.

- Each subquery must be a JSON object with the following fields:

- Only add to the proceeding_id metadata field if the id of the proceeding is CLEARLY STATED in the original user query.

- If there is potential for multiple proceedings, do not include the proceeding_id field in the JSON object.

Schema:
{schema}

Only return a list of such JSON objects, without any extra commentary, explanation, or markdown formatting.

"""

# %%
from langchain_core.documents import Document
from langchain_core.tools import tool
from qdrant_client import QdrantClient
from sentence_transformers import SentenceTransformer

from advanced_retrieval import query_db, crossEncoderQuery, hydeRetrieval, hydeCrossEncoderRetrieval

import os
from dotenv import load_dotenv

load_dotenv()

K = 8
DOCUMENT_COLLECTION = os.getenv("DOCUMENT_COLLECTION")  # Placeholder for the ChromaDB collection

embedding_model_name = os.getenv("EMBEDDING_MODEL", "all-MiniLM-L6-v2")
embedding_function = SentenceTransformer(embedding_model_name)

# %%
# Multithreading for api calls
import asyncio
import time
from tenacity import AsyncRetrying, stop_after_attempt, RetryError, wait_exponential, retry
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage


def retrieve_context(query: str, k: int = 8, search_filter: Filter = None) -> str:
    """Retrieve information related to a query."""
    # Query qdrant directly
    if not qdrant_client:
        raise ValueError("Qdrant client is not initialized. Please set the QDRANT_CONNECT environment variable.")
    
    results = crossEncoderQuery(
        qdrant_client=qdrant_client,
        query=query,
        collection_name=DOCUMENT_COLLECTION,
        k=k,
        search_filter = search_filter 
    )

    # Format results for LangChain compatibility
    retrieved_docs = []
    for result in results:
        doc_id = result.payload['document_id']
        content = result.payload['text']
        metadata = {k: v for k, v in result.payload.items() if k != 'text'} if result.payload else {}

        doc = Document(page_content=content, metadata=metadata)
        retrieved_docs.append(doc)

    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\n" f"Content: {doc.page_content} Document Link: {doc.metadata.get('source_url', 'N/A')}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs



def getFormattedQuery(subquery: Dict[str, Any]):
    search_strings = subquery.get("search_strings", [])
    proceeding_ids = subquery.get("proceeding_id", None) # list of potential IDs to search through
    subquery_text = subquery.get("subquery", "")

    for i,proceeding in enumerate(proceeding_ids):
        # we need to format it so it can be used in the query, remove everything but the alphanumeric characters
        proceeding_ids[i] = re.sub(r'[^A-Za-z0-9]', '', proceeding)# Remove non-alphanumeric characters
        print(f"Proceeding ID {i}: {proceeding_ids[i]}")
        

    # create filter for proceeding_id if it exists
    query_filter = None
    if proceeding_ids:
        query_filter = Filter(
            must=[
                models.FieldCondition(
                    key="proceeding_id",
                    match=models.MatchAny(any=proceeding_ids)
                )
            ]
        )

    search_result = retrieve_context(
        query=search_strings[0], # use first string for retrieval, will modify later to use all and combine
        k=K,
        search_filter = query_filter
    )

    formatted_query = f"""
    You are "GRC Regulatory Analysis Expert," an AI assistant specialized in California GRC proceedings.
                </SYSTEM>

                <INFORMATION SOURCES>
                Base your responses EXCLUSIVELY on:
                1. Retrieved documents (HIGHEST PRIORITY)
                2. User-provided context in the current session

                The retrieval system has already provided you with the most relevant information.
                Always cite your sources with specific references (e.g., "PG&E 2023 GRC, Exhibit 4, p.15").
                </INFORMATION SOURCES>

                <IDENTITY AND EXPERTISE>
                You are a regulatory specialist focused exclusively on California General Rate Case (GRC) proceedings and related CPUC filings with expertise in:
                - Rate case applications and testimony
                - Revenue requirement analysis
                - Procedural requirements and timelines
                - CPUC decisions and precedents
                </IDENTITY AND EXPERTISE>

                <RESPONSE FORMAT>
                Structure your responses with:
                1. Concise summary of key findings
                2. Detailed analysis with multiple supporting citations
                3. Relevant regulatory background and historical context
                4. Discussion of practical implications
                5. Throughout your response, for example after each bullet point, supply a list of markdown links to the sources you used to generate that part of the response as a comma seperated list.
                

                Use markdown formatting (headers, tables, bullets) to enhance readability.
                </RESPONSE FORMAT>

                <PROFESSIONAL TONE>
                Maintain a voice that is:
                - Authoritative yet accessible
                - Technically precise
                - Thorough and explanatory
                - Objective in regulatory interpretation
                </PROFESSIONAL TONE>

                <ACCURACY REQUIREMENTS>
                - Never invent citations, docket numbers, or proceedings
                - Clearly indicate when information is missing or insufficient
                - Present multiple interpretations when guidance is ambiguous
                - Quote directly from sources for critical regulatory language
                </ACCURACY REQUIREMENTS>

                <SCOPE LIMITATIONS>
                Address only topics related to California GRC proceedings and CPUC regulatory matters.
                For other topics, politely explain they fall outside your expertise.
                </SCOPE LIMITATIONS>

                Always end responses with: "Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?"

                Document Context: {search_result[0]}

                User Query: {subquery_text}
                """

    return formatted_query

async def process_subqueries(original_query:str, subqueries: str):
    """
    Process the subqueries to ensure they are in the correct format.
    """
    # Manually cleaning the response since gemini does not seem to be able to
    cleaned_response = subqueries.strip()
    if cleaned_response.startswith("```json"):
        cleaned_response = cleaned_response.lstrip("```json").strip()
    if cleaned_response.endswith("```"):
        cleaned_response = cleaned_response.rstrip("```").strip()
    print(cleaned_response)
    
    try:
        response_json = json.loads(cleaned_response)
    except json.JSONDecodeError:
        print("Failed to parse response as JSON. Here's the raw content:")
        return None
    
    combined_responses = ''
    queries = []

    for i,item in enumerate(response_json):
        queries.append(
            {
            'query': item['subquery'],
            'index': i,
            'prompt': getFormattedQuery(item)
            }
        )
    
    combined_queries =  await multiThreadedQueries(queries)
    formatted_return = '\n\n'.join(combined_queries)
    answer = await combineSubqueries(original_query, formatted_return)

    return answer

async def combineSubqueries(original_query:str, formatted_answers: str):
    combine_queries_prompt = f"""
    You are an expert in regulatory analysis, tasked with combining multiple subqueries into a single, coherent response.
    
    Please synthesize the responses to all previous subqueries into a comprehensive analysis of the California GRC proceedings, ensuring all relevant details are integrated and presented coherently. Focus on providing a unified understanding of the regulatory landscape and its implications.

    Ensure that the final response is well-structured, and maintains the same level of detail and professionalism as the individual subquery responses. Do your best to keep the responses and thorough as possible, maintaining enough details from each subquery answer.

    To make the response more seamless, act as though this is a single response to the original user query, and not a response to multiple subqueries.

    Maintain formatting such as bullets, headers, and markdown links from the original subqueries. Do not say "The provided documents" in the response, instead refer to context as "availible data".

    ORIGINAL USER QUERY:
    {original_query}
    
    SUBQUERIES AND RESPONSES:
    
    """

    final_prompt = combine_queries_prompt + formatted_answers
    messages = [HumanMessage(content=final_prompt)]
    results = combine_llm.invoke(messages)
    return results.content if isinstance(results, AIMessage) else "Failed to synthesize subqueries."
    


@retry(
    wait=wait_exponential(multiplier=1, min=4, max=10),
    stop=stop_after_attempt(3)
)
async def asyncQueryLLM(query: Dict[str, Any]) -> str:
    prompt = query.get('prompt', "")

    if not prompt:
        raise ValueError("Prompt is empty or not provided in the query dictionary.")

    try:
        messages = [HumanMessage(content=prompt)]
        response = await llm.ainvoke(messages)
        llm_response = response.content if isinstance(response, AIMessage) else "Failed to retrieve response for Subquery\n"
        
        formatted_response = f"""
        Subquery {query['index'] + 1}:\n{query["query"]}\nGenerated Response:\n{llm_response}\n
        """
        return formatted_response

    except Exception as e:
        print(f"Error querying LLM: {e}")
        raise e

async def multiThreadedQueries(queries: List[str]):
    tasks = []
    for query in queries:
        tasks.append(asyncQueryLLM(query))
    
    results = []

    for future in asyncio.as_completed(tasks):
        try:
            result = await future
            results.append(result)
        except RetryError as e:
            print(f"RetryError in async task: {e}")
            results.append("Error processing subquery after retries.")
        except Exception as e:
            print(f"Error in async task: {e}")
            results.append("Error processing subquery.")

    # sort by query index
    results.sort(key=lambda x: int(re.search(r'Subquery (\d+):', x).group(1)) - 1)
    return results

# %%
test_query = "Based on the public record in proceeding A.21-06-021, analyze the differences between PG&E's original undergrounding proposal and what was authorized in Decision 23-11-069. Include: (1) comparison of the miles of undergrounding requested by PG&E versus what was approved by the CPUC and the stated rationale for the reduction in the decision, (2) analysis of the Administrative Law Judge's Proposed Decision versus the Alternate Proposed Decision regarding undergrounding miles and which approach was ultimately adopted, (3) summary of intervenor positions on undergrounding from their filed testimony, including any opposition or alternative proposals, (4) identification of the specific CPUC findings regarding cost-effectiveness of undergrounding versus covered conductor alternatives as stated in the final decision, and (5) explanation of how the decision addresses PG&E's 10,000-mile undergrounding program timeline based on the proceeding record."

combined_prompt = PROMPT + f"\nUSER QUERY:\n{test_query}"

print("Combined Prompt:")
print(combined_prompt)

response = llm.invoke(combined_prompt)

print("Response from LLM:")
print(response.content)
# Out:
# Combined Prompt:
#
# You are a tool in a retrieval-augmented generation (RAG) system. Your job is to decompose a complex user query into specific and focused subqueries, each paired with relevant search strings. These subqueries will be used to retrieve relevant documents from a vector database.
#
# Important:
#
# - DO NOT answer the user query.
#
# - You are NOT allowed to summarize, explain, or discuss the topic.
#
# - Only return a list of JSON objects in the schema format below.
#
# - Each subquery must be a JSON object with the following fields:
#
# - Only add to the proceeding_id metadata field if the id of the proceeding is CLEARLY STATED in the original user query.
#
# Schema:
# {'type': 'object', 'properties': {'subquery': {'type': 'string', 'description': 'A specific subquery derived from the user query for efficient document retrieval.', 'examples': "Describe key aspects of Pacific Gas and Electric's (PG&E) 2023 General Rate Case application."}, 'search_strings': {'type': 'array', 'items': {'type': 'string', 'description': 'A search string derived from the subquery that will be used to retrieve relevant documents from the vector database. We include multiple in case the subquery involves multiple aspects or entities.'}, 'description': 'A list of search strings that will be used to retrieve relevant documents from the vector database.', 'maxItems': 2, 'minItems': 1}, 'proceeding_id': {'type': 'array', 'items': {'type': 'string', 'description': 'The unique identifier for the proceeding related to the subquery extracted from the subquery if available.', 'examples': ['A.23-03-005', 'A.21-06-021']}, 'description': 'List of unique identifiers for the proceeding related to the subquery. This field should only be populated if the id of the proceeding is clearly stated in the original user query.'}}}
#
# Only return a list of such JSON objects, without any extra commentary, explanation, or markdown formatting.
#
#
# USER QUERY:
# Based on the public record in proceeding A.21-06-021, analyze the differences between PG&E's original undergrounding proposal and what was authorized in Decision 23-11-069. Include: (1) comparison of the miles of undergrounding requested by PG&E versus what was approved by the CPUC and the stated rationale for the reduction in the decision, (2) analysis of the Administrative Law Judge's Proposed Decision versus the Alternate Proposed Decision regarding undergrounding miles and which approach was ultimately adopted, (3) summary of intervenor positions on undergrounding from their filed testimony, including any opposition or alternative proposals, (4) identification of the specific CPUC findings regarding cost-effectiveness of undergrounding versus covered conductor alternatives as stated in the final decision, and (5) explanation of how the decision addresses PG&E's 10,000-mile undergrounding program timeline based on the proceeding record.
# Response from LLM:
# ```json
# [
#   {
#     "subquery": "Compare PG&E's original undergrounding proposal in A.21-06-021 with the authorized undergrounding in Decision 23-11-069, focusing on the difference in miles and the CPUC's rationale for any reduction.",
#     "search_strings": [
#       "A.21-06-021 PG&E undergrounding proposal vs Decision 23-11-069",
#       "Decision 23-11-069 rationale for undergrounding reduction"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Analyze the Administrative Law Judge's Proposed Decision (PD) versus the Alternate Proposed Decision (APD) in A.21-06-021 regarding undergrounding miles, and identify which approach was adopted in Decision 23-11-069.",
#     "search_strings": [
#       "A.21-06-021 ALJ PD vs APD undergrounding miles",
#       "Decision 23-11-069 undergrounding miles PD APD"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Summarize intervenor positions on undergrounding in A.21-06-021, including opposition and alternative proposals from filed testimony.",
#     "search_strings": [
#       "A.21-06-021 intervenor positions undergrounding",
#       "A.21-06-021 intervenor testimony undergrounding"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Identify CPUC findings in Decision 23-11-069 regarding the cost-effectiveness of undergrounding versus covered conductor alternatives.",
#     "search_strings": [
#       "Decision 23-11-069 cost-effectiveness undergrounding covered conductor",
#       "Decision 23-11-069 undergrounding vs covered conductor cost"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Explain how Decision 23-11-069 addresses PG&E's 10,000-mile undergrounding program timeline based on the A.21-06-021 record.",
#     "search_strings": [
#       "Decision 23-11-069 PG&E 10000 mile undergrounding timeline",
#       "A.21-06-021 PG&E undergrounding program timeline"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   }
# ]
# ```

# %%
await process_subqueries(test_query, response.content)
# Out:
# [
#   {
#     "subquery": "Compare PG&E's original undergrounding proposal in A.21-06-021 with the authorized undergrounding in Decision 23-11-069, focusing on the difference in miles and the CPUC's rationale for any reduction.",
#     "search_strings": [
#       "A.21-06-021 PG&E undergrounding proposal vs Decision 23-11-069",
#       "Decision 23-11-069 rationale for undergrounding reduction"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Analyze the Administrative Law Judge's Proposed Decision (PD) versus the Alternate Proposed Decision (APD) in A.21-06-021 regarding undergrounding miles, and identify which approach was adopted in Decision 23-11-069.",
#     "search_strings": [
#       "A.21-06-021 ALJ PD vs APD undergrounding miles",
#       "Decision 23-11-069 undergrounding miles PD APD"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Summarize intervenor positions on undergrounding in A.21-06-021, including opposition and alternative proposals from filed testimony.",
#     "search_strings": [
#       "A.21-06-021 intervenor positions undergrounding",
#       "A.21-06-021 intervenor testimony undergrounding"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Identify CPUC findings in Decision 23-11-069 regarding the cost-effectiveness of undergrounding versus covered conductor alternatives.",
#     "search_strings": [
#       "Decision 23-11-069 cost-effectiveness undergrounding covered conductor",
#       "Decision 23-11-069 undergrounding vs covered conductor cost"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   },
#   {
#     "subquery": "Explain how Decision 23-11-069 addresses PG&E's 10,000-mile undergrounding program timeline based on the A.21-06-021 record.",
#     "search_strings": [
#       "Decision 23-11-069 PG&E 10000 mile undergrounding timeline",
#       "A.21-06-021 PG&E undergrounding program timeline"
#     ],
#     "proceeding_id": [
#       "A.21-06-021"
#     ]
#   }
# ]
# Proceeding ID 0: A2106021
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Proceeding ID 0: A2106021
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Proceeding ID 0: A2106021
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Proceeding ID 0: A2106021
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Proceeding ID 0: A2106021
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ## Comprehensive Analysis of PG&E's Undergrounding Proposal in A.21-06-021 and Decision 23-11-069
#
# This analysis synthesizes the public record in proceeding A.21-06-021 and Decision 23-11-069 to provide a comprehensive understanding of the regulatory landscape surrounding PG&E's undergrounding proposal. It encompasses the evolution of the proposal, the CPUC's rationale for modifications, a comparative analysis of the Proposed Decision (PD) and Alternate Proposed Decision (APD), and considerations of cost-effectiveness and timelines.
#
# ### 1. Comparison of Undergrounding Miles: PG&E's Proposal vs. CPUC Authorization
#
# *   **Initial Proposal:** PG&E initially proposed undergrounding **3,600 miles** of distribution lines, announced in February 2022, as part of its broader **10,000-mile** undergrounding concept announced in late 2021. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [A2306008, Brief, p. 4](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M545/K343/545343978.PDF), [A.21-06-021, Brief, p. 379](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K814/498814881.PDF]]
# *   **Reasons for Adjustments:** PG&E significantly reduced its undergrounding proposal due to concerns about its **executability**. [[A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)] Specific issues included:
#     *   Obtaining environmental, Caltrans, and municipal permits. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]
#     *   Acquiring land rights. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]
#     *   Coordinating with stakeholders and landowners. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]
#     *   Completing CEQA review. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]
#     *   TURN noted that PG&E's reductions amounted to approximately 1,200 miles in a proposal filed on December 9, 2022. [[D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]
# *   **CPUC Concerns and RAMP Process:** Cal Advocates raised concerns that the significantly different undergrounding proposals presented in February and December 2022 were not vetted through the Risk Assessment Mitigation Phase (RAMP) process. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF]] PG&E acknowledged that its expanded undergrounding proposal was not included in its RAMP proceeding (A.20-06-020). [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)]
# *   **Final Authorization:** Decision 23-11-069 authorized **200 miles** of wildfire mitigation undergrounding. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K613/520613654.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K613/520613654.PDF), [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526939.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526939.PDF)]
#
# ### 2. Analysis of PD vs. APD Regarding Undergrounding Miles
#
# *   The PD and APD in A.21-06-021 differed significantly in their recommendations for undergrounding versus covered conductor, with the **PD calling for 200 miles of undergrounding** and **the APD calling for 973 miles**. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K515/520515932.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K515/520515932.PDF)]
# *   PG&E proposed undergrounding 2,000 miles of conductor, but the PD and APD questioned PG&E's ability to achieve this target within four years, given their past performance. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K532/520532473.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K532/520532473.PDF)]
# *   Decision 23-11-069 adopted elements of both the PD and APD, authorizing **200 miles** of wildfire mitigation undergrounding while emphasizing enhanced oversight and accountability. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K613/520613654.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K613/520613654.PDF), [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526939.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526939.PDF)]
#
# ### 3. Intervenor Positions on Undergrounding
#
# I am sorry, but I cannot provide a summary of intervenor positions on undergrounding in A.21-06-021. The documents provided do not contain information about intervenor positions on undergrounding.
#
# ### 4. CPUC Findings on Cost-Effectiveness of Undergrounding vs. Covered Conductor
#
# *   **Relative Costs**: The CPUC determined a reasonable cost for covered conductor installation of $1.261 million per mile in 2023, increasing to approximately $1.396 million per mile in 2026. [[, 520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)] In contrast, a Proposed Decision in A.21-06-021 found that PG&E's claim that undergrounding costs would decline during the rate case period (from $3.3 million per mile in 2023 to $2.8 million per mile in 2026) was unpersuasive. [[, 520418881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)]
# *   **Undergrounding Cost Estimates**: PG&E’s estimated costs for undergrounding of approximately $3.3 million per mile in 2023, decreasing to approximately $2.8 million in 2026 (four-year average cost of $2.97 million) was considered reasonable. [[, 520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)]
# *   **Covered Conductor as an Alternative**: Covered conductor offers significant risk reduction benefits, can be deployed more quickly, and is significantly less costly than undergrounding. [[, 526147020.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K613/520613654.PDF)] TURN found that covered conductor has a higher Risk Spend Efficiency (RSE) than undergrounding. [[, 498814881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)]
# *   **Factors Influencing Cost-Effectiveness**: The cost-effectiveness of hardening overhead distribution circuits varies spatially due to factors like vegetation and wind. [[, 498814881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)]
#
# ### 5. Addressing PG&E's 10,000-Mile Undergrounding Program Timeline in Decision 23-11-069
#
# *   **Initial Proposal and CPUC Concerns**: PG&E's initial plan to underground 10,000 miles was significantly cut back in Decision 23-10-069 due to concerns raised by TURN and other parties regarding various problems with the proposal. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M545/K343/545343978.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M545/K343/545343978.PDF)]
# *   **CPUC's Phased Approach and Scrutiny of Costs**: The CPUC decided to implement a phased approach, initially approving 2,000 miles of undergrounding in the A.21-06-021 application to allow PG&E to demonstrate its capabilities. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)] The Commission emphasized that PG&E's actual costs per mile and the trend of these costs would be a factor in assessing the reasonableness of future undergrounding requests. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)]
# *   **Feasibility Concerns and Past Performance**: The CPUC raised concerns about PG&E's ability to secure the necessary construction resources to complete such a large project. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)] PG&E's historical undergrounding rate of approximately 22 miles per year (2015-2021) was cited as a reason to doubt the feasibility of the ambitious 2,000-mile proposal. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF), [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K807/498807440.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K807/498807440.PDF), [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K814/498814881.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K814/498814881.PDF)]
# *   **Timeline Concerns and OEIS Findings**: The Commission was presented with arguments that PG&E's proposed timeline for the undergrounding program was unrealistic and lacked sufficient support. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K338/498338970.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K338/498338970.PDF)] The Office of Energy Infrastructure Safety (OEIS) identified discrepancies between PG&E's undergrounding plans and goals, further highlighting the uncertainty in the timeline. [[https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K338/498338970.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K338/498338970.PDF)]
#
# ### Conclusion
#
# Decision 23-11-069, informed by the A.21-06-021 record, reflects the CPUC's cautious approach to PG&E's ambitious 10,000-mile undergrounding program. The decision significantly scaled back the initial proposal due to concerns about feasibility, cost management, and historical performance. The CPUC opted for a phased implementation, emphasizing the need for PG&E to demonstrate its capabilities and cost-effectiveness before considering further expansion of the program. The decision also reflects a preference for covered conductor as a more cost-effective and rapidly deployable alternative for wildfire mitigation in certain circumstances. The CPUC's focus remains on ensuring that any investments in undergrounding are reasonable, cost-effective, and contribute to a tangible reduction in wildfire risk.
# "## Comprehensive Analysis of PG&E's Undergrounding Proposal in A.21-06-021 and Decision 23-11-069\n\nThis analysis synthesizes the public record in proceeding A.21-06-021 and Decision 23-11-069 to provide a comprehensive understanding of the regulatory landscape surrounding PG&E's undergrounding proposal. It encompasses the evolution of the proposal, the CPUC's rationale for modifications, a comparative analysis of the Proposed Decision (PD) and Alternate Proposed Decision (APD), and considerations of cost-effectiveness and timelines.\n\n### 1. Comparison of Undergrounding Miles: PG&E's Proposal vs. CPUC Authorization\n\n*   **Initial Proposal:** PG&E initially proposed undergrounding **3,600 miles** of distribution lines, announced in February 2022, as part of its broader **10,000-mile** undergrounding concept announced in late 2021. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [A2306008, Brief, p. 4](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M545/K343/545343978.PDF), [A.21-06-021, Brief, p. 379](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K814/498814881.PDF]]\n*   **Reasons for Adjustments:** PG&E significantly reduced its undergrounding proposal due to concerns about its **executability**. [[A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)] Specific issues included:\n    *   Obtaining environmental, Caltrans, and municipal permits. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]\n    *   Acquiring land rights. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]\n    *   Coordinating with stakeholders and landowners. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]\n    *   Completing CEQA review. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), [D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]\n    *   TURN noted that PG&E's reductions amounted to approximately 1,200 miles in a proposal filed on December 9, 2022. [[D2311069, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf)]\n*   **CPUC Concerns and RAMP Process:** Cal Advocates raised concerns that the significantly different undergrounding proposals presented in February and December 2022 were not vetted through the Risk Assessment Mitigation Phase (RAMP) process. [[A.21-06-021, Proposed Decision, p. 249](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), [A.21-06-021, Alternate, p. 248](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF]] PG&E acknowledged that its expanded undergrounding proposal was not included in its RAMP proceeding (A.20-06-020). [[A.21-06-021, Proposed Decision, p. 249](https:/ ...

# %%
query = 'Summarize intervenor positions on undergrounding in A.21-06-021, including opposition and alternative proposals from filed testimony.'

query_filter = Filter(
            must=[
                models.FieldCondition(
                    key="proceeding_id",
                    match=models.MatchAny(any=["A2106021"])
                )
            ]
        )

results = query_db(
        query=query, # use first string for retrieval, will modify later to use all and combine
        k=50,
        search_filter = query_filter,
        qdrant_client=qdrant_client,
        collection_name=DOCUMENT_COLLECTION,
    )

# Format results for LangChain compatibility
retrieved_docs = []
for result in results:
    doc_id = result.payload['document_id']
    content = result.payload['text']
    metadata = {k: v for k, v in result.payload.items() if k != 'text'} if result.payload else {}

    doc = Document(page_content=content, metadata=metadata)
    retrieved_docs.append(doc)

    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\n" f"Content: {doc.page_content} Document Link: {doc.metadata.get('source_url', 'N/A')}")
        for doc in retrieved_docs
    )
print(serialized)
# Out:
# Source: {'chunk_index': 11, 'document_id': '418717765', 'proceeding_id': 'A2101003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M418/K717/418717765.PDF', 'published_date': '11/01/2021', 'year': 0, 'title': 'Motion filed by WATER RATE ADVOCATES FOR TRANSPARENCY, EQUITY AND SUSTAINABILITY on 10/26/2021 Conf# 173304', 'doc_type': 'Motion'}
# Content: May 27, 2021; Motion for an extension to serve intervenor testimony.
# 12 D.0606066 with modifications
# 13 GO 66-D 3.3 and 3.4 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M418/K717/418717765.PDF
#
# Source: {'chunk_index': 13, 'document_id': '397312194', 'proceeding_id': 'A2107003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M397/K312/397312194.PDF', 'published_date': '08/09/2021', 'year': 0, 'title': 'Protest filed by Cal Advocates/Zarchy/CPUC on 08/06/2021 Conf# 169341', 'doc_type': 'Protest'}
# Content: 01/24/22
# Other Intervenor Testimony
# 10/06/21
# 02/07/22
# Rebuttal Testimony
# 10/21/21
# 03/23/22
# Alternative Dispute Resolution Begins
# 10/25/21
# 03/29/22
# Evidentiary Hearings Start Date
# 11/04/21
# 04/18/22
# Opening Briefs Filed and Served
# 12/08/21
# 06/07/22
# Motion for Interim Rates
# 12/08/21
# 06/07/22
# Mandatory Status Conference
# 12/09/21
# 06/08/22
# Reply Briefs Filed and Served (with
# Comparison Exhibit)
# 12/23/21
# 06/17/22
#
# 11 D.07-05-062, pp. 5-9. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M397/K312/397312194.PDF
#
# Source: {'chunk_index': 12, 'document_id': '397312196', 'proceeding_id': 'A2107004', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M397/K312/397312196.PDF', 'published_date': '08/09/2021', 'year': 0, 'title': 'Protest filed by Cal Advocates/Zarchy/CPUC on 08/06/2021 Conf# 169339', 'doc_type': 'Protest'}
# Content: 10/06/21
# 01/24/22
# Other Intervenor Testimony
# 10/06/21
# 02/07/22
# Rebuttal Testimony
# 10/21/21
# 03/23/22
# Alternative Dispute Resolution Begins
# 10/25/21
# 03/29/22
# Evidentiary Hearings Start Date
# 11/04/21
# 04/18/22
# Opening Briefs Filed and Served
# 12/08/21
# 06/07/22
# Motion for Interim Rates
# 12/08/21
# 06/07/22
# Mandatory Status Conference
# 12/09/21
# 06/08/22
# Reply Briefs Filed and Served (with
# Comparison Exhibit)
# 12/23/21
# 06/17/22
#
# 11 D.07-05-062, pp. 5-9. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M397/K312/397312196.PDF
#
# Source: {'chunk_index': 5, 'document_id': '560273042', 'proceeding_id': 'A2409014', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M560/K273/560273042.PDF', 'published_date': '03/21/2025', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/ALICE REYNOLDS/CPUC on 03/21/2025 Conf# 216576', 'doc_type': 'Scoping Ruling'}
# Content: Documents
# July 23, 2025
# Intervenors Testimony served and
# submitted as Supporting
# Documents
# August 25, 2025
# Settlement Discussions
# September 2025-December 2025
# Concurrent Rebuttal Testimony
# served and submitted as Supporting
# Documents
# January 16, 2026
# Rule 13.9 Meet and Confer Report
# (including List of Stipulated and
# Disputed Facts) filed and served
# February 2, 2026 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M560/K273/560273042.PDF
#
# Source: {'chunk_index': 3, 'document_id': '538612792', 'proceeding_id': 'A2312014', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M538/K612/538612792.PDF', 'published_date': '08/21/2024', 'year': 0, 'title': 'Response filed by Cal Adovcates/M.George/CPUC on 08/20/2024 Conf# 210199', 'doc_type': 'Response'}
# Content: intervenor testimony.  The stipulation also requests that the Motion be granted. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M538/K612/538612792.PDF
#
# Source: {'chunk_index': 25, 'document_id': '539203665', 'proceeding_id': 'A2408012', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M539/K203/539203665.PDF', 'published_date': '08/28/2024', 'year': 0, 'title': 'Application filed by SOUTHERN CALIFORNIA EDISON COMPANY on 08/28/2024 Conf# 210422', 'doc_type': 'Application'}
# Content: set for intervenor testimony and rebuttal testimony, along with dates for the evidentiary hearings. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M539/K203/539203665.PDF
#
# Source: {'chunk_index': 7, 'document_id': '347811029', 'proceeding_id': 'R2001007', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M347/K811/347811029.PDF', 'published_date': '10/02/2020', 'year': 0, 'title': 'Ruling filed by ALJ/TRAN/CPUC on 10/02/2020 Conf# 155478', 'doc_type': 'Ruling'}
# Content: Intervenor Testimony
# (if determined
# to be needed)
# January 5, 2021
# February 22, 2021
#
# Rebuttal Testimony
# (if determined
# to be needed)
# January 20, 2021
# March 8, 2021 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M347/K811/347811029.PDF
#
# Source: {'chunk_index': 5, 'document_id': '441160145', 'proceeding_id': 'A2111017', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M441/K160/441160145.PDF', 'published_date': '01/19/2022', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/RECHTSCHAFFEN/CPUC on 01/19/2022 Conf# 176370', 'doc_type': 'Scoping Ruling'}
# Content: resolution of the application:
#
#
# Event
# Date
# Intervenors’ prepared direct testimony served
# January 31, 2022
# Prepared rebuttal testimony served
# February 14, 2022
# Motion for Evidentiary Hearing
# February 16, 2022
# Evidentiary hearing (if needed)
# Feb. 23-25, 2022
# Opening briefs (if no Evidentiary Hearing)
# February 28, 2022
# Reply briefs (if no Evidentiary Hearing)
# March 14, 2022
# Opening briefs (if Evidentiary Hearing)
# March 14, 2022 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M441/K160/441160145.PDF
#
# Source: {'chunk_index': 8, 'document_id': '340868969', 'proceeding_id': 'A2004003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M340/K868/340868969.PDF', 'published_date': '06/19/2020', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/SHIROMA/CPUC on 06/19/2020 Conf# 150992', 'doc_type': 'Scoping Ruling'}
# Content: Event
# Date
# Intervenors’ prepared direct
# testimony served
# Monday, July 6, 2020
# Prepared rebuttal testimony
# served
# Monday, July 27, 2020
# Public Participation Hearings
# Monday, August 3, 2020
# Settlement Conference
# TBD
# Evidentiary hearing
# Monday August 10 – Friday
# August 14, 2020
# Opening briefs
# Monday, August 31, 2020
# Reply briefs [matter submitted]
# Monday, September 14, 2020
# Proposed decision
# Monday, November 23, 2020 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M340/K868/340868969.PDF
#
# Source: {'chunk_index': 48, 'document_id': '385840299', 'proceeding_id': 'A2011001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF', 'published_date': '06/01/2021', 'year': 0, 'title': 'Brief filed by The Utility Reform Network on 05/28/2021 Conf# 166422', 'doc_type': 'Brief'}
# Content: 34 Mailloux Intervenor Testimony (Exh. TURN-01-C) at pp. 5-6; Ahlstedt Intervenor Testimony (Exh.
# CA-06-C) at p. 18-19. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF
#
# Source: {'chunk_index': 6, 'document_id': '348580419', 'proceeding_id': 'A2008002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M348/K580/348580419.PDF', 'published_date': '10/14/2020', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/GUZMAN ACEVES/CPUC on 10/14/2020 Conf# 156000', 'doc_type': 'Scoping Ruling'}
# Content: A.20-08-002  COM/MGA/kz1
# - 4 -
#
#
# Event
# Date
# Intervenors’ prepared direct testimony served   December 1, 2020
# Prepared rebuttal testimony served
#  February 1, 2021
# Joint Status Update
#  February 5, 2021
# Evidentiary hearing (two days)
#  February 15, 2021-
#  February 16, 2021
# Opening briefs
#  March 19, 2021
# Reply briefs
#  April 2, 2021
#
#
# By February 5, 2021, the parties shall file a Joint Status Update confirming
# the need for an evidentiary hearing.  If evidentiary hearings are confirmed,
# parties shall include in the Joint Status Update:  1) The order of witnesses for
# evidentiary hearings, and 2) cross-examination times estimated by each of the
# parties, and for each of the witnesses they wish to question.
# The organization of prepared testimony and briefs must correlate to the
# identified issues.
# The above schedule may be modified if a motion for an interim decision is
# granted and prepared on any uncontested or contested issues.  In addition, the Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M348/K580/348580419.PDF
#
# Source: {'chunk_index': 8, 'document_id': '496451498', 'proceeding_id': 'A2204001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M496/K451/496451498.PDF', 'published_date': '08/11/2022', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/JOHN REYNOLDS/CPUC on 08/11/2022 Conf# 183768', 'doc_type': 'Scoping Ruling'}
# Content: Event
# Date
# Intervenors’ prepared direct testimony served
# December 5, 2022
# Prepared rebuttal testimony served
# January 31, 2023
# Settlement Talks
# February 2023
# Meet and Confer
# By March 1, 2023
# Completion of Settlement Talks
# March 10, 2023
# Status Conference
# March 14, 2023
# Evidentiary hearing
# March 22 – March 24, 2023
# Concurrent Opening briefs
# April 14, 2023
# Concurrent Reply briefs [matter submitted]
# April 28, 2023
# Proposed decision
# June to July 2023 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M496/K451/496451498.PDF
#
# Source: {'chunk_index': 1, 'document_id': '564685945', 'proceeding_id': 'A2405020', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M564/K685/564685945.PDF', 'published_date': '04/23/2025', 'year': 0, 'title': 'Ruling filed by ALJ/PRATT/CPUC on 04/23/2025 Conf# 217497', 'doc_type': 'Ruling'}
# Content: Event
# Date
# Intervenors’ prepared direct testimony
# served
# May 9, 2025
# Prepared rebuttal testimony served
# May 30, 2025
# Meet and confer
# June 2025
# Joint Case Management Statement
# June 27, 2025
# Evidentiary hearing, if needed
# July 2025
# FILED
# 04/23/25
# 11:36 AM
# A2405020 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M564/K685/564685945.PDF
#
# Source: {'chunk_index': 4, 'document_id': '355771011', 'proceeding_id': 'A2009002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M355/K771/355771011.PDF', 'published_date': '12/22/2020', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/RECHTSCHAFFEN/CPUC on 12/22/2020 Conf# 159273', 'doc_type': 'Scoping Ruling'}
# Content: A.20-09-002  COM/CR6/smt
#
# - 3 -
#
#
# Event
# Date
# Joint Status Update
# March 1, 2021
# Intervenors’ prepared direct
# testimony served
# March 5, 2021
# Public Participation Hearing
# To be determined
# Prepared rebuttal testimony served
#              April 2, 2021
# Evidentiary Hearing
# April 21-23, 2021
# Opening briefs
# May 21, 2021
# Reply briefs [matter submitted]
# June 7, 2021
# Proposed decision
# [no later than 90 days after
# submission]
# Commission decision
# [no sooner than 30 days after
# PD]
#
#
# By March 1, 2021, the parties shall file a Joint Status Update confirming
# the need for an evidentiary hearing.  If evidentiary hearings are confirmed,
# parties shall include in the Joint Status Update:  1) any and all stipulated factual
# and legal issues, 2) all material disputed factual and legal issues and the
# evidentiary basis for claims and defenses, 3) the party or parties who will be
# submitting templates for all rates proposed by the parties in their prepared Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M355/K771/355771011.PDF
#
# Source: {'chunk_index': 9, 'document_id': '540720009', 'proceeding_id': 'A2406001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M540/K720/540720009.PDF', 'published_date': '09/19/2024', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/JOHN REYNOLDS/CPUC on 09/19/2024 Conf# 211063', 'doc_type': 'Scoping Ruling'}
# Content: December 13, 2024
# Intervenors’ and applicant’s rebuttal testimony
# served
# February 14, 2025
# Rule 13.9 Meet and Confer Deadline by which
# parties must file a joint case management
# statement indicating whether the parties believe
# an evidentiary hearing is necessary, providing an
# update on settlement discussions, identifying any
# contested material issues of fact, witness lists, and
# a proposed schedule for cross-examination
# March 7, 2025
# Evidentiary hearing (if necessary)
#
# Week of March 24, 2025
# If evidentiary hearing not held, date by which
# parties must submit joint statement moving to
# April 11, 2025 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M540/K720/540720009.PDF
#
# Source: {'chunk_index': 10, 'document_id': '479337946', 'proceeding_id': 'A2202016', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M479/K337/479337946.PDF', 'published_date': '05/24/2022', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/HOUCK/CPUC on 05/24/2022 Conf# 180952', 'doc_type': 'Scoping Ruling'}
# Content: A.22-02-016  COM/DLH/lil
#
#
# - 6 -
# Event
# Date
# Intervenors’ prepared direct testimony
# served
# September 23, 2022
# Prepared rebuttal testimony served
# November 14, 2022
# Meet and Confer
# (Pursuant to Rule 13.9)
# December 1, 2022
# Evidentiary hearing
# January 18-20, 2023
# Opening briefs filed
# February 17, 2023
# Reply briefs filed [matter submitted]
# March 17, 2023
# Proposed decision
# 2nd Quarter of 2023
#
#
# The purpose of the December 1, 2022 status conference is to ascertain
# whether, pursuant to Rule 13.8(c), the parties stipulate to the receipt of prepared
# testimony into evidence without direct or cross examination or other need to
# convene an evidentiary hearing or, in the alternative, the parties’ resources,
# readiness and needs for the effective remote conduct of the evidentiary hearing,
# including estimates of time requested for cross-examination and identification of
# anticipated exhibits.
# The proceeding will stand submitted upon the filing of reply briefs, unless Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M479/K337/479337946.PDF
#
# Source: {'chunk_index': 5, 'document_id': '526148055', 'proceeding_id': 'A2401002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M526/K148/526148055.PDF', 'published_date': '02/29/2024', 'year': 0, 'title': 'Statement filed by LIBERTY UTILITIES (PARK WATER) CORP. on 02/20/2024 Conf# 203384', 'doc_type': 'Statement'}
# Content: 07/24/24
# Other Intervenor Testimony
# 08/07/24
# Rebuttal Testimony
# 09/23/24
# Formal Settlement Negotiations
# 09/28/24 – 10/18/24
# Alternative Dispute Resolution
# Begins
# 10/01/24-10/18/24 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M526/K148/526148055.PDF
#
# Source: {'chunk_index': 4, 'document_id': '562392355', 'proceeding_id': 'A2410006', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M562/K392/562392355.PDF', 'published_date': '04/10/2025', 'year': 0, 'title': 'Ruling filed by ALJ/FOX/CPUC on 04/09/2025 Conf# 217089', 'doc_type': 'Ruling'}
# Content: allow service of supplemental intervenor testimony on May 15, 2025.  The
# supplemental intervenor testimony shall be limited in scope to only addressing
# any new materials not previously shared with intervenors and presented in Joint
# Applicants’ Supplemental Testimony due on April 25, 2025. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M562/K392/562392355.PDF
#
# Source: {'chunk_index': 5, 'document_id': '480219391', 'proceeding_id': 'A2112006', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M480/K219/480219391.PDF', 'published_date': '05/31/2022', 'year': 0, 'title': 'Ruling filed by ALJ/WANG/CPUC on 05/31/2022 Conf# 181186', 'doc_type': 'Ruling'}
# Content: Intervenor testimony served
# August 25, 2022
# September 8, 2022
# Rebuttal testimony served
# September 23, 2022
# October 6, 2022
# Meet and confer
# September/October 2022
# October 2022
# Joint Case Management
# Statement
# October 6, 2022
# November 9, 2022
#
# 1  In its response to the Public Advocates Office’s motion, SDG&E requested that any
# evidentiary hearing be held either in November 2022 or after December 2022. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M480/K219/480219391.PDF
#
# Source: {'chunk_index': 5, 'document_id': '542964535', 'proceeding_id': 'A2405002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M542/K964/542964535.PDF', 'published_date': '10/18/2024', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/BAKER/CPUC on 10/18/2024 Conf# 212084', 'doc_type': 'Scoping Ruling'}
# Content: Intervenors’ prepared direct testimony served
# November 1, 2024
# Prepared rebuttal testimony served
# November 22, 2024
# Virtual Public Participation Hearings
# TBD
# Evidentiary hearing
# April 2025
# Opening briefs
# May 1, 2025
# Reply briefs [matter submitted]
# May 22, 2025
# Proposed decision (PD)
# No later than 90 days
# after submission
# Commission decision
# No sooner than 30 days
# after PD
# The proceeding will stand submitted upon the filing of reply briefs, unless
# the ALJ requires further evidence or argument. Based on this schedule, the Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M542/K964/542964535.PDF
#
# Source: {'chunk_index': 11, 'document_id': '542964529', 'proceeding_id': 'A2310009', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M542/K964/542964529.PDF', 'published_date': '10/17/2024', 'year': 0, 'title': 'Request filed by Community Legal Services on 10/17/2024 Conf# 212042 (Attachment2)', 'doc_type': 'Request'}
# Content: 2.50
# 2/21/2024 Review PG&E responses to DRs
# 0.50
# 2/22/2024 Email discussion with PG&E re: DR Documentation and Answer Not Provided
# 0.17
# 2/22/2024 Draft Notes re: Issues and Arguments for Intervenor Testimony
# 2.17
# 2/22/2024 Email discussion with Lillian Rafii re: Data Requests
# 0.25
# 2/22/2024 Review Testimony in A.21-12-007 as referenced in Data Requests
# 0.65
# 2/23/2024
# Review Notes re: Issues and Arguments for Intervenor Testimony to Prepare for Meeting
# with TG
# 0.33
# 2/23/2024 Meeting with TG re: Issues and Arguments for Intervenor Testimony
# 1.50
# 2/23/2024 Draft Intervenor Testimony
# 1.00
# 2/23/2024 Review Testimony in A.21-12-007 as referenced in Data Requests
# 0.42
# 2/26/2024 Review Testimony in A.21-12-007 as referenced in Data Requests
# 1.33
# 2/26/2024 Draft Intervenor Testimony
# 0.08
# Page 4 of 7 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M542/K964/542964529.PDF
#
# Source: {'chunk_index': 17, 'document_id': '558014112', 'proceeding_id': 'A2308013', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M558/K014/558014112.PDF', 'published_date': '02/28/2025', 'year': 0, 'title': 'A.23-08-013 Amended Settlement Agreement dated 12 6 24.docx', 'doc_type': 'Final Decision'}
# Content: extended by parties’ agreement and ALJ’s rulings, with intervenor testimony due Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M558/K014/558014112.PDF
#
# Source: {'chunk_index': 17, 'document_id': '551544152', 'proceeding_id': 'A2308013', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M551/K544/551544152.PDF', 'published_date': '12/27/2024', 'year': 0, 'title': 'Proposed Decision filed by ALJ/LARSEN/CPUC on 12/27/2024 Conf# 214247 (Attachment2)', 'doc_type': 'Proposed Decision'}
# Content: extended by parties’ agreement and ALJ’s rulings, with intervenor testimony due Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M551/K544/551544152.PDF
#
# Source: {'chunk_index': 16, 'document_id': '548361423', 'proceeding_id': 'A2308013', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M548/K361/548361423.PDF', 'published_date': '12/09/2024', 'year': 0, 'title': 'Report filed by SOUTHERN CALIFORNIA EDISON COMPANY on 12/06/2024 Conf# 213630', 'doc_type': 'Report'}
# Content: extended by parties’ agreement and ALJ’s rulings, with intervenor testimony due Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M548/K361/548361423.PDF
#
# Source: {'chunk_index': 86, 'document_id': '543719453', 'proceeding_id': 'A2106021', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M543/K719/543719453.PDF', 'published_date': '10/18/2024', 'year': 0, 'title': 'D2410026 Dec Granting Compensation to TURN D2203008 D2311069', 'doc_type': 'Final Decision'}
# Content: A.21-06-021  ALJ/JOR/JR7/jnf
#
# - 42 -
# Intervenor’s Claimed Contribution(s)
# to D.23-11-0695
# Specific References to
# Intervenor’s Claimed
# Contribution(s)6
# CPUC
# Discussion
# motions was generally coded by the
# relevant subject matter area, but if no
# single issue area applied it was coded
# "proc." The procedural victories on
# several key issues were important to
# ensure Commission consideration of
# these issues, and to ensure sufficient
# evidence was present in the record.
# TURN lists below several of the key
# procedural victories that were relevant to
# our subsequent contributions on the
# underlying substantive issues.
#
#  Consideration of Undergrounding
# Proposal
# TURN advocated that PG&E be required
# to update its entire showing due to the
# announcement of the undergrounding
# proposal after the filing of the
# application.
#
# The Assigned Commissioner agreed and
# ordered PG&E to submit supplemental
# testimony.
#
#  Use of Affordability Metrics
# TURN requested that PG&E provide an Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M543/K719/543719453.PDF
#
# Source: {'chunk_index': 216, 'document_id': '385840299', 'proceeding_id': 'A2011001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF', 'published_date': '06/01/2021', 'year': 0, 'title': 'Brief filed by The Utility Reform Network on 05/28/2021 Conf# 166422', 'doc_type': 'Brief'}
# Content: 312 Karambelkar Intervenor Testimony (Exh. CA-04-C) at pp. 14-15, 20-22. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF
#
# Source: {'chunk_index': 1, 'document_id': '523197165', 'proceeding_id': 'A2303002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M523/K197/523197165.PDF', 'published_date': '01/12/2024', 'year': 0, 'title': 'Ruling filed by ALJ/GLEGOLA/CPUC on 01/12/2024 Conf# 201838', 'doc_type': 'Ruling'}
# Content: and March 19
# Intervenors’ Testimony, filed and
# served
# November 30, 2023
#
# 1 Assigned Commissioner’s Scoping Memo and Ruling, issued November 21, 2023, at 4.
# FILED
# 01/12/24
# 03:09 PM
# A2303002 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M523/K197/523197165.PDF
#
# Source: {'chunk_index': 1, 'document_id': '528454348', 'proceeding_id': 'A2205006', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M528/K454/528454348.PDF', 'published_date': '04/02/2024', 'year': 0, 'title': 'Ruling filed by ALJ/SISTO/CPUC on 04/02/2024 Conf# 204880', 'doc_type': 'Ruling'}
# Content: intervenor testimony is due on April 3, 2024, and PacifiCorp’s rebuttal testimony
# is due on May 10, 2024.
# The purpose of the April 10, 2024, status conference is to determine,
# pursuant to Rule 13.8(c) of the Rules of Practice and Procedure (Rules), whether
# the parties stipulate to the receipt of prepared testimony into evidence without
# direct or cross examination or other need to convene an evidentiary hearing or,
# in the alternative, the parties’ resources, readiness and needs for the effective
# FILED
# 04/02/24
# 10:35 AM
# A2205006 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M528/K454/528454348.PDF
#
# Source: {'chunk_index': 6, 'document_id': '560138216', 'proceeding_id': 'A2412009', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M560/K138/560138216.PDF', 'published_date': '03/25/2025', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/BAKER/CPUC on 03/25/2025 Conf# 216653', 'doc_type': 'Scoping Ruling'}
# Content: A.24-12-009  COM/MBK/jnf
# - 4 -
# 4.
# Schedule
# The following schedule is adopted here and may be modified by the ALJs
# as required, to promote the efficient and fair resolution of the application:
# Item
# Timing
# Notices of Intent to Claim Intervenor Compensation Due
# (Filed)
# April 16, 2025
# Intervenors’ prepared direct testimony served
# June 4, 2025
# Rebuttal Testimony
# June 20, 2025
# Deadline to file a motion to request evidentiary hearings,
# detailing disputed issues of material fact
# June 30, 2025
# ALJ ruling confirming need for evidentiary hearings
# July 7, 2025
# If evidentiary hearings are not held:
# Opening briefs
# July 25, 2025
# Reply briefs (matter submitted)
# August 8, 2025
# Proposed Decision published for party comments
# September 5, 2025
# Proposed Decision on Commission agenda for vote
# October 9, 2025
# If evidentiary hearings are held:
# Evidentiary hearings
# July 22-23, 2025
# Opening briefs
# August 15, 2025
# Reply briefs (matter submitted)
# August 29, 2025 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M560/K138/560138216.PDF
#
# Source: {'chunk_index': 11, 'document_id': '506071500', 'proceeding_id': 'A2205005', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M506/K071/506071500.PDF', 'published_date': '04/11/2023', 'year': 0, 'title': 'Comments filed by PACIFIC GAS AND ELECTRIC COMPANY on 04/11/2023 Conf# 192082', 'doc_type': 'Comments'}
# Content: and address Commission precedent and the evidence in reaching its conclusion, not
# simply restate intervenors’ positions.
#
# 6  PD, pp. 14-15.
# 7  PD, pp. 14-15. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M506/K071/506071500.PDF
#
# Source: {'chunk_index': 105, 'document_id': '385840299', 'proceeding_id': 'A2011001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF', 'published_date': '06/01/2021', 'year': 0, 'title': 'Brief filed by The Utility Reform Network on 05/28/2021 Conf# 166422', 'doc_type': 'Brief'}
# Content: 116 Tr. Vol. 2, 306:1-6 (Mailloux); Exh. TURN X-10.
# 117 Ahlstedt Intervenor Testimony (Exh. CA-06-C) at p. 11.
# 118 Duffy Intervenor Testimony (Exh. CA-08-C) at pp. 21, 25.
# 119 Tr. Vol. 1, 200:16-19 (Klein, sealed testimony). Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF
#
# Source: {'chunk_index': 7, 'document_id': '511370444', 'proceeding_id': 'R2102014', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M511/K370/511370444.PDF', 'published_date': '06/16/2023', 'year': 0, 'title': 'D2306019 Decision Granting Compensation to CforAT (D2106036)', 'doc_type': 'Final Decision'}
# Content: R.21-02-014  ALJ/KWZ/jnf
# - 5 -
# Intervenor’s Claimed
# Contribution(s)
# Specific References to Intervenor’s
# Claimed Contribution(s)
# CPUC Discussion
#  Comments on Scoping
# Memo and Ruling, filed on
# March 22, 2021;
#  Responses to Post-Workshop
# Questions, filed on April 12,
# 2021;
#  Opening Brief, filed on April
# 23, 2021;
#  Ex Parte Notice, filed on
# April 26, 2021;
#  Reply Brief, filed on April
# 30, 2021;
#  Transcript of Evidentiary
# Hearing held on May 27,
# 2021;
#  Comments on Proposed
# Decision, filed on June 14,
# 2021;
#  Reply Comments on
# Proposed Decision, filed on
# June 21, 2021. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M511/K370/511370444.PDF
#
# Source: {'chunk_index': 9, 'document_id': '370844989', 'proceeding_id': 'A2012009', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M370/K844/370844989.PDF', 'published_date': '03/12/2021', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/BATJER/CPUC on 03/12/2021 Conf# 162913', 'doc_type': 'Scoping Ruling'}
# Content: Proposed Decision
# 4th Quarter of 2021
#
# Proceeding Schedule if Evidentiary Hearings are no longer needed.
# List of Stipulated and Disputed Facts6
# April 2, 2021
# Intervenors’ Testimony served
# April 29, 2021
# Handout for Workshops served
# May 7, 2021
# Technical Workshop
# May 11, 2021
#
# 5  A separate ruling will be issued giving parties further directions on the submission of the List
# of Stipulated and Disputed Facts.
# 6  A separate ruling will be issued giving parties further directions on the submission of the List
# of Stipulated and Disputed Facts. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M370/K844/370844989.PDF
#
# Source: {'chunk_index': 14, 'document_id': '437881018', 'proceeding_id': 'A2109018', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M437/K881/437881018.PDF', 'published_date': '01/05/2022', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/HOUCK/CPUC on 01/05/2022 Conf# 175772', 'doc_type': 'Scoping Ruling'}
# Content: Intervenor testimony and deadline to file
# motion for evidentiary hearings
# May 20, 2022
# Public participation hearings
# June-August 2022
# (dates to be determined)
# Concurrent rebuttal testimony
# July 29, 2022
# Meet and confer pursuant to Rule 13.9
# August 8, 2022
# Evidentiary hearings and workshops if
# needed and discovery cutoff
# September 2022
# (dates to be determined)
# Concurrent opening briefs
# October 28, 2022
# Concurrent reply briefs
# December 9, 2022
# Proposed Decision
# 3rd Quarter 2023
#
# 5  A.21-06-021, Assigned Commissioner’s Scoping Memo and Ruling at 12-13. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M437/K881/437881018.PDF
#
# Source: {'chunk_index': 16, 'document_id': '523043624', 'proceeding_id': 'A2310007', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M523/K043/523043624.PDF', 'published_date': '01/10/2024', 'year': 0, 'title': 'Statement filed by Cal-Ore Telephone Co. on 01/10/2024 Conf# 201732', 'doc_type': 'Statement'}
# Content: Intervenor
# Testimony Due
# 150
# Thursday,
# February 29, 2024
# Thursday,
# February 29, 2024
# Thursday,
# March 14, 2024
# Rebuttal Testimony
# Due
# 180
# Monday,
# April 1, 2024
# Monday,
# April 1, 2024
# Monday,
# April 15, 2024
# Meet and Confer
# (Rule 13.9)
# 190
# Thursday,
# April 11, 2024
# Thursday,
# April 11, 2024
# Thursday,
# April 25, 2024
# Evidentiary
# Hearings
# 210-220
# Monday, April 29,
# 2024 – Thursday,
# May 9, 2024
# the week of May 6,
# 2024
# the week of May 27,
# 2024
# Opening Briefs
# 250
# Monday, June 10,
# 2024
# Wednesday,
# June 19, 2024
# Wednesday,
# July 10, 2024
# Reply Briefs/ALJ
# closes record
# 271
# Monday, July 1,
# 2024
# Wednesday,
# July 10, 2024
# Wednesday,
# July 31, 2024
# Proposed Decision
# 331
# Wednesday, August
# 28, 2024
# September 2024
# September 2024
# Comments on PD
# 351
# Tuesday, September
# 17, 2024
# October 2024
# October 2024
# Commission
# Meeting/Decision
# 361-390
# Friday, September
# 27, 2024 – Saturday,
# October 26, 2024
# November 2024
# November 2024
# Implement new Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M523/K043/523043624.PDF
#
# Source: {'chunk_index': 7, 'document_id': '521134487', 'proceeding_id': 'A2303003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M521/K134/521134487.PDF', 'published_date': '12/04/2023', 'year': 0, 'title': 'Motion filed by Cal Advocates/K.Turner/CPUC on 12/01/2023 Conf# 200410', 'doc_type': 'Motion'}
# Content: 3
# Event
# Presently Scheduled Date
# Joint Intervenors’
# Proposed Date
# Applicant’s Opening
# Testimony filed and
# served
# December 19, 2023
# January 15, 2024
# Public Participation
# Hearings
# February and March 2024
# January 29, 2024, to February
# 29, 2024
# Intervenors’ prepared
# direct testimony served
# January 19, 2024
# March 11, 2024
# Applicant’s prepared
# rebuttal testimony served
# February 2, 2024
# March 25, 2024
# Status Conference
# January 2024
# April 2024
# Evidentiary Hearings
# April 2024
# May 2024
# Opening briefs
# TBD
# TBD
# Reply briefs [matter
# submitted]
# TBD
# TBD
# Proposed decision
# [no later than 90 days after
# submission]
# [no later than 90 days after
# submission]
# Pursuant to Rule 11.6, on November 29 and November 30, 2023, Joint Intervenors
# conferred with the parties to this proceeding via email, prior to making this request.  Nina
# Beety, representing herself, responded that she agrees with Joint Intervenors’ proposed Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M521/K134/521134487.PDF
#
# Source: {'chunk_index': 11, 'document_id': '524929421', 'proceeding_id': 'A2310001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M524/K929/524929421.PDF', 'published_date': '02/08/2024', 'year': 0, 'title': 'Notice filed by The Utility Reform Network on 02/08/2024 Conf# 202978', 'doc_type': 'Notice'}
# Content: intervenors as necessary to avoid duplication.
# The party’s description of the nature and extent of the party’s planned participation in this
# proceeding (to the extent that it is possible to describe on the date this NOI is filed).
# TURN has already been an active participant in this proceeding, including submitting a protest, a
# motion in opposition to SCE’s motion for Interim Rate Relief, and participating in the prehearing
# conference. TURN intends to actively participate in this proceeding on all of the above identified
# issues, including but not limited to serving testimony, participating in hearings, and filing all
# necessary pleadings. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M524/K929/524929421.PDF
#
# Source: {'chunk_index': 4, 'document_id': '528555371', 'proceeding_id': 'A2310001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M528/K555/528555371.PDF', 'published_date': '04/03/2024', 'year': 0, 'title': 'Exparte filed by Small Business Utility Advocates on 03/21/2024 Conf# 204536', 'doc_type': 'Exparte'}
# Content: proposed schedule, which inappropriately and inefficiently provides for SCE’s supplemental
# testimony being filed simultaneously with intervenor testimony on April 19, 2024.  Because the
# supplemental testimony has far-reaching significance that will alter SCE’s existing testimony,
# which intervenors are prepare to responding to, this piecemeal approach will be wasteful, create
# ambiguity about what is within scope for intervenor supplemental testimony and not afford
# adequate time for a complete evaluation, including any necessary discovery, by
# intervenors.  Finally (c) SBUA will be requesting that the ALJ urgently hold a status conference
# to address these considerations.
#
# Given the importance of these issues to developing a record appropriate to the size of SCE’s
# request and enabling robust participation, particularly in the event that the ALJ has not already Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M528/K555/528555371.PDF
#
# Source: {'chunk_index': 51, 'document_id': '530661199', 'proceeding_id': 'A2111024', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M530/K661/530661199.PDF', 'published_date': '05/03/2024', 'year': 0, 'title': 'Brief filed by City of Marina on 04/30/2024 Conf# 205932', 'doc_type': 'Brief'}
# Content: Phase 2: CalAm Phase 2 Direct Testimony due on July 20, 2022; Intervenor Phase 2 Testimony
# due on August 19, 2022; and CalAm Phase 2 Rebuttal Testimony due on September 19, 2022,
# with a Meet and Confer, a Joint Case Management Statement, and Evidentiary Hearings (as
#
# 33 D.22-12-001, at p. 9.
# 34 Id., at p. 10.
# 35 Id., at p. 15.
# 36 Id..
# 37 Id., at pp. 15-16.
# 38 Id., COLs 2 and 4, at p. 84; OP 1, at p. 87.
# 39 Id., at pp. 16-17, 69. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M530/K661/530661199.PDF
#
# Source: {'chunk_index': 9, 'document_id': '497964364', 'proceeding_id': 'A2208003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M497/K964/497964364.PDF', 'published_date': '10/26/2022', 'year': 0, 'title': 'Notice filed by Sierra Club on 10/26/2022 Conf# 186366', 'doc_type': 'Notice'}
# Content: Commission in R.19-01-011 on November 9, 2020.
# 4 See D.07-03-011 at 7 (“Section 1801.3(f) requires an intervenor to avoid unnecessary participation that Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M497/K964/497964364.PDF
#
# Source: {'chunk_index': 157, 'document_id': '512708142', 'proceeding_id': 'A2105017', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M512/K708/512708142.PDF', 'published_date': '06/28/2023', 'year': 0, 'title': 'Request filed by Tahoe Energy Ratepayers Group on 06/28/2023 Conf# 194658', 'doc_type': 'Request'}
# Content: Application No. 21-05-017 - Request for Intervenor Compensation
# Attachment 2. Time Sheet Records with Allocation of Hours by Issue
# Time Sheet Entries for Expert Witness Karen Miller
# ISSUE IDENTIFICATION
# 1.  Testimony Preparation
# 2.  Written Discovery
# 3.  CPUC Procedural Activities
# 4.  Settlement Agreement Activities
# 5.  Hearing Preparation
# 6.  Communications
# 7.  Protest to LU's Tariff Filing AL-219-E
# 8.  Preparation of the Intervenor Compensation Form
# 9.  Notion for Intention (NOI) to Claim Intervenor Status
# 10.  Preparation for participating in proceeding/Motion for Party Status
# Date
# Activity
# Issue 1
# Issue 2
# Issue 3
# Issue 4
# Issue 5
# Issue 6
# Issue 7
# Issue 8
# Issue 9
# Issue 10
# 6/2/2023 Begin review and analysis of LU AL 219-E
# 3.4
# 6/2/2023 Began drafting Intervenor Comp claim.
# 3.4
# 6/4/2023 Draft protest to LU AL
# 4
# 6/4/2023 Call w/ Anita to review draft protest to AL
# 0.2
# 6/4/2023 Working on Intervenor Comp Claim.
# 4.2
# 6/4/2023 Meeting with Anita regarding intervenor comp claim.
# 0.3 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M512/K708/512708142.PDF
#
# Source: {'chunk_index': 9, 'document_id': '340252586', 'proceeding_id': 'A2004002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M340/K252/340252586.PDF', 'published_date': '06/17/2020', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/GUZMAN ACEVES/CPUC on 06/17/2020 Conf# 150870', 'doc_type': 'Scoping Ruling'}
# Content: Intervenor Supplemental Testimony and Rebuttal
# Testimony on PSPS-related issues if there is a
# second phase of this proceeding.
# To Be Determined
# Meet and Confer, Joint Case Management
# Statement and Deadline to Confirm Need for
# Evidentiary Hearings
# December 3, 2020
# Evidentiary Hearings, if needed
# December 9-11, 2020
# Opening Briefs
# January 8, 2021
# Reply Briefs
# January 29, 2021
#
# The proceeding will stand submitted upon the filing of reply briefs, unless
# the ALJ requires further evidence or argument.  It is the Commission’s intent to Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M340/K252/340252586.PDF
#
# Source: {'chunk_index': 2, 'document_id': '370429058', 'proceeding_id': 'A2008002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M370/K429/370429058.PDF', 'published_date': '03/11/2021', 'year': 0, 'title': 'Ruling filed by ALJ/LARSEN/CPUC on 03/05/2021 Conf# 162849', 'doc_type': 'Ruling'}
# Content: serving Intervenor Direct Testimony of March 12, 2021. On March 2, 2021, the parties jointly requested
# an extension of the date for filing Intervenor Direct Testimony to March 18, 2021 due to service of
# Errata to the Supplemental Testimony served by PacificCorp on March 1, 2021. Good cause is found for
# this request. Accordingly, the hearing schedule is modified, as set forth below:
#
# Event
# Date
# Intervenor Direct Testimony
# March 18, 2021
# Rebuttal Testimony
# May 7, 2021
# Joint Status Update
# May 12, 2021
# Evidentiary Hearing
# May 25-26, 2021
# Simultaneous Opening Briefs
# June 18, 2021
# Simultaneous Reply Briefs
# July 2, 2021 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M370/K429/370429058.PDF
#
# Source: {'chunk_index': 11, 'document_id': '398465770', 'proceeding_id': 'R2011003', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M398/K465/398465770.PDF', 'published_date': '08/10/2021', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/BATJER/CPUC on 08/10/2021 Conf# 169447', 'doc_type': 'Scoping Ruling'}
# Content: September 1, 2021
# Reply testimony served
# September 10, 2021
# Opening briefs served and filed
# September 20, 2021
# Reply briefs served and filed
# September 27, 2021
# Proposed Decision issued
# October 29, 2021
# Final Decision
# November 18, 2021
#
# 4. Intervenor Compensation
# Supplemental Filing
# All intervenors that are seeking or will seek a claim for intervenor
# compensation at or above $50,000 are directed to serve and file, concurrently Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M398/K465/398465770.PDF
#
# Source: {'chunk_index': 8, 'document_id': '382426808', 'proceeding_id': 'A2009019', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M382/K426/382426808.PDF', 'published_date': '05/06/2021', 'year': 0, 'title': 'Response filed by Pacific Gas and Electric Company on 05/05/2021 Conf# 165526', 'doc_type': 'Response'}
# Content: 6 Del Monte Direct Testimony, p. 3.
# 7 PG&E Motion to Strike Testimony Submitted By Intervenor Thomas Del Monte, pp. 1-3. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M382/K426/382426808.PDF
#
# Source: {'chunk_index': 7, 'document_id': '409638365', 'proceeding_id': 'A2108010', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M409/K638/409638365.PDF', 'published_date': '09/24/2021', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/SHIROMA/CPUC on 09/24/2021 Conf# 171544', 'doc_type': 'Scoping Ruling'}
# Content: and served
# October 22, 2021
# Opening briefs, filed and served
# October 29, 2021
# Reply briefs, filed and served
# [matter submitted]
# November 5, 2021
# Proposed decision
# November 2021
# Schedule 2:  Proceeding Schedule With Evidentiary Hearings
# Intervenors’ prepared direct testimony,
# served
# October 1, 2021
# Prepared rebuttal testimony, served
# October 8, 2021
# List of Stipulated and Disputed Facts
# and Report of Meet and Confer, filed
# and served;
# Deadline for Motion for Evidentiary
# Hearing
# October 22, 2021 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M409/K638/409638365.PDF
#
# Source: {'chunk_index': 69, 'document_id': '385840299', 'proceeding_id': 'A2011001', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF', 'published_date': '06/01/2021', 'year': 0, 'title': 'Brief filed by The Utility Reform Network on 05/28/2021 Conf# 166422', 'doc_type': 'Brief'}
# Content: 59 Mailloux Intervenor Testimony (Exh. TURN-01-R) at p. 9.
# 60 Protest Reply at p. 16; Mailloux Intervenor Testimony (Exh. TURN-01-R) at p. 9 Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M385/K840/385840299.PDF
#
# Source: {'chunk_index': 91, 'document_id': '498802243', 'proceeding_id': 'A2203014', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K802/498802243.PDF', 'published_date': '11/14/2022', 'year': 0, 'title': 'Request filed by The Utility Reform Network on 11/14/2022 Conf# 187127', 'doc_type': 'Request'}
# Content: Revised March 2017
#
# 5
#
# intervenors and explore opportunities to coordinate and develop joint positions as
# appropriate. As a general matter, TURN does its best to minimize potential overlap in
# issues and to ensure that where such overlap occurs, each party is presenting a unique
# analysis.
#
# The party’s description of the nature and extent of the party’s planned participation in this
# proceeding (to the extent that it is possible to describe on the date this NOI is filed).
#
# TURN submitted a protest to the application, conducted initial discovery and submitted
# comments on the Proposed Decision. Had the application not been dismissed, TURN
# intended to attend the prehearing conference, conduct additional discovery, submit written
# testimony, participate in evidentiary hearings (if held), participate in settlement negotiations,
# submit post-hearing briefs, conduct ex parte meetings and comment on the Proposed
# Decision. Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M498/K802/498802243.PDF
#
# Source: {'chunk_index': 254, 'document_id': '526553960', 'proceeding_id': 'A2302018', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M526/K553/526553960.PDF', 'published_date': '03/01/2024', 'year': 0, 'title': 'Motion filed by CALIFORNIA COMMUNITY CHOICE ASSOCIATION on 02/23/2024 Conf# 203559', 'doc_type': 'Motion'}
# Content: A.23-06-002  COM/JR5/smt
# - 5 -
# Event
# Date
# Intervenors’ prepared direct testimony
# served
# December 15, 2023
# Status Report on Settlement Talks (if needed)
# February 17, 2024
# Rule 13.9 Meet and Confer Deadline
# March 8, 2024
# Status Conference on Need for Hearings
# March 11, 2024
# Evidentiary Hearings
# March 18, 2024
# Opening Briefs
# April 12, 2024
# Reply Briefs
# May 3, 2024
# Proposed Decision
# Third Quarter
# 2024
#
# The purpose of the March 11, 2024 status conference is to ascertain
# whether, pursuant to Rule 13.8(c), the parties stipulate to the receipt of prepared
# testimony into evidence without direct or cross examination or other need to
# convene an evidentiary hearing or, in the alternative, the parties’ resources,
# readiness and needs for the effective remote conduct of the evidentiary hearing,
# including estimates of time requested for cross-examination and identification of
# anticipated exhibits.
# The proceeding will stand submitted upon the filing of reply briefs, unless Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M526/K553/526553960.PDF
#
# Source: {'chunk_index': 8, 'document_id': '520648000', 'proceeding_id': 'A2306002', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K648/520648000.PDF', 'published_date': '10/31/2023', 'year': 0, 'title': 'Scoping Ruling filed by CMMR/JOHN REYNOLDS/ CPUC on 10/31/2023 Conf# 199069', 'doc_type': 'Scoping Ruling'}
# Content: A.23-06-002  COM/JR5/smt
# - 5 -
# Event
# Date
# Intervenors’ prepared direct testimony
# served
# December 15, 2023
# Status Report on Settlement Talks (if needed)
# February 17, 2024
# Rule 13.9 Meet and Confer Deadline
# March 8, 2024
# Status Conference on Need for Hearings
# March 11, 2024
# Evidentiary Hearings
# March 18, 2024
# Opening Briefs
# April 12, 2024
# Reply Briefs
# May 3, 2024
# Proposed Decision
# Third Quarter
# 2024
#
# The purpose of the March 11, 2024 status conference is to ascertain
# whether, pursuant to Rule 13.8(c), the parties stipulate to the receipt of prepared
# testimony into evidence without direct or cross examination or other need to
# convene an evidentiary hearing or, in the alternative, the parties’ resources,
# readiness and needs for the effective remote conduct of the evidentiary hearing,
# including estimates of time requested for cross-examination and identification of
# anticipated exhibits.
# The proceeding will stand submitted upon the filing of reply briefs, unless Document Link: https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K648/520648000.PDF

# %%
def create_proceeding_id_index():
    """Create a keyword index on proceeding_id field"""
    try:
        print("Creating index on proceeding_id field...")
        
        qdrant_client.create_payload_index(
            collection_name=DOCUMENT_COLLECTION,
            field_name="proceeding_id",
            field_schema="keyword"  # Best for exact string matches like IDs
        )
        
        print("✅ Index creation request submitted successfully!")
        print("⏳ Index is being built in the background...")
        
        return True
        
    except Exception as e:
        print(f"❌ Index creation failed: {e}")
        return False

# Create the index
create_proceeding_id_index()
# Out:
# Creating index on proceeding_id field...
# ✅ Index creation request submitted successfully!
# ⏳ Index is being built in the background...
# True
