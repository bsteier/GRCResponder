# %%
from pathlib import Path
import chromadb
from chromadb.utils.embedding_functions import SentenceTransformerEmbeddingFunction
from langgraph.graph import MessagesState, StateGraph
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage
from langgraph.prebuilt import ToolNode
from langgraph.graph import END
from langgraph.prebuilt import tools_condition
from langchain_core.documents import Document
from langchain.chat_models import init_chat_model
import time
import io
from contextlib import redirect_stdout
from datetime import datetime
from testing.response_eval_tools import set_api_key_from_path, initialize_evaluation_llm, evaluate_model_outputs_from_paths
from pathlib import Path
import json
from typing import List, Dict, Any
import uuid


set_api_key_from_path(Path('./testing/gemini-key'))

################# [ Validate GPU Available ] #################
import torch

# assert(torch.cuda.is_available())

##############################################################

chroma_path = "./test_db"
collection_name = 'multi_proceedings_test'
embedding_model_name = 'all-MiniLM-L6-v2'

client = chromadb.PersistentClient(path=chroma_path)
embedding_function = SentenceTransformerEmbeddingFunction(model_name=embedding_model_name)
collection = client.get_or_create_collection(name=collection_name, embedding_function=embedding_function)

llm = initialize_evaluation_llm()
# llm = init_chat_model("llama3.2:3b-instruct-q8_0", model_provider="ollama")

class ChatHistoryManager:
    def __init__(self, max_history_length=10):
        self.sessions = {}
        self.max_history_length = max_history_length

    def get_or_create_session(self, session_id: str) -> List:
        """Get or create a new chat session"""
        if session_id not in self.sessions:
            self.sessions[session_id] = []
        return self.sessions[session_id]

    def add_message(self, session_id: str, message) -> None:
        """Add a message to the chat history"""
        history = self.get_or_create_session(session_id)
        history.append(message)

        if len(history) > self.max_history_length * 2:  # Keep pairs of messages
            self.sessions[session_id] = history[-self.max_history_length*2:]

    def get_history(self, session_id: str) -> List:
        """Get the chat history for a session"""
        return self.get_or_create_session(session_id)

    def clear_history(self, session_id: str) -> None:
        """Clear the chat history for a session"""
        self.sessions[session_id] = []

    def save_history(self): # TODO: STORE HISTORY TO FILE
        pass

    def load_history(self): # TODO: LOAD HISTORY FROM FILE
        pass

chat_manager = ChatHistoryManager(max_history_length=15)

# Set up retrieval tool
@tool(response_format="content_and_artifact")
def retrieve(query: str, k: int = 8):
    """Retrieve information related to a query."""
    # Query ChromaDB directly
    results = collection.query(
        query_texts=[query],
        n_results=k,
    )

    # Format results for LangChain compatibility
    retrieved_docs = []
    for i in range(len(results['ids'][0])):
        doc_id = results['ids'][0][i]
        content = results['documents'][0][i]
        metadata = results['metadatas'][0][i] if results['metadatas'][0] else {}

        doc = Document(page_content=content, metadata=metadata)
        retrieved_docs.append(doc)

    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\n" f"Content: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# Build the graph
def build_graph():
    graph_builder = StateGraph(MessagesState)

    def force_retrieval(state: MessagesState):
        """Always call the retrieve tool first."""
        # Get the latest human message
        latest_human_message = None
        for message in reversed(state["messages"]):
            if message.type == "human":
                latest_human_message = message
                break

        if latest_human_message is None:
            return {"messages": state["messages"]}

        # Create a tool call for retrieval with a properly formatted tool_calls attribute
        tool_call_id = str(uuid.uuid4())
        retrieval_message = AIMessage(
            content="I'll search for relevant information to answer your question.",
            tool_calls=[{
                "name": "retrieve",
                "id": tool_call_id,
                "args": {"query": latest_human_message.content, "k": 8}
            }]
        )

        return {
            "messages": state["messages"] + [retrieval_message]
        }

    # Execute the retrieval
    tools = ToolNode([retrieve])

    # Generate a response using the retrieved content
    def generate(state: MessagesState):
        """Generate answer."""
        # Get generated ToolMessages
        recent_tool_messages = []
        for message in reversed(state["messages"]):
            if message.type == "tool":
                recent_tool_messages.append(message)
            else:
                break
        tool_messages = recent_tool_messages[::-1]

        # Format into prompt
        docs_content = "\n\n".join(doc.content for doc in tool_messages)
        system_message_content = (
            """<SYSTEM>
                You are "GRC Regulatory Analysis Expert," an AI assistant specialized in California GRC proceedings.
                </SYSTEM>

                <INFORMATION SOURCES>
                Base your responses EXCLUSIVELY on:
                1. Retrieved documents (HIGHEST PRIORITY)
                2. User-provided context in the current session

                The retrieval system has already provided you with the most relevant information.
                Always cite your sources with specific references (e.g., "PG&E 2023 GRC, Exhibit 4, p.15").
                </INFORMATION SOURCES>

                <IDENTITY AND EXPERTISE>
                You are a regulatory specialist focused exclusively on California General Rate Case (GRC) proceedings and related CPUC filings with expertise in:
                - Rate case applications and testimony
                - Revenue requirement analysis
                - Procedural requirements and timelines
                - CPUC decisions and precedents
                </IDENTITY AND EXPERTISE>

                <RESPONSE FORMAT>
                Structure your responses with:
                1. Concise summary of key findings
                2. Detailed analysis with multiple supporting citations
                3. Relevant regulatory background and historical context
                4. Discussion of practical implications
                5. Complete citations formatted as markdown links

                Use markdown formatting (headers, tables, bullets) to enhance readability.
                </RESPONSE FORMAT>

                <PROFESSIONAL TONE>
                Maintain a voice that is:
                - Authoritative yet accessible
                - Technically precise
                - Thorough and explanatory
                - Objective in regulatory interpretation
                </PROFESSIONAL TONE>

                <ACCURACY REQUIREMENTS>
                - Never invent citations, docket numbers, or proceedings
                - Clearly indicate when information is missing or insufficient
                - Present multiple interpretations when guidance is ambiguous
                - Quote directly from sources for critical regulatory language
                </ACCURACY REQUIREMENTS>

                <SCOPE LIMITATIONS>
                Address only topics related to California GRC proceedings and CPUC regulatory matters.
                For other topics, politely explain they fall outside your expertise.
                </SCOPE LIMITATIONS>

                Always end responses with: "Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?"
                """
            f"Document Context: {docs_content}"
        )
        # Get conversation messages excluding tool messages and tool-calling AI messages
        conversation_messages = []
        for message in state["messages"]:
            if message.type == "human":
                conversation_messages.append(message)
            elif message.type == "ai" and not getattr(message, "tool_calls", None):
                conversation_messages.append(message)

        prompt = [SystemMessage(content=system_message_content)] + conversation_messages

        # Run llm
        response = llm.invoke(prompt)
        return {"messages": [response]}

    # Set up the graph connections
    graph_builder.add_node("force_retrieval", force_retrieval)
    graph_builder.add_node("tools", tools)
    graph_builder.add_node("generate", generate)

    graph_builder.set_entry_point("force_retrieval")
    graph_builder.add_edge("force_retrieval", "tools")
    graph_builder.add_edge("tools", "generate")
    graph_builder.add_edge("generate", END)

    return graph_builder.compile()

# Initialize the graph
graph = build_graph()

def process_query(query: str, session_id: str, retrieval_k: int = 8) -> Dict[str, Any]:
    # Set the K value for this query
    retrieve.bind(k=retrieval_k)

    start_time = time.time()

    # Get chat history
    history = chat_manager.get_history(session_id)

    # Format messages
    messages = []
    for msg in history:
        if msg["role"] == "user":
            messages.append(HumanMessage(content=msg["content"]))
        elif msg["role"] == "assistant":
            messages.append(AIMessage(content=msg["content"]))
        elif msg["role"] == "tool":
            # Create a tool message with appropriate attributes and a tool_call_id
            messages.append(ToolMessage(
                content=msg["content"],
                name=msg.get("tool_name", "retrieve"),
                tool_call_id=msg.get("tool_call_id", str(uuid.uuid4()))
            ))

    # Add the current query
    messages.append(HumanMessage(content=query))

    # Run the graph
    result = None
    tool_outputs = []

    # Process the query through the graph
    with io.StringIO() as buf, redirect_stdout(buf):
        for step in graph.stream(
            {"messages": messages},
            stream_mode="values",
        ):
            last_message = step["messages"][-1]
            if last_message.type == "tool":
                tool_outputs.append({
                    "tool_name": getattr(last_message, "name", "retrieve"),
                    "content": last_message.content
                })
            if last_message.type == "ai" and not getattr(last_message, "tool_calls", None):
                result = last_message.content

        debug_output = buf.getvalue()

    end_time = time.time()
    elapsed_time = end_time - start_time

    # Add messages to chat history
    chat_manager.add_message(session_id, {"role": "user", "content": query})

    # Add tool messages to history
    for tool_output in tool_outputs:
        chat_manager.add_message(session_id, {
            "role": "tool",
            "content": tool_output["content"],
            "tool_name": tool_output.get("tool_name", "retrieve")
        })

    if result:
        chat_manager.add_message(session_id, {"role": "assistant", "content": result})

    response = {
        "result": result,
        "processing_time": elapsed_time,
        "tool_outputs": tool_outputs,
        "session_id": session_id,
        "timestamp": datetime.now().isoformat(),
        "debug_output": debug_output if debug_output else None
    }

    return response

def get_chat_history(session_id: str):
    return chat_manager.get_history(session_id)

def clear_chat_history(session_id: str):
    chat_manager.clear_history(session_id)
    return {"status": "success", "message": f"Chat history cleared for session {session_id}"}

def generate_session_id():
    return str(uuid.uuid4())

# %%
class LLMChatSession():
    def __init__(self, console_mode = False) -> None:
        self.session_id = generate_session_id()
        self.console_mode = console_mode
        self.timestamp_queue = [] # New ones get inserted at end (using append); remove by deleting element 0
        self.max_queries = 15
        # When query, update message queue; if still at limit then stop, otherwise
    def query(self, user_input: str, k = None) -> Dict[str, Any]:
        # if self.is_under_limit():
        if k is None:
            response = process_query(user_input, self.session_id)
        else:
            response = process_query(user_input, self.session_id, k)


        if self.console_mode:
            print(f"\nGRC Assistant: {response['result']}")
            print(f"\nProcessing time: {response['processing_time']:.2f} seconds")
        self.timestamp_queue.append(datetime.fromisoformat(response['timestamp']))
        return {'result': response['result'],
                'messages_remaining': self.max_queries - sum([(datetime.now() - timestamp).seconds < 60 for timestamp in self.timestamp_queue]),
                'sec_remaining': [60 - (datetime.now() - timestamp).seconds for timestamp in self.timestamp_queue],
                'tool_outputs': response['tool_outputs'],
                }
        # else:
        #     raise ConnectionRefusedError(f"Rate Limit Exceeded | Try again in {60 - (datetime.now() - self.timestamp_queue[0]).seconds} seconds")

    def is_under_limit(self) -> bool:
        while len(self.timestamp_queue) > 0:
            if (datetime.now() - self.timestamp_queue[0]).seconds > 60: # Is over 60 sec time limit
                del self.timestamp_queue[0]
                continue
            else:
                break
        return len(self.timestamp_queue) < 15

    def hist_free_query(self, user_input: str) -> Dict[str, Any]:
        clear_chat_history(self.session_id)
        out = self.query(user_input)
        clear_chat_history(self.session_id)
        return out

# %%
results = collection.query(
        query_texts=["AAJKNKFEJ"],
        n_results=3,
    )

# %%
results
# Out:
# {'ids': [['405059555_898', '405059555_1331', '405059555_393']],
#  'embeddings': None,
#  'documents': [['AABBCCDDEEFF(cid:8)(cid:8)BBGGEEDDEEGGEEHHII(cid:8)(cid:8)FFJJKKKKEEIIIIEEJJLLMM(cid:8)(cid:8)IIGGNNGGHH(cid:8)(cid:8)JJOO(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\nIINNLL(cid:8)(cid:8)OOPPNNLLFFEEIIFFJJMM(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\n00112233224411556677(cid:9)(cid:9)889966::22112266;;22\n<<==77==>>??(cid:9)(cid:9)@@AABB(cid:9)(cid:9)CCAACCDD ZC\n(cid:23)(cid:30)(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:2)(cid:9)(cid:11)(cid:15)(cid:3)(cid:9)(cid:15)(cid:16)(cid:17)(cid:7)(cid:18)(cid:16)(cid:4)(cid:2)\n(cid:23)’(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:19)(cid:19)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:20)(cid:2)',
#    'OOTTRR(cid:2)(cid:2)UUVVTTRRLLKKOOLLPPSS(cid:2)(cid:2)LLTTJJKKUUPPVVRRKKTT\n22334455446633778899(cid:8)(cid:8)::;;88<<44334488==44\n>>??99??@@AA(cid:8)(cid:8)BBCCDD(cid:8)(cid:8)EECCEEFF FBa\n(cid:17)W(cid:8)(cid:8)(cid:8)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:6)(cid:2)(cid:7)(cid:8)(cid:9)(cid:4)(cid:10)(cid:11)(cid:12)(cid:13)(cid:4)(cid:3)(cid:14)(cid:8)(cid:15)(cid:5)(cid:2)(cid:7)(cid:4)(cid:3)(cid:4)(cid:5)(cid:6)(cid:16)(cid:17)(cid:8)(cid:18)(cid:11)(cid:8)(cid:13)(cid:19)(cid:20)(cid:20)(cid:5)(cid:12)(cid:3)(cid:8)(cid:3)(cid:21)(cid:11)\n(cid:17)X(cid:8)(cid:8)(cid:8)(cid:22)(cid:5)(cid:23)(cid:23)(cid:11)(cid:6)(cid:3)(cid:13)(cid:8)(cid:2)(cid:7)(cid:12)(cid:11)(cid:2)(cid:24)(cid:14)(cid:8)(cid:23)(cid:2)(cid:24)(cid:11)(cid:8)(cid:2)(cid:6)(cid:24)(cid:8)(cid:21)(cid:2)(cid:10)(cid:11)(cid:8)(cid:6)(cid:5)(cid:8)(cid:25)(cid:19)(cid:12)(cid:3)(cid:21)(cid:11)(cid:12)',
#    'FFGGHHIIJJKK(cid:3)(cid:3)GGLLJJIIJJLLJJMMNN(cid:3)(cid:3)KKOOPPPPJJNNNNJJOOQQRR(cid:3)(cid:3)NNLLSSLLMM(cid:3)(cid:3)OOTT(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\nNNSSQQ(cid:3)(cid:3)TTUUSSQQKKJJNNKKOORR(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\n,,--..//..00--112233(cid:12)(cid:12)44552266..--..2277..\n88993399::;;(cid:12)(cid:12)<<==>>(cid:12)(cid:12)??==??@@ [@\n(cid:21)Q(cid:12)(cid:12)(cid:12)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:5)(cid:2)(cid:6)(cid:7)(cid:8)(cid:9)(cid:10)(cid:4)(cid:6)(cid:11)(cid:12)(cid:4)(cid:6)(cid:12)(cid:8)(cid:12)(cid:13)(cid:14)(cid:8)(cid:6)(cid:12)(cid:9)(cid:15)(cid:8)(cid:9)(cid:12)(cid:3)(cid:4)(cid:16)(cid:14)(cid:7)(cid:12)(cid:17)(cid:2)(cid:12)(cid:5)(cid:4)(cid:4)(cid:9)']],
#  'uris': None,
#  'data': None,
#  'metadatas': [[{'chunk_index': 898,
#     'document_id': '405059555',
#     'proceeding_id': 'A2106021',
#     'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#     'text': 'AABBCCDDEEFF(cid:8)(cid:8)BBGGEEDDEEGGEEHHII(cid:8)(cid:8)FFJJKKKKEEIIIIEEJJLLMM(cid:8)(cid:8)IIGGNNGGHH(cid:8)(cid:8)JJOO(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\nIINNLL(cid:8)(cid:8)OOPPNNLLFFEEIIFFJJMM(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\n00112233224411556677(cid:9)(cid:9)889966::22112266;;22\n<<==77==>>??(cid:9)(cid:9)@@AABB(cid:9)(cid:9)CCAACCDD ZC\n(cid:23)(cid:30)(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:2)(cid:9)(cid:11)(cid:15)(cid:3)(cid:9)(cid:15)(cid:16)(cid:17)(cid:7)(cid:18)(cid:16)(cid:4)(cid:2)\n(cid:23)’(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:19)(cid:19)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:20)(cid:2)'},
#    {'chunk_index': 1331,
#     'document_id': '405059555',
#     'proceeding_id': 'A2106021',
#     'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#     'text': 'OOTTRR(cid:2)(cid:2)UUVVTTRRLLKKOOLLPPSS(cid:2)(cid:2)LLTTJJKKUUPPVVRRKKTT\n22334455446633778899(cid:8)(cid:8)::;;88<<44334488==44\n>>??99??@@AA(cid:8)(cid:8)BBCCDD(cid:8)(cid:8)EECCEEFF FBa\n(cid:17)W(cid:8)(cid:8)(cid:8)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:6)(cid:2)(cid:7)(cid:8)(cid:9)(cid:4)(cid:10)(cid:11)(cid:12)(cid:13)(cid:4)(cid:3)(cid:14)(cid:8)(cid:15)(cid:5)(cid:2)(cid:7)(cid:4)(cid:3)(cid:4)(cid:5)(cid:6)(cid:16)(cid:17)(cid:8)(cid:18)(cid:11)(cid:8)(cid:13)(cid:19)(cid:20)(cid:20)(cid:5)(cid:12)(cid:3)(cid:8)(cid:3)(cid:21)(cid:11)\n(cid:17)X(cid:8)(cid:8)(cid:8)(cid:22)(cid:5)(cid:23)(cid:23)(cid:11)(cid:6)(cid:3)(cid:13)(cid:8)(cid:2)(cid:7)(cid:12)(cid:11)(cid:2)(cid:24)(cid:14)(cid:8)(cid:23)(cid:2)(cid:24)(cid:11)(cid:8)(cid:2)(cid:6)(cid:24)(cid:8)(cid:21)(cid:2)(cid:10)(cid:11)(cid:8)(cid:6)(cid:5)(cid:8)(cid:25)(cid:19)(cid:12)(cid:3)(cid:21)(cid:11)(cid:12)'},
#    {'chunk_index': 393,
#     'document_id': '405059555',
#     'proceeding_id': 'A2106021',
#     'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#     'text': 'FFGGHHIIJJKK(cid:3)(cid:3)GGLLJJIIJJLLJJMMNN(cid:3)(cid:3)KKOOPPPPJJNNNNJJOOQQRR(cid:3)(cid:3)NNLLSSLLMM(cid:3)(cid:3)OOTT(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\nNNSSQQ(cid:3)(cid:3)TTUUSSQQKKJJNNKKOORR(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\n,,--..//..00--112233(cid:12)(cid:12)44552266..--..2277..\n88993399::;;(cid:12)(cid:12)<<==>>(cid:12)(cid:12)??==??@@ [@\n(cid:21)Q(cid:12)(cid:12)(cid:12)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:5)(cid:2)(cid:6)(cid:7)(cid:8)(cid:9)(cid:10)(cid:4)(cid:6)(cid:11)(cid:12)(cid:4)(cid:6)(cid:12)(cid:8)(cid:12)(cid:13)(cid:14)(cid:8)(cid:6)(cid:12)(cid:9)(cid:15)(cid:8)(cid:9)(cid:12)(cid:3)(cid:4)(cid:16)(cid:14)(cid:7)(cid:12)(cid:17)(cid:2)(cid:12)(cid:5)(cid:4)(cid:4)(cid:9)'}]],
#  'distances': [[1.3253289461135864, 1.3262158632278442, 1.3285788297653198]],
#  'included': [<IncludeEnum.distances: 'distances'>,
#   <IncludeEnum.documents: 'documents'>,
#   <IncludeEnum.metadatas: 'metadatas'>]}

# %%
results['metadatas'][0]
Document(page_content=content, metadata=metadata)
# Out:
# [{'chunk_index': 898,
#   'document_id': '405059555',
#   'proceeding_id': 'A2106021',
#   'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#   'text': 'AABBCCDDEEFF(cid:8)(cid:8)BBGGEEDDEEGGEEHHII(cid:8)(cid:8)FFJJKKKKEEIIIIEEJJLLMM(cid:8)(cid:8)IIGGNNGGHH(cid:8)(cid:8)JJOO(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\nIINNLL(cid:8)(cid:8)OOPPNNLLFFEEIIFFJJMM(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\n00112233224411556677(cid:9)(cid:9)889966::22112266;;22\n<<==77==>>??(cid:9)(cid:9)@@AABB(cid:9)(cid:9)CCAACCDD ZC\n(cid:23)(cid:30)(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:2)(cid:9)(cid:11)(cid:15)(cid:3)(cid:9)(cid:15)(cid:16)(cid:17)(cid:7)(cid:18)(cid:16)(cid:4)(cid:2)\n(cid:23)’(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:19)(cid:19)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:20)(cid:2)'},
#  {'chunk_index': 1331,
#   'document_id': '405059555',
#   'proceeding_id': 'A2106021',
#   'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#   'text': 'OOTTRR(cid:2)(cid:2)UUVVTTRRLLKKOOLLPPSS(cid:2)(cid:2)LLTTJJKKUUPPVVRRKKTT\n22334455446633778899(cid:8)(cid:8)::;;88<<44334488==44\n>>??99??@@AA(cid:8)(cid:8)BBCCDD(cid:8)(cid:8)EECCEEFF FBa\n(cid:17)W(cid:8)(cid:8)(cid:8)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:6)(cid:2)(cid:7)(cid:8)(cid:9)(cid:4)(cid:10)(cid:11)(cid:12)(cid:13)(cid:4)(cid:3)(cid:14)(cid:8)(cid:15)(cid:5)(cid:2)(cid:7)(cid:4)(cid:3)(cid:4)(cid:5)(cid:6)(cid:16)(cid:17)(cid:8)(cid:18)(cid:11)(cid:8)(cid:13)(cid:19)(cid:20)(cid:20)(cid:5)(cid:12)(cid:3)(cid:8)(cid:3)(cid:21)(cid:11)\n(cid:17)X(cid:8)(cid:8)(cid:8)(cid:22)(cid:5)(cid:23)(cid:23)(cid:11)(cid:6)(cid:3)(cid:13)(cid:8)(cid:2)(cid:7)(cid:12)(cid:11)(cid:2)(cid:24)(cid:14)(cid:8)(cid:23)(cid:2)(cid:24)(cid:11)(cid:8)(cid:2)(cid:6)(cid:24)(cid:8)(cid:21)(cid:2)(cid:10)(cid:11)(cid:8)(cid:6)(cid:5)(cid:8)(cid:25)(cid:19)(cid:12)(cid:3)(cid:21)(cid:11)(cid:12)'},
#  {'chunk_index': 393,
#   'document_id': '405059555',
#   'proceeding_id': 'A2106021',
#   'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF',
#   'text': 'FFGGHHIIJJKK(cid:3)(cid:3)GGLLJJIIJJLLJJMMNN(cid:3)(cid:3)KKOOPPPPJJNNNNJJOOQQRR(cid:3)(cid:3)NNLLSSLLMM(cid:3)(cid:3)OOTT(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\nNNSSQQ(cid:3)(cid:3)TTUUSSQQKKJJNNKKOORR(cid:3)(cid:3)KKSSIIJJTTOOUUQQJJSS\n,,--..//..00--112233(cid:12)(cid:12)44552266..--..2277..\n88993399::;;(cid:12)(cid:12)<<==>>(cid:12)(cid:12)??==??@@ [@\n(cid:21)Q(cid:12)(cid:12)(cid:12)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:5)(cid:2)(cid:6)(cid:7)(cid:8)(cid:9)(cid:10)(cid:4)(cid:6)(cid:11)(cid:12)(cid:4)(cid:6)(cid:12)(cid:8)(cid:12)(cid:13)(cid:14)(cid:8)(cid:6)(cid:12)(cid:9)(cid:15)(cid:8)(cid:9)(cid:12)(cid:3)(cid:4)(cid:16)(cid:14)(cid:7)(cid:12)(cid:17)(cid:2)(cid:12)(cid:5)(cid:4)(cid:4)(cid:9)'}]

# %%
retrieved_docs = []
for i in range(len(results['ids'][0])):
    doc_id = results['ids'][0][i]
    content = results['documents'][0][i]
    metadata = results['metadatas'][0][i] if results['metadatas'][0] else {}

    doc = Document(page_content=content, metadata=metadata)
    retrieved_docs.append(doc)

serialized = "\n\n".join(
    (f"Source: {doc.metadata}\n" f"Content: {doc.page_content}")
    for doc in retrieved_docs
)

# %%
serialized
# Out:
# "Source: {'chunk_index': 898, 'document_id': '405059555', 'proceeding_id': 'A2106021', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF', 'text': 'AABBCCDDEEFF(cid:8)(cid:8)BBGGEEDDEEGGEEHHII(cid:8)(cid:8)FFJJKKKKEEIIIIEEJJLLMM(cid:8)(cid:8)IIGGNNGGHH(cid:8)(cid:8)JJOO(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\\nIINNLL(cid:8)(cid:8)OOPPNNLLFFEEIIFFJJMM(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\\n00112233224411556677(cid:9)(cid:9)889966::22112266;;22\\n<<==77==>>??(cid:9)(cid:9)@@AABB(cid:9)(cid:9)CCAACCDD ZC\\n(cid:23)(cid:30)(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:2)(cid:9)(cid:11)(cid:15)(cid:3)(cid:9)(cid:15)(cid:16)(cid:17)(cid:7)(cid:18)(cid:16)(cid:4)(cid:2)\\n(cid:23)’(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:19)(cid:19)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:20)(cid:2)'}\nContent: AABBCCDDEEFF(cid:8)(cid:8)BBGGEEDDEEGGEEHHII(cid:8)(cid:8)FFJJKKKKEEIIIIEEJJLLMM(cid:8)(cid:8)IIGGNNGGHH(cid:8)(cid:8)JJOO(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\nIINNLL(cid:8)(cid:8)OOPPNNLLFFEEIIFFJJMM(cid:8)(cid:8)FFNNDDEEOOJJPPLLEENN\n00112233224411556677(cid:9)(cid:9)889966::22112266;;22\n<<==77==>>??(cid:9)(cid:9)@@AABB(cid:9)(cid:9)CCAACCDD ZC\n(cid:23)(cid:30)(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:2)(cid:9)(cid:11)(cid:15)(cid:3)(cid:9)(cid:15)(cid:16)(cid:17)(cid:7)(cid:18)(cid:16)(cid:4)(cid:2)\n(cid:23)’(cid:9)(cid:9)(cid:9)(cid:0)(cid:2)(cid:0)(cid:3)(cid:4)(cid:5)(cid:6)(cid:7)(cid:8)(cid:0)(cid:9)(cid:5)(cid:10)(cid:10)(cid:3)(cid:8)(cid:6)(cid:11)(cid:12)(cid:13)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:19)(cid:19)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:11)(cid:14)(cid:5)(cid:11)(cid:9)(cid:20)(cid:2)\n\nSource: {'chunk_index': 1331, 'document_id': '405059555', 'proceeding_id': 'A2106021', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M405/K059/405059555.PDF', 'text': 'OOTTRR(cid:2)(cid:2)UUVVTTRRLLKKOOLLPPSS(cid:2)(cid:2)LLTTJJKKUUPPVVRRKKTT\\n22334455446633778899(cid:8)(cid:8)::;;88<<44334488==44\\n>>??99??@@AA(cid:8)(cid:8)BBCCDD(cid:8)(cid:8)EECCEEFF FBa\\n(cid:17)W(cid:8)(cid:8)(cid:8)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:6)(cid:2)(cid:7)(cid:8)(cid:9)(cid:4)(cid:10)(cid:11)(cid:12)(cid:13)(cid:4)(cid:3)(cid:14)(cid:8)(cid:15)(cid:5)(cid:2)(cid:7)(cid:4)(cid:3)(cid:4)(cid:5)(cid:6)(cid:16)(cid:17)(cid:8)(cid:18)(cid:11)(cid:8)(cid:13)(cid:19)(cid:20)(cid:20)(cid:5)(cid:12)(cid:3)(cid:8)(cid:3)(cid:21)(cid:11)\\n(cid:17)X(cid:8)(cid:8)(cid:8)(cid:22)(cid:5)(cid:23)(cid:23)(cid:11)(cid:6)(cid:3)(cid:13)(cid:8)(cid:2)(cid:7)(cid:12)(cid:11)(cid:2)(cid:24)(cid:14)(cid:8)(cid:23)(cid:2)(cid:24)(cid:11)(cid:8)(cid:2)(cid:6)(cid:24)(cid:8)(cid:21)(cid:2)(cid:10)(cid:11)(cid:8)(cid:6)(cid:5)(cid:8)(cid:25)(cid:19)(cid:12)(cid:3)(cid:21)(cid:11)(cid:12)'}\nContent: OOTTRR(cid:2)(cid:2)UUVVTTRRLLKKOOLLPPSS(cid:2)(cid:2)LLTTJJKKUUPPVVRRKKTT\n22334455446633778899(cid:8)(cid:8)::;;88<<44334488==44\n>>??99??@@AA(cid:8)(cid:8)BBCCDD(cid:8)(cid:8)EECCEEFF FBa\n(cid:17)W(cid:8)(cid:8)(cid:8)(cid:0)(cid:2)(cid:3)(cid:4)(cid:5)(cid:6)(cid:2)(cid:7)(cid:8)(cid:9)(cid:4)(cid:10)(cid:11)(cid:12)(cid:13)(cid:4)(cid:3)(cid:14)(cid:8)(cid:15)(cid:5)(cid:2)(cid:7)(cid:4)(cid:3)(cid:4)(cid:5)(cid:6)(cid:16)(cid:17)(cid:8)(cid:18)(cid:11)(cid:8)(cid:13)(cid:19)(cid:20)(cid:20)(cid:5)(cid:12)(cid:3)(cid:8)(cid:3)(cid:21)(cid:11)\n(cid:17)X(cid:8)(cid:8)(cid:8)(cid:22)(cid:5)(cid:23)(cid:23)(cid:11)(cid:6)(cid:3)(cid:13)(cid:8)(cid:2)(cid:7)(cid:12)(cid:11)(cid:2)(cid:24)(ci ...

# %%
results['distances']
# Out:
# [[1.3253289461135864, 1.3262158632278442, 1.3285788297653198]]

# %%
llm_session = LLMChatSession(console_mode=True)

# %%
llm_session.query("Hey, how's it going?")
# Out:
# GRC Assistant: I am doing well. How can I help you today?
#
# Processing time: 0.38 seconds
# {'result': 'I am doing well. How can I help you today?',
#  'messages_remaining': 14,
#  'sec_remaining': [-45, -39, -22, 60],
#  'tool_outputs': []}

# %%
result = llm_session.query("What information do you vae on PG&E from your retrival")
# Out:
# GRC Assistant: I can provide information on PG&E from the documents I have access to. To give you the most relevant information, could you please specify what you're interested in? For example, are you interested in:
#
# *   PG&E's 2023 General Rate Case (GRC) application?
# *   PG&E's Short-Term Incentive Plan (STIP)?
# *   PG&E's wildfire risk mitigation work?
# *   PG&E's Non-Tariffed Products and Services?
# *   PG&E's plans for electrifying vehicles?
# *   Other topics related to PG&E?
#
# Once you let me know the specific area you're interested in, I can provide a detailed summary with supporting citations.
#
# Processing time: 2.12 seconds

# %%
llm_session.query("I am interested learning more about the Non-Tariffed Products and Services")
# Out:
# GRC Assistant: Okay, I can help you with information regarding PG&E's Non-Tariffed Products and Services (NTP&S) based on the documents I have.
#
# **Overview of PG&E's Non-Tariffed Products and Services**
#
# PG&E offers Non-Tariffed Products and Services (NTP&S) primarily using underutilized PG&E assets or capacity to generate incremental revenues by marketing products and services to third parties (PG&E GRC A.21-06-021, [Ex-06 at 2-17](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)). These services are consistent with the Affiliate Transaction Rules, Rule VII, adopted by the Commission in D.06-12-029 (PG&E GRC A.21-06-021, [Ex-06 at 2-17](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)).
#
# **Examples of Non-Tariffed Products and Services**
#
# Typical transactions under this program include (PG&E GRC A.21-06-021, [Ex-06](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)):
#
# *   Joint use pole attachment arrangements
# *   Short-term use of conference facilities by third-parties
# *   Customer emergency transformer loans
#
# **Financial Aspects and Regulatory Oversight**
#
# PG&E requested an expense forecast for 2023 of $49.851 million for the New Revenue Development Department’s provision of Non-Tariffed Products and Services (NTP&S) (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)). PG&E's forecasted revenues for 2023 were $60.5 million (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).
#
# PG&E presents minimal information about the utility assets relied upon and other financial aspects of its Non-Tariffed Products and Services (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)). PG&E states that its request of $49.851 million supports “PG&E’s efforts to offer additional services [non-utility services] with existing assets [utility assets] to generate revenue, which reduces the costs of service in customer rates” (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).
#
# Most of the information provided about profits and expenses for Non-Tariffed Products and Services is provided by PG&E annually pursuant to D.97-12-088, as modified by D.06-12-029, and Rule VII.H of the Affiliate Transactions Rules (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)).
#
# **Concerns and Lack of Transparency**
#
# It has been noted that details regarding how PG&E implements a reduction “in cost of service in customer rates” are not provided (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)). The amount of overall financial support provided by shareholders (who share in the profits) is particularly difficult to discern from the information provided by PG&E (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)). While PG&E forecasts profits, it does not provide evidence in the form of specific business transactions or executed contracts to support its forecast of actual profits during the rate case period on a forward-looking basis (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 8.20 seconds
# {'result': "Okay, I can help you with information regarding PG&E's Non-Tariffed Products and Services (NTP&S) based on the documents I have.\n\n**Overview of PG&E's Non-Tariffed Products and Services**\n\nPG&E offers Non-Tariffed Products and Services (NTP&S) primarily using underutilized PG&E assets or capacity to generate incremental revenues by marketing products and services to third parties (PG&E GRC A.21-06-021, [Ex-06 at 2-17](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)). These services are consistent with the Affiliate Transaction Rules, Rule VII, adopted by the Commission in D.06-12-029 (PG&E GRC A.21-06-021, [Ex-06 at 2-17](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)).\n\n**Examples of Non-Tariffed Products and Services**\n\nTypical transactions under this program include (PG&E GRC A.21-06-021, [Ex-06](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF)):\n\n*   Joint use pole attachment arrangements\n*   Short-term use of conference facilities by third-parties\n*   Customer emergency transformer loans\n\n**Financial Aspects and Regulatory Oversight**\n\nPG&E requested an expense forecast for 2023 of $49.851 million for the New Revenue Development Department’s provision of Non-Tariffed Products and Services (NTP&S) (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)). PG&E's forecasted revenues for 2023 were $60.5 million (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).\n\nPG&E presents minimal information about the utility assets relied upon and other financial aspects of its Non-Tariffed Products and Services (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)). PG&E states that its request of $49.851 million supports “PG&E’s efforts to offer additional services [non-utility services] with existing assets [utility assets] to generate revenue, which reduces the costs of service in customer rates” (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).\n\nMost of the information provided about profits and expenses for Non-Tariffed Products and Services is provided by PG&E annually pursuant to D.97-12-088, as modified by D.06-12-029, and Rule VII.H of the Affiliate Transactions Rules (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)).\n\n**Concerns and Lack of Transparency**\n\nIt has been noted that details regarding how PG&E implements a reduction “in cost of service in customer rates” are not provided (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)). The amount of overall financial support provided by shareholders (who share in the profits) is particularly difficult to discern from the information provided by PG&E (PG&E GRC A.21-06-021, [520526938.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF)). While PG&E forecasts profits, it does not provide evidence in the form of specific business transactions or executed contracts to support its forecast of actual profits during the rate case period on a forward-looking basis (PG&E GRC A.21-06-021, [520114360.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF)).\n\nWould you like me to explore any aspect of this response in greater depth or address related regulatory considerations?",
#  'messages_remaining': 12,
#  'sec_remaining': [-59, -53, -35, 47, 50, 60],
#  'tool_outputs': [{'tool_name': 'retrieve',
#    'content': "Source: {'chunk_index': 271, 'document_id': '520526938', 'proceeding_id': 'A2106021', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF', 'text': '255. Further dDetails regarding Non-Tariffed Products and Services, such as\\nhow PG&E implements a reduction “in cost of service in customer rates,” are not\\nprovided.\\n256. Most of the iInformation provided about profits and expense for Non-\\nTariffed Products and Services is provided by PG&E annually pursuant to D.97-12-\\n088, as modified by D.06-12-029, and Rule VII.H of the Affiliate Transactions Rules.\\nTwenty-Fifth Periodic Report on Non-Tariffed Products and Services, dated August 31,\\n2021, where PG&E shows costs and allocated profits for 2020 but a number of aspects\\nof the program are unclear, for example, the amount of profits allocated to\\nshareholders\\n257. Regarding Non-Tariffed Products and Services, the amount of\\noverall financial support provided by shareholders (who share in the profits) is\\nparticularly difficult to discern from the information provided by PG&E.\\nB-13\\nA.21-06-021 COM/JR5/nd3 ALTERNATE PROPOSED DECISION'}\nContent: 255. Further dDetails regarding Non-Tariffed Products and Services, such as\nhow PG&E implements a reduction “in cost of service in customer rates,” are not\nprovided.\n256. Most of the iInformation provided about profits and expense for Non-\nTariffed Products and Services is provided by PG&E annually pursuant to D.97-12-\n088, as modified by D.06-12-029, and Rule VII.H of the Affiliate Transactions Rules.\nTwenty-Fifth Periodic Report on Non-Tariffed Products and Services, dated August 31,\n2021, where PG&E shows costs and allocated profits for 2020 but a number of aspects\nof the program are unclear, for example, the amount of profits allocated to\nshareholders\n257. Regarding Non-Tariffed Products and Services, the amount of\noverall financial support provided by shareholders (who share in the profits) is\nparticularly difficult to discern from the information provided by PG&E.\nB-13\nA.21-06-021 COM/JR5/nd3 ALTERNATE PROPOSED DECISION\n\nSource: {'chunk_index': 184, 'document_id': '520526938', 'proceeding_id': 'A2106021', 'source_url': 'https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K526/520526938.PDF', 'text': 'rates.”\\n267. Further Details regarding Non-Tariffed Products and Services, such\\nas how PG&E implements a reduction “in cost of service in customer rates,” are\\nnot provided.\\n268. Most of the iInformation provided about profits and expense for\\nNon- Tariffed Products and Services is provided by PG&E annually pursuant to\\nD.97-12-088, as modified by D.06-12-029, and Rule VII.H of the Affiliate\\nTransactions Rules. Twenty-Fifth Periodic Report on Non-Tariffed Products and\\nServices, dated August 31, 2021, where PG&E shows costs and allocated profits\\nfor 2020 but a number of aspects of the program are unclear, for example, the\\namount of profits allocated to shareholders\\n269. Regarding Non-Tariffed Products and Services, the amount of\\noverall financial support provided by shareholders (who share in the\\nprofits) is particularly difficult to discern from the information provided by\\nPG&E.\\n269A. Forecasted Other Operating Revenues associated with Non-Tariffed'}\nContent: rates.”\n267. Further Details regarding Non-Tariffed Products and Services, such\nas how PG&E implements a reduction “in cost of service in customer rates,” are\nnot provided.\n268. Most of the iInformation provided about profits and expense for\nNon- Tariffed Products and Services is provided by PG&E annually pursuant to\nD.97-12-088, as modified by D.06-12-029, and Rule VII.H of the Affiliate\nTransactions Rules. Twenty-Fifth Periodic Report on Non-Tariffed Products and\nServices, dated August 31, 2021, where PG&E shows costs and allocated profits\nfor 2020 but a number of aspects of the program are unclear, for example, the\namount of profits allocated to shareho ...

# %%
llm_session.query("What was my first question?")
# Out:
# GRC Assistant: Your first question was: "What information do you vae on PG&E from your retrival"
#
# Processing time: 0.52 seconds
# {'result': 'Your first question was: "What information do you vae on PG&E from your retrival"',
#  'messages_remaining': 12,
#  'sec_remaining': [53, 60, 60],
#  'tool_outputs': []}

# %% [markdown]
# # Prompt Testing

# %%
import io
import time
import random
from datetime import datetime
from pathlib import Path
from contextlib import redirect_stdout
import traceback
import re

from langchain.schema import HumanMessage
from google.api_core import exceptions as google_exceptions

def test_prompts_and_save(prompts):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_path = Path(
        f"./llm_output/test/llm_responses_with_context_qa_gemini_{timestamp}.txt"
    )
    llm_session = LLMChatSession(console_mode=True)
    clear_chat_history(llm_session.session_id)
    with output_path.open("w", encoding="utf-8") as f:
        for idx, prompt_text in enumerate(prompts):
            print(f"\n--- Running Prompt {idx+1}/{len(prompts)} ---")
            f.write(f"================= Prompt {idx+1} =================\n")
            f.write(f"PROMPT:\n{prompt_text}\n\n")

            success = False
            attempt = 0

            while not success:
                try:
                    response = llm_session.query(prompt_text)
                    response_result = response['result']
                    try:
                        response_context = response['tool_outputs'][0]['content']
                        f.write(f'SOURCES:\n{response_context}\n\n')
                    except:
                        f.write(f'SOURCES:\nNONE\n\n')
                    f.write(f'LLM RESPONSE:\n{response_result}\n\n')
                    clear_chat_history(llm_session.session_id)
                    success = True
                # except ConnectionRefusedError as e:
                #     error_message = str(e)
                #     match = re.search(r"Try again in (\d+) seconds", error_message)
                #     if match:
                #         wait_time = int(match.group(1))
                #         print(f"Rate limited. Waiting for {wait_time} seconds...")
                #         time.sleep(wait_time)
                #     clear_chat_history(llm_session.session_id)
                except google_exceptions.ResourceExhausted as e:
                    error_message = str(e)
                    print(f"Rate limit hit")

                    # Extract the retry_delay using regex
                    retry_match = re.search(r"retry_delay\s*\{\s*seconds:\s*(\d+)", error_message)

                    if retry_match:
                        retry_seconds = int(retry_match.group(1))
                        print(f"API suggests waiting for {retry_seconds} seconds")

                        # Wait for the suggested time
                        time.sleep(retry_seconds)
            if success:
                print(f"Prompt {idx+1} complete.")
            else:
                print(f"Prompt {idx+1} failed after {attempt} attempts.")

            # Delay between prompts
            if idx < len(prompts) - 1:
                time.sleep(random.uniform(1, 3))

    print(f"\nAll responses and contexts saved to: {output_path.resolve()}")

# %%
import json

with open('./qa_pairs/test_qa.json', 'r', encoding='utf-8') as file:
    test_data = json.load(file)

# %%
test_list = list(pair['question'] for pair in test_data['qa_pairs'])

# %%
test_prompts_and_save(test_list)
# Out:
# --- Running Prompt 1/60 ---
#
# GRC Assistant: I am unable to determine the witness for the CSO Closure and Transformation Proposal from the provided documents. Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.02 seconds
# Prompt 1 complete.
#
# --- Running Prompt 2/60 ---
#
# GRC Assistant: PG&E filed Application A.22-04-016 in April 2022, proposing to permanently close all 65 of its Customer Service Offices (CSOs) (PG&E 2023 GRC, [520418881](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K418/520418881.PDF), p.531; PG&E 2023 GRC, [520896345](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf), p.534; PG&E 2023 GRC, [520114360](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), p.531). The Commission authorized the permanent closure of PG&E’s 65 Customer Service Offices effective January 1, 2023, in D.22-12-033 (PG&E 2023 GRC, [520896345](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M520/K896/520896345.pdf), p.535; PG&E 2023 GRC, [520114360](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M520/K114/520114360.PDF), p.531).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.82 seconds
# Prompt 2 complete.
#
# --- Running Prompt 3/60 ---
#
# GRC Assistant: PG&E proposed permanently transforming its Customer Service Office (CSO) workforce to proactively engage with vulnerable customers through outbound calls, case management support, and community-based organization (CBO) engagement (PG&E 2022 Proposal, p. 1).
#
# Here's a breakdown:
#
# *   **COVID-19 Pandemic Impact:** PG&E temporarily closed all CSOs in March 2020 due to the COVID-19 pandemic (PG&E 2022 Proposal, p. 1; A2204016, AtchA-2, Para. 1.6).
# *   **Transition to Proactive Outreach:** The former CSO workforce transitioned to a proactive outreach model to assist vulnerable customers (PG&E 2022 Proposal, p. 1).
# *   **New Customer Outreach Model:** PG&E states that CSO representatives have become the owners of a transformed customer outreach model that facilitates longer conversations with customers to provide them with the right suite of programs, products, and services to meet their needs (A2204016, AtchA-2, Para. 1.6).
# *   **Targeted Vulnerable Customers:** PG&E would proactively reach out to targeted vulnerable customers through outbound calling, case management support, and community-based organization engagement, rather than serving customers who seek in-person services at a CSO (A2204016, AtchA-2, Para. 1.6).
# *   **Leveraging Partnerships:** PG&E will leverage its partnerships with CBOs to better engage with and provide support to PG&E’s low-income, disabled, and vulnerable customers (PG&E 2022 Proposal, p. 1).
# *   **Small Business Engagement:** PG&E continues to directly engage with small business customers through its Small Business Engagement (SBE) team, which includes the Small Business Advisors and Success through Additional Resources and Training (START) team, Customer Contact Center, and website for both payment and non-payment assistance (A2204016, p. 3).
#
# It's important to note that the Commission has never sanctioned this new form of customer service in lieu of traditional CSO services (A2204016, p. 4).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.15 seconds
# Prompt 3 complete.
#
# --- Running Prompt 4/60 ---
#
# GRC Assistant: PG&E reassigned its Customer Service Office (CSO) workforce to focus on proactive outreach to vulnerable customers after temporarily closing CSOs due to the COVID-19 pandemic in March 2020 (PG&E A.22-04-016, p.1; PG&E A.22-04-016, p.42).
#
# Here's a breakdown of the changes:
# *   **Temporary Closure:** PG&E temporarily closed all of its CSOs due to health and safety concerns during the COVID-19 pandemic (PG&E A.22-04-016, p.1; PG&E A.22-04-016, p.42).
# *   **Transition to Alternative Channels:** Customers transitioned to alternative service methods such as mail (29%), internet (25%), pay by phone (24%), and neighborhood payment centers (17%) (PG&E A.22-04-016, p.6). By the end of 2021, 98% of customers had migrated to other payment channels (PG&E A.22-04-016, p.6).
# *   **Proactive Outreach Model:** The CSO workforce transitioned to a proactive outreach model to assist vulnerable customers (PG&E A.22-04-016, p.1).
# *   **New responsibilities:** This included outbound calls, "case management" support, and community-based organization (CBO) engagement (PG&E A.22-04-016, p.1).
# *   **Staffing Levels:** In May 2022, PG&E's CSO workforce comprised 82 employees: 12 management and 70 customer service representatives (PG&E A.22-04-016, p.26).
# *   **Permanent Transformation:** PG&E proposed permanently transforming the CSO employees' scope of work (PG&E A.22-04-016, p.1).
# *   **Cost Savings:** PG&E estimated $14.9 million in total cost savings during the 2023 GRC period (2023-2026) from the 65 office closures. This includes $11.8 million in cumulative expense savings and an estimated $3.1 million from the sale of CSOs that PG&E owns (PG&E A.22-04-016, p.2).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.58 seconds
# Prompt 4 complete.
#
# --- Running Prompt 5/60 ---
#
# GRC Assistant: Yes. By the end of 2021, 98% of PG&E's exclusive CSO customers used other payment channels after the closure of CSOs (PG&E 2023 GRC, Exhibit PG&E-01 at 5; PG&E 2023 GRC, Exhibit 4, p.15). These channels included mail (29%), web (25%), pay by phone (24%), and Neighborhood Payment Centers (“NPCs”) (17%) (PG&E 2023 GRC, Exhibit PG&E-01 at 5-6; PG&E 2023 GRC, Exhibit 4, p.15).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.66 seconds
# Prompt 5 complete.
#
# --- Running Prompt 6/60 ---
#
# GRC Assistant: Yes, PG&E will submit the last CSO Annual Report on March 1, 2027, with data for 2026 (A.22-04-016, p.12).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 0.83 seconds
# Prompt 6 complete.
#
# --- Running Prompt 7/60 ---
#
# GRC Assistant: Within 90 days of the California Public Utilities Commission's (CPUC) approval of the CSO Closure and Transformation Proposal, PG&E plans to inform its customers of the closure of the 65 CSOs via direct mail and email notices to approximately 128,000 exclusive CSO customers. The notifications will include:
# *   The CPUC’s decision to close the CSOs and closure dates
# *   A list of available alternative channels for payments and nonpayment transactions, including the name and address of the nearest Non-Payment Center (NPC)
# *   Customer service phone numbers and website addresses for additional information and support
# *   A list of Community Based Organizations (CBOs) that PG&E compensates who provide customers information and financial assistance support (PG&E 2022 GRC, A2204016, [471485059](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M471/K485/471485059.PDF), chunk 14).
#
# PG&E also stated that they would inform customers of the CSO closures by mailing or emailing notices to CSO exclusive customers, including translated messages in non-English languages most commonly spoken in PG&E’s service area (PG&E 2022 GRC, A2204016, [475508067](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M475/K508/475508067.PDF), chunk 7).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.70 seconds
# Prompt 7 complete.
#
# --- Running Prompt 8/60 ---
#
# GRC Assistant: PG&E involves Community Based Organizations (CBOs) to improve outreach to underserved communities. These partnerships facilitate the dissemination of information in multiple languages regarding:
#
# *   Financial assistance and bill savings programs
# *   Rate options
# *   Wildfire safety-related topics
# *   Emergency preparedness (PG&E 2023 GRC, Exhibit 4, p.15)
#
# PG&E also coordinates with The Utility Reform Network (TURN), The Center for Accessible Technology (CforAT), and Cal Advocates to ensure that their constituents’ voices are heard (PG&E A.22-04-016, p.16). PG&E has stated it intends to engage with CBOs, including providing compensation for their collaboration (PG&E A.22-04-016, p.15).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.85 seconds
# Prompt 8 complete.
#
# --- Running Prompt 9/60 ---
#
# GRC Assistant: Yes, PG&E will post signage at the closed CSOs for at least one year or until PG&E no longer occupies the location, whichever is sooner (A2204016, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M471/K485/471485059.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M471/K485/471485059.PDF), p. 6).
#
# Processing time: 1.55 seconds
# Prompt 9 complete.
#
# --- Running Prompt 10/60 ---
#
# GRC Assistant: PG&E will measure the impacts of the CSO Closure and Transformation Proposal by tracking and reporting on several metrics over the next three years in a CSO Annual Report (PG&E 2023 GRC, A.22-04-016).
#
# **Key aspects of the measurement and reporting:**
#
# *   **Annual Reports:** PG&E will submit a CSO Annual Report providing specific metrics to the service list of this proceeding, beginning March 1 of the first full year following Commission approval of its application (PG&E 2023 GRC, A.22-04-016). The last CSO Annual Report will be submitted on March 1, 2027, with data for 2026 (PG&E 2023 GRC, A.22-04-016).
# *   **Metrics Tracked:** The metrics include (PG&E 2023 GRC, A.22-04-016):
#     *   Success rate of customer contact attempts
#     *   Number of call backs received
#     *   Average speed of answer (“ASA”) for the call center and web-based online completion rates
#     *   Number of customers enrolled by former CSO employees in the CARE, FERA, AMP programs and other financial assistance programs
#     *   Number of ESA program referrals
#     *   Number of Medical Baseline program applications sent to customers
#     *   Number of LIHEAP pledges from customers contacted by former CSO employees
#     *   Number of new customers that self-identify as vulnerable, disabled, and AFN
#     *   The number of payment transactions, per channel
#     *   The name of every CBO (that PG&E compensates) who provided outreach and/or enrollment in utility programs promoting bill affordability serving the city and/or county with the closed CSO, including the language(s) in which services are provided by the CBO and the number of customers that each CBO reports that they have enrolled in utility programs.
#
# *   **Transparency and Accountability:** The information gathered will improve transparency and accountability, which are critical because of the novelty and cost of PG&E’s proposal (PG&E 2023 GRC, A.22-04-016).
# *   **Informing Future Decisions:** This data will help inform the Commission’s and stakeholders’ consideration of whether the CSO Transformation program should continue after the 2023-2026 GRC cycle when PG&E requests continuation of the program in its Test Year 2027 GRC (PG&E 2023 GRC, A.22-04-016).
# *   **Tier 2 Advice Letter:** Following the Commission’s approval of PG&E’s CSO Closure and Transformation Proposal and 2023 GRC, PG&E will submit a Tier 2 Advice Letter within 60 days, detailing (1) the reduction to the adopted electric and gas distribution revenue requirements effective January 1, 2024, resulting from the closure of CSOs up to that date and (2) the savings to be returned to customers that were realized from the date of the CSO closures through December 31, 2023 (PG&E 2023 GRC, A.22-04-016).
# *   **Ongoing Adjustments:** As the new CSO model matures, PG&E will evolve its efforts to meet customers’ changing needs and continue soliciting community feedback on how to improve PG&E’s services (PG&E 2023 GRC, A.22-04-016).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 4.98 seconds
# Prompt 10 complete.
#
# --- Running Prompt 11/60 ---
#
# GRC Assistant: The Memorandum of Understanding (MOU) regarding the closure of PG&E’s Customer Service Offices (CSOs) and redirection of CSO staff to a new customer service program was agreed upon by the following parties:
#
# *   The Utility Reform Network (TURN)
# *   Center for Accessible Technology (CforAT)
# *   The Public Advocates Office (Cal Advocates)
# *   PG&E (Pacific Gas and Electric Company) (PG&E 2023 GRC, Exhibit PG&E-01, Attachment A)
#
# The MOU outlines a plan for transitioning PG&E’s CSO employees to perform outreach activities targeted to vulnerable customers, a communications plan informing customers about CSO closures and alternative payment methods, information about neighborhood payment centers and community based organizations, and metrics to evaluate the CSO Closure and transformation activities (PG&E 2023 GRC, Exhibit PG&E-01, Attachment A; D.22-12-033, pp. 2, 8-13).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.66 seconds
# Prompt 11 complete.
#
# --- Running Prompt 12/60 ---
#
# GRC Assistant: PG&E's CSO Closure and Transformation Proposal aligns with the Commission's Environmental and Social Justice Action Plan by focusing on proactively reaching marginalized and disadvantaged customers (PG&E 2023 GRC, Exhibit 4, p.4). Specifically, PG&E's proposal includes the following:
#
# *   **Targeted Customer Outreach:** PG&E will transition CSO employees to focus on targeted customer outreach to vulnerable customers through outbound calls, "case management" support, and community-based organization (CBO) engagement (PG&E 2023 GRC, Exhibit 4, p.1).
# *   **Training and Support:** PG&E will train CBOs on financial assistance programs and provide customers with a dedicated phone line connecting them to a CSO representative. The CSO workforce will engage with non-English speaking customers using third-party translation services. Annual training will be provided to CSO representatives on the challenges faced by vulnerable customers (PG&E 2023 GRC, Exhibit 4, p.4).
# *   **Alignment with ESJ Action Plan:** PG&E states that these efforts are aligned with the Commission’s Environmental and Social Justice Plan (ESJ Action Plan) (PG&E 2023 GRC, Exhibit 4, p.4).
#
# The CPUC also considered whether the closures of the CSOs would result in an unmitigated impact on the achievement of the Commission’s Environmental and Social Justice Action Plan (PG&E 2023 GRC, Scoping Memo, p.5; PG&E 2023 GRC, Scoping Ruling, p.6).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.59 seconds
# Prompt 12 complete.
#
# --- Running Prompt 13/60 ---
#
# GRC Assistant: I am unable to determine the witness for the CSO Closure and Transformation Proposal from the provided documents. Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 0.88 seconds
# Prompt 13 complete.
#
# --- Running Prompt 14/60 ---
#
# GRC Assistant: PG&E filed Application A.22-04-016 in April 2022, proposing to permanently close all 65 of its Customer Service Offices (CSOs) (PG&E 2023 GRC, p.531; PG&E 2023 GRC, p.534). The Commission authorized the permanent closure of PG&E’s 65 Customer Service Offices effective January 1, 2023, in Decision (D.) 22-12-033 (PG&E 2023 GRC, p.535).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.41 seconds
# Prompt 14 complete.
#
# --- Running Prompt 15/60 ---
#
# GRC Assistant: PG&E proposed permanently transforming the scope of work of its Customer Service Office (CSO) employees to proactively engage with vulnerable customers through outbound calls, "case management" support, and community-based organization (CBO) engagement (PG&E 2022 Proposal, p. 1).
#
# Here's a breakdown:
#
# *   **COVID-19 Pandemic:** PG&E temporarily closed all CSOs in March 2020 due to the COVID-19 pandemic (PG&E 2022 Proposal, p. 1; A2204016, Exhibit A-2, Para. 1.6).
# *   **Transition to Proactive Outreach:** Recognizing the needs of vulnerable customers during the pandemic, PG&E transitioned its CSO workforce to a proactive outreach model (PG&E 2022 Proposal, p. 1).
# *   **New Customer Outreach Model:** PG&E testified that CSO representatives became owners of a transformed customer outreach model, facilitating longer conversations with customers to provide them with the right suite of programs, products, and services to meet their needs (A2204016, Exhibit A-2, Para. 1.6).
# *   **Engagement methods**: This new approach involves outbound calling, case management support, and CBO engagement to better support low-income, disabled, and vulnerable customers (PG&E 2022 Proposal, p. 1; A2204016).
# *   **Alternative Service Channels**: PG&E states that former CSO customers have successfully transitioned to alternative service channels since the CSO closures in March 2020 (A2204016).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.79 seconds
# Prompt 15 complete.
#
# --- Running Prompt 16/60 ---
#
# GRC Assistant: PG&E transitioned its Customer Service Office (CSO) employees to a proactive outreach model to assist vulnerable customers (PG&E A.22-04-016, p.1). This transition began after the temporary closure of CSOs due to the COVID-19 pandemic in March 2020 (PG&E A.22-04-016, p.2).
#
# Here's a breakdown of the changes:
# *   **Temporary Closure:** PG&E temporarily closed all of its CSOs due to the COVID-19 pandemic (PG&E A.22-04-016, p.1).
# *   **Transition to Alternative Channels:** Customers who previously used CSOs successfully transitioned to alternate service methods, such as mail (29%), internet (25%), pay by phone (24%), and neighborhood payment centers (17%) (PG&E A.22-04-016, p.6). By the end of 2021, 98% of customers had migrated to other payment channels (PG&E A.22-04-016, p.6).
# *   **Proactive Outreach:** The CSO workforce transitioned to proactively engage with vulnerable customers through outbound calls, "case management" support, and community-based organization (CBO) engagement (PG&E A.22-04-016, p.1).
# *   **Staffing Levels:** While PG&E believes that CSO staffing levels are appropriate, the CSO workforce declined by 61% since March 2020. In March 2020, PG&E operated 75 CSOs with 212 positions. By May 2022, the workforce had declined to 82 positions (PG&E A.22-04-016).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.10 seconds
# Prompt 16 complete.
#
# --- Running Prompt 17/60 ---
#
# GRC Assistant: Yes. By the end of 2021, 98% of PG&E's exclusive CSO customers used other payment channels after the closure of CSOs (PG&E 2023 GRC, Exhibit PG&E-01 at 5; PG&E 2023 GRC, Exhibit 4, p.15). These channels included mail (29%), web (25%), pay by phone (24%), and Neighborhood Payment Centers (“NPCs”) (17%) (PG&E 2023 GRC, Exhibit PG&E-01 at 5-6).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.63 seconds
# Prompt 17 complete.
#
# --- Running Prompt 18/60 ---
#
# GRC Assistant: Yes, PG&E will submit the last CSO Annual Report on March 1, 2027, with data for 2026 (A2204016, p.12).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.01 seconds
# Prompt 18 complete.
#
# --- Running Prompt 19/60 ---
#
# GRC Assistant: Within 90 days of the Commission's approval of the CSO Closure and Transformation Proposal, PG&E plans to inform its customers of the closure of the 65 CSOs through direct mail and e-mail notices to approximately 128,000 exclusive CSO customers. These notices will include:
#
# *   The Commission’s decision to close the CSO and closure dates.
# *   A list of available alternative channels for payments and nonpayment transactions, including the name and address of the nearest NPCs.
# *   Customer service phone numbers and website addresses for additional information and support.
# *   A list of CBOs that PG&E compensates who provide customers information and financial assistance support (PG&E 2023 GRC, Exhibit 4, p.14).
#
# PG&E will also inform customers of the 65 CSO closures by mailing or emailing notices to CSO exclusive customers, including translated messages in non-English languages most commonly spoken in PG&E’s service area (PG&E 2023 GRC, Exhibit 4, p.14).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.17 seconds
# Prompt 19 complete.
#
# --- Running Prompt 20/60 ---
#
# GRC Assistant: PG&E included partnerships with Community Based Organizations (CBOs) in its communications plan to improve outreach to underserved communities by disseminating information about:
#
# *   Financial assistance and bill savings programs
# *   Rate options
# *   Wildfire safety-related topics
# *   Emergency preparedness in multiple languages to help reach vulnerable customers (PG&E 2023 GRC, Exhibit 4, p.15).
#
# PG&E also engaged with organizations such as The Utility Reform Network (TURN), the Center for Accessible Technology (CforAT), and the Public Advocates’ Office at the California Public Utilities Commission (“CalAdvocates”) to ensure that the voices of their constituents were heard in developing its CSO Closure and Transformation Proposal (PG&E A.22-04-016, p.16). PG&E stated that it has provided details in its testimony about how it intends to engage with CBOs including providing compensation for their collaboration (PG&E A.22-04-016, p.15).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.75 seconds
# Prompt 20 complete.
#
# --- Running Prompt 21/60 ---
#
# GRC Assistant: Yes, PG&E will post signage at the closed CSOs for at least one year or until PG&E no longer occupies the location, whichever is sooner. The signage and PG&E's website will include relevant information for customers (PG&E 2022, A2204016, p.6).
#
# Processing time: 0.94 seconds
# Prompt 21 complete.
#
# --- Running Prompt 22/60 ---
#
# GRC Assistant: PG&E will measure the impacts of the CSO Closure and Transformation Proposal by tracking and reporting on several metrics over the next three years in a CSO Annual Report (PG&E 2023 GRC, A.22-04-016).
#
# **Key aspects of the measurement and reporting:**
#
# *   **Annual Reports:** PG&E will submit a CSO Annual Report providing specific metrics to the service list of the proceeding, starting March 1 of the first full year following Commission approval of its application (PG&E 2023 GRC, A.22-04-016). The final report will be submitted on March 1, 2027, with data for 2026 (PG&E 2023 GRC, A.22-04-016).
# *   **Metrics Tracked:** The metrics include (PG&E 2023 GRC, A.22-04-016):
#
#     *   Success rate of customer contact attempts
#     *   Number of call backs received
#     *   Average speed of answer (ASA) for the call center and web-based online completion rates
#     *   Number of customers enrolled by former CSO employees in CARE, FERA, AMP, and other financial assistance programs
#     *   Number of ESA program referrals
#     *   Number of Medical Baseline program applications sent to customers
#     *   Number of LIHEAP pledges from customers contacted by former CSO employees
#     *   Number of new customers that self-identify as vulnerable, disabled, and AFN
#     *   Number of payment transactions, per channel
#     *   The name of every Community Based Organization (CBO) that PG&E compensates who provided outreach and/or enrollment in utility programs promoting bill affordability serving the city and/or county with the closed CSO, including the language(s) in which services are provided by the CBO and the number of customers that each CBO reports that they have enrolled in utility programs.
# *   **Transparency and Accountability:** The information gathered will improve transparency and accountability, which is critical because of the novelty and cost of PG&E’s proposal (PG&E 2023 GRC, A.22-04-016).
# *   **Future Program Considerations:** The data will inform the Commission’s and stakeholders’ consideration of whether the CSO Transformation program should continue after the 2023-2026 GRC cycle when PG&E requests continuation of the program in its Test Year 2027 GRC (PG&E 2023 GRC, A.22-04-016).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.77 seconds
# Prompt 22 complete.
#
# --- Running Prompt 23/60 ---
#
# GRC Assistant: The Memorandum of Understanding (MOU) in support of PG&E's Customer Service Office (CSO) Closure and Transformation Proposal was agreed upon by the following parties:
#
# *   The Utility Reform Network (TURN)
# *   Center for Accessible Technology (CforAT)
# *   The Public Advocates Office (Cal Advocates)
# *   PG&E (PG&E 2023 GRC, Exhibit 4, p.15)
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.40 seconds
# Prompt 23 complete.
#
# --- Running Prompt 24/60 ---
#
# GRC Assistant: PG&E's CSO Closure and Transformation Proposal aligns with the Commission's Environmental and Social Justice Action Plan in several ways:
#
# *   **Targeted Outreach to Vulnerable Customers:** The proposal focuses on transitioning CSO employees to conduct targeted outreach to the most vulnerable customers through outbound calls, "case management" support, and community-based organization (CBO) engagement (PG&E 2023 GRC, Exhibit 4, p.1).
# *   **Alignment with ESJ Action Plan:** PG&E states that its efforts, including providing a dedicated phone line and annual training to CSO representatives, are aligned with the Commission’s Environmental and Social Justice Plan (PG&E 2023 GRC, Exhibit 4, p.4). The proposal aims to proactively reach marginalized and disadvantaged customers, which aligns with the ESJ Action Plan 2.0 (PG&E 2023 GRC, Exhibit 2, p.11).
# *   **Consideration of Unmitigated Impact:** The CPUC will consider whether the closures of the CSOs would result in an unmitigated impact on the achievement of the Commission’s Environmental and Social Justice Action Plan as part of the GRC proceeding (PG&E 2023 GRC, Exhibit 15, p.6; PG&E 2023 GRC, Exhibit 11, p.5; PG&E 2023 GRC, Exhibit 14, p.2).
#
# PG&E intends to evolve its CSO model to meet customers’ changing needs as it matures (PG&E 2023 GRC, Exhibit 4, p.4). The CPUC will also assess whether PG&E has appropriately engaged with underserved communities to receive feedback on their needs and input on how to mitigate any harms (PG&E 2023 GRC, Exhibit 15, p.6; PG&E 2023 GRC, Exhibit 11, p.5).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.04 seconds
# Prompt 24 complete.
#
# --- Running Prompt 25/60 ---
#
# GRC Assistant: PG&E filed a Motion for Order Maintaining the Status Quo, seeking to keep Customer Service Offices (CSOs) closed until the Commission decided on PG&E’s application, and TURN responded to this motion pursuant to Rule 11.1(e) of the Commission’s Rules of Practice and Procedure (PG&E 2022 CSO Closure Application, p.1; PG&E 2022 CSO Closure Proposal, p. 1).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.61 seconds
# Prompt 25 complete.
#
# --- Running Prompt 26/60 ---
#
# GRC Assistant: PG&E's Customer Service Offices (CSOs) were closed in March 2020 due to health and safety concerns related to the COVID-19 epidemic (PG&E 2023 GRC, Exhibit 4, p.15). As of April 28, 2022, when PG&E filed its application to permanently close the CSOs, they had been closed for approximately two years (PG&E 2023 GRC, Application A.22-04-016).
#
# Processing time: 1.15 seconds
# Prompt 26 complete.
#
# --- Running Prompt 27/60 ---
#
# GRC Assistant: PG&E argues that reopening Customer Service Offices (CSOs) before a final decision on their permanent closure would be detrimental for several reasons:
#
# *   **Customer and Employee Confusion:** Reopening CSOs temporarily, only to close them again if the Commission approves the closure application, would create confusion for both customers and employees (PG&E 2023 GRC, Exhibit 4, p.15; PG&E Motion, pp. 3-4). Customers who have already transitioned to alternative payment methods might revert to using CSOs, only to have them close again (PG&E 2023 GRC, Exhibit 4, p.15).
# *   **Unnecessary Costs:** PG&E argues that temporarily reopening CSOs would lead to incurring costs for backfilling CSO positions that might be eliminated shortly thereafter (PG&E Motion, p. 4). PG&E also states that cost savings resulting from the permanent closure of CSOs should be returned to ratepayers, instead of being used to temporarily operate and maintain reopened CSOs (PG&E 2023 GRC, Exhibit 4, p.15).
# *   **Impact on Ratepayers:** PG&E contends that ratepayers benefit when utilities avoid short-sighted spending and that maintaining the status quo would ensure cost savings are properly returned to them (PG&E 2023 GRC, Exhibit 4, p.15).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.41 seconds
# Prompt 27 complete.
#
# --- Running Prompt 28/60 ---
#
# GRC Assistant: PG&E's application to close its remaining 65 Customer Service Offices (CSOs) cited the following pre-pandemic trend to support its motion:
#
# *   In 2019, prior to the COVID-19 pandemic, 93% of all CSO transactions were energy bill payments (PG&E 2023 GRC, Exhibit 4, p.15; PG&E A.22-04-016).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.03 seconds
# Prompt 28 complete.
#
# --- Running Prompt 29/60 ---
#
# GRC Assistant: Yes, the motion states that 98% of exclusive CSO customers had migrated to alternative payment channels by the end of 2021. According to PG&E's data, 98% of their customers, including low-income, disabled, and vulnerable customers, successfully transitioned to other payment channels by the end of 2021 (PG&E 2023 GRC, Exhibit PG&E-01 at 5; PG&E 2023 GRC, p.2; PG&E 2023 GRC). These alternative channels include mail (29%), web (25%), pay by phone (24%), and Neighborhood Payment Centers (17%) (PG&E 2023 GRC, Exhibit PG&E-01 at 5-6; PG&E 2023 GRC).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.91 seconds
# Prompt 29 complete.
#
# --- Running Prompt 30/60 ---
#
# GRC Assistant: PG&E cites the Public Utilities Act, noting that the Commission has the authority to "do all things, whether specifically designated in [the Public Utilities Act] or in addition thereto, which are necessary and convenient” in the exercise of its jurisdiction over public utilities (PG&E 2023 GRC, Exhibit 4, p.15).
#
# Processing time: 1.23 seconds
# Prompt 30 complete.
#
# --- Running Prompt 31/60 ---
#
# GRC Assistant: PG&E filed a Motion for Order Maintaining the Status Quo, requesting that PG&E be permitted to keep its Customer Service Offices (CSOs) closed until the Commission decided PG&E’s Application for Authorization of PG&E’s Customer Service Office (“CSO”) Closure and Transformation Proposal, Application (“A.”) 22-04-016 (PG&E 2022 CSO Closure Application).
#
# TURN (The Utility Reform Network) responded to PG&E’s request for an expedited schedule under Rule 2.9 and PG&E’s proposed schedule. Pursuant to Rule 11.1(e), TURN also responded to PG&E’s motion to maintain the status quo (TURN Response to PG&E Motion, p. 1).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.79 seconds
# Prompt 31 complete.
#
# --- Running Prompt 32/60 ---
#
# GRC Assistant: PG&E's Customer Service Offices (CSOs) were closed in March 2020 due to health and safety concerns related to the COVID-19 epidemic (PG&E 2023 GRC, Exhibit 4, p.15). As of September 15, 2022, when PG&E and NDC jointly filed a motion for approval of settlement, the CSOs had been closed for approximately two years and six months (PG&E 2023 GRC, Exhibit 4, p.15).
#
# In April 2022, PG&E filed Application A.22-04-016 proposing to permanently close all of its Customer Service Offices (A.21-06-021).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.68 seconds
# Prompt 32 complete.
#
# --- Running Prompt 33/60 ---
#
# GRC Assistant: PG&E argues that reopening Customer Service Offices (CSOs) before a final decision on their permanent closure would be detrimental for several reasons in the context of Application A.22-04-016:
#
# *   **Customer and Employee Confusion:** Reopening CSOs temporarily, only to close them again shortly thereafter if the Commission approves their permanent closure, would create confusion for both customers and employees (PG&E 2023 GRC, Exhibit 4, p.15; PG&E Motion, pp. 3-4). Customers who have shifted to alternative payment methods during the pandemic might return to CSOs, only to have them close again (PG&E Motion, pp. 1-2).
# *   **Unnecessary Costs:** PG&E contends that temporarily reopening CSOs would lead to unnecessary costs, including backfilling CSO positions that might soon be eliminated (PG&E Motion, p. 4). PG&E argues that these costs should be avoided, as ratepayers benefit when utilities avoid short-sighted spending.
# *   **Ratepayer Benefits:** Maintaining the status quo ensures that any cost savings resulting from the permanent closure of CSOs are properly returned to ratepayers, instead of being used to temporarily operate and maintain reopened CSOs (PG&E 2023 GRC, Exhibit 4, p.15).
# *   **Alternative Uses of CSO Locations:** Uncertainty about reopening CSOs does not allow for a complete weighing of all the options for alternative uses for PG&E CSO closure locations (PG&E 2023 GRC, Exhibit 4, p.48).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.79 seconds
# Prompt 33 complete.
#
# --- Running Prompt 34/60 ---
#
# GRC Assistant: PG&E's application to close its remaining 65 Customer Service Offices (CSOs) cited that prior to the COVID-19 pandemic in 2019, 93 percent of all CSO transactions were energy bill payments (PG&E 2023 GRC, Exhibit 4, p.15; A2204016).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 0.90 seconds
# Prompt 34 complete.
#
# --- Running Prompt 35/60 ---
#
# GRC Assistant: Yes, the motion states that 98% of exclusive CSO customers had migrated to alternative payment channels by the end of 2021 (PG&E 2023 GRC, Exhibit PG&E-01, p.5; PG&E 2023 GRC, A2204016).
#
# Processing time: 1.15 seconds
# Prompt 35 complete.
#
# --- Running Prompt 36/60 ---
#
# GRC Assistant: PG&E cites the Public Utilities Act, noting that the Commission has the authority to "do all things, whether specifically designated in [the Public Utilities Act] or in addition thereto, which are necessary and convenient" in the exercise of its jurisdiction over public utilities (PG&E 2023 GRC, Exhibit 4, p.15).
#
# Processing time: 1.18 seconds
# Prompt 36 complete.
#
# --- Running Prompt 37/60 ---
#
# GRC Assistant: I am sorry, but I cannot provide the application number that Decision 25-03-008 addresses based on the provided documents. Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.22 seconds
# Prompt 37 complete.
#
# --- Running Prompt 38/60 ---
#
# GRC Assistant: I am unable to locate any information regarding a decision with the number 25-03-008.
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 0.86 seconds
# Prompt 38 complete.
#
# --- Running Prompt 39/60 ---
#
# GRC Assistant: PG&E maintains three layers of non-wildfire liability insurance coverage (PG&E 2023 GRC, Exhibit 4, p.4). The total coverage for non-wildfire liability claims is $700 million (PG&E 2023 GRC, Exhibit 4, p.4).
#
# The layers are:
# *   **Layer 1:** Covers claims between $10 million and $115 million. This layer has the highest likelihood of use due to the frequency of small claims (PG&E 2023 GRC, Exhibit 4, p.4, p.5). PG&E's self-insured retention covers the first $10 million in liability for claims (PG&E 2023 GRC, Exhibit 4, p.5). This layer will be revised downward to cover claims up to $75 million, a decrease from $115 million (PG&E 2023 GRC, Exhibit 4, p.5).
# *   **Layer 2:** Covers claims between $115 million and $535 million (PG&E 2023 GRC, Exhibit 1, p.3).
# *   **Layer 3:** Coverage details for Layer 3 are not specified in the provided documents.
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.66 seconds
# Prompt 39 complete.
#
# --- Running Prompt 40/60 ---
#
# GRC Assistant: The Settling Parties requested that a final decision adopting the settlement agreement in A.21-06-021 be issued no later than the Commission’s voting meeting on March 13, 2025, because PG&E had to decide whether to secure replacement third-party commercial coverage before the end of March 2025 (A.21-06-021; [551138788], p. 20).
#
# The Settling Parties argued that the circumstances represented a "rare case" where a delay beyond a certain date would invalidate the basis for the proposal, as described in Rule 12.1(c) of the Commission’s Rules of Practice and Procedure (A.21-06-021; [551138788], p. 20).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.82 seconds
# Prompt 40 complete.
#
# --- Running Prompt 41/60 ---
#
# GRC Assistant: The Decision in PG&E's 2023 GRC (A.21-06-021) states several reasons why the self-insurance framework is in the public interest:
#
# *   **Cost Savings:** In the near term, ratepayers will not have to pay procurement fees and taxes tied to third-party insurance coverage. In the longer term, once the self-insurance target of $460 million is reached, ratepayers will no longer need to pay the related cost, which is currently $96 million per year (A.21-06-021, [559409281](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M559/K409/559409281.PDF), p. 19).
# *   **Consistency with Law:** The agreement provides a lawful framework and structure materially consistent with Commission treatment of self-insurance for wildfire liability coverage. The Commission finds that the agreement is consistent with law (A.21-06-021, [559409281](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M559/K409/559409281.PDF), p. 19).
# *   **Reduced Exposure to Market Volatility:** Self-insurance can reduce PG&E’s exposure to insurance market volatility, such as sharp premium increases, changes in coverage, and reductions in global capacity (A.21-06-021, [551138788](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M551/K138/551138788.PDF), p. 3).
# *   **Avoidance of "Use It or Lose It" Paradigm:** Unlike commercial insurance, where premiums are kept by insurers regardless of claims, self-insurance allows excess revenue requirement to accumulate and be available for covered claims in subsequent years (A.21-06-021, [551138788](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M551/K138/551138788.PDF), p. 1, [559409281](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M559/K409/559409281.PDF), p. 13).
# *   **Modeled After Wildfire Self-Insurance Programs:** The self-insurance proposal is modeled after the wildfire self-insurance programs the Commission approved for PG&E and Southern California Edison Company (A.21-06-021, [556455160](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M556/K455/556455160.PDF), p. 4).
#
# It's important to note that the success of the self-insurance framework in reducing costs for customers depends on the total amount of non-wildfire liability claims incurred by PG&E. A single large claim or a high volume of claims could deplete the fund and delay the achievement of a fully funded program (A.21-06-021, [551138788](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M551/K138/551138788.PDF), p. 3).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 4.79 seconds
# Prompt 41 complete.
#
# --- Running Prompt 42/60 ---
#
# GRC Assistant: Based on the documents provided, I can confirm that there was opposition to a motion for modification filed in proceeding A.21-06-021. Specifically, the Joint CCAs opposed the motion’s request for a March 30, 2022, end date for discovery on PG&E’s Opening Testimony, arguing that the meet and confer process on the motion’s proposed changes was incomplete (A.21-06-021, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M454/K865/454865286.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M454/K865/454865286.PDF)).
#
# Therefore, the answer is Yes.
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.94 seconds
# Prompt 42 complete.
#
# --- Running Prompt 43/60 ---
#
# GRC Assistant: I am sorry, but I cannot answer this question. My knowledge base does not contain any documents that mention Decision 25-03-008.
#
# Processing time: 0.99 seconds
# Prompt 43 complete.
#
# --- Running Prompt 44/60 ---
#
# GRC Assistant: I am unable to locate the issuance date for a decision numbered 25-03-008 from the provided documents.
#
# Processing time: 0.84 seconds
# Prompt 44 complete.
#
# --- Running Prompt 45/60 ---
#
# GRC Assistant: PG&E maintains three layers of non-wildfire liability insurance coverage, providing a target of $700 million in total coverage (PG&E 2023 GRC, Exhibit 4, p.4). The first layer (Layer 1) covers claims between $10 million and $115 million (PG&E 2023 GRC, Exhibit 4, p.4). PG&E's self-insured retention covers the first $10 million in liability for claims (PG&E 2023 GRC, Exhibit 4, p.5).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.61 seconds
# Prompt 45 complete.
#
# --- Running Prompt 46/60 ---
#
# GRC Assistant: The Settling Parties requested that a final decision adopting the settlement agreement in proceeding A.21-06-021 be issued no later than the Commission’s voting meeting on March 13, 2025 because PG&E needed to decide whether to secure replacement third-party commercial coverage before the end of March 2025 (A.21-06-021; 551138788.PDF, p. 20). The settling parties argued that the circumstances represented a "rare case" where a delay beyond a certain date would invalidate the basis for the proposal, as described in Rule 12.1(c) of the Commission’s Rules of Practice and Procedure (A.21-06-021; 551138788.PDF, p. 20).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.68 seconds
# Prompt 46 complete.
#
# --- Running Prompt 47/60 ---
#
# GRC Assistant: The Decision justifies the self-insurance framework as being in the public interest for several reasons, primarily related to cost savings for ratepayers and reduced exposure to volatile insurance market conditions:
#
# *   **Reduced Costs:** In the near term, ratepayers will not have to cover procurement fees and taxes associated with third-party insurance. In the long term, once the self-insurance target of $460 million is reached, ratepayers will no longer need to pay the related cost, which is currently $96 million per year (A.21-06-021, p. 19).
# *   **Savings for Ratepayers**: Self-insurance can result in overall cost savings compared to commercial insurance, especially with increasing premiums. If funds are not needed to cover losses in a given year, the excess revenue accumulates and is available for claims in subsequent years, unlike commercial insurance where premiums are typically kept by insurers regardless of claims (PG&E 2023 GRC, Exhibit 4, p.1).
# *   **Mitigation of Premium Volatility:** Self-insurance reduces PG&E’s exposure to insurance market volatility, such as sharp premium increases, changes in coverage, and reductions in market capacity (PG&E 2023 GRC, Exhibit 4).
# *   **Modeled After Wildfire Self-Insurance Programs:** The self-insurance proposal is modeled after the wildfire self-insurance programs the Commission approved for PG&E and Southern California Edison Company (PG&E 2023 GRC, Exhibit 4).
# *   **Flexibility in Funding:** Self-insurance funds may grow during the time between a third-party liability event occurring and when settlement payments are made. This differs from commercial insurance, where the entire premium is paid annually (PG&E 2023 GRC, Exhibit 4).
#
# However, it is important to note that the success of the self-insurance framework in reducing costs for customers depends on the total amount of non-wildfire liability claims incurred by PG&E. A single large claim or a high volume of claims could deplete the fund and delay the achievement of a fully funded program (PG&E 2023 GRC, Exhibit 4).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.10 seconds
# Prompt 47 complete.
#
# --- Running Prompt 48/60 ---
#
# GRC Assistant: Based on the provided documents, it is not possible to definitively answer whether any responses were filed opposing the Joint Petition for Modification. While one document mentions PG&E's motion to modify an ALJ Ruling and another discusses a Joint Motion for sur-reply briefing, these do not directly address whether any opposition was filed to a Joint Petition for Modification (PG&E 2023 GRC, Exhibit 4, p.15; PG&E 2023 GRC, Exhibit 7, p.3; TURN 2022, p.2).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.27 seconds
# Prompt 48 complete.
#
# --- Running Prompt 49/60 ---
#
# GRC Assistant: The effective date for the 2023 GRC revenue requirement approved by the CPUC is January 1, 2023 (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)). The CPUC granted PG&E’s motion to make this effective date regardless of when the final decision was issued. This means the rate change calculation includes the amount that would have been in effect from January 1, 2023 (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)).
#
# PG&E did not request interim rates, which are subject to refund if the proceeding decides such rates were not warranted (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M488/K540/488540929.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Published/G000/M488/K540/488540929.PDF)). To address the timing of the final decision, the order specifies using the three-month commercial paper rate, published in the Federal Reserve Statistical Release H.15, to ensure PG&E, ratepayers, shareholders, and other affected parties remain indifferent to the decision's timing (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.74 seconds
# Prompt 49 complete.
#
# --- Running Prompt 50/60 ---
#
# GRC Assistant: PG&E states that approximately 86 percent of the requested increases over 2022 adopted rates is to mitigate risk in its gas and electric operations (A2106021, 499773045.PDF, p.16).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.45 seconds
# Prompt 50 complete.
#
# --- Running Prompt 51/60 ---
#
# GRC Assistant: PG&E included an analysis of climate change in its 2023 GRC testimony because the environment is continuously changing (PG&E 2023 GRC, Opening Brief, p. 78). PG&E's climate resilience work is based on three pillars (PG&E 2023 GRC, Opening Brief, p. 78):
# *   Bringing forward-looking climate data into internal decision making.
# *   Working with policymakers and regulators to advance climate adaptation policies and initiatives.
# *   Collaborating with local governments and communities on adaptation solutions. (PG&E 2023 GRC, Opening Brief, p. 78)
#
# PG&E remains committed to California’s climate and clean energy goals and to actions that reduce greenhouse gas emissions (PG&E 2023 GRC, Exhibit PG&E-2, Chapter 1). In 2020, approximately 85% of the electricity PG&E supplied to customers was greenhouse gas-free. PG&E supports customers in their climate goals through programs and incentives for energy efficiency, clean energy transportation, solar energy, and battery storage (PG&E 2023 GRC, Exhibit PG&E-2, Chapter 1). PG&E established a Climate Resilience team in 2016 to assess the impact of climate change on PG&E’s assets and employees (PG&E 2023 GRC, Exhibit PG&E-2, Chapter 1).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.51 seconds
# Prompt 51 complete.
#
# --- Running Prompt 52/60 ---
#
# GRC Assistant: PG&E acknowledges the uncertainty in future gas capacity growth due to California's decarbonization policies, including local ordinances restricting gas appliance installation in new construction (PG&E-16, p. 11-37). To address this uncertainty, PG&E is:
#
# *   Working with the California Energy Commission and other agencies to develop detailed, location-based gas demand forecasts under peak conditions that reflect decarbonization impacts (PG&E-16, p. 11-37).
# *   Leveraging the use of compressed natural gas (CNG), liquified natural gas (LNG), and manual field operations to ensure system reliability in localized or constrained regions (PG&E-16, p. 11-37).
#
# PG&E proposed shifting to the Unit of Production (UoP) method to accelerate the recovery of gas distribution depreciation expenses, however, this proposal was contested by other parties, who argued that the Gas Planning OIR (R.20-01-007) is the appropriate forum to address these issues (Cal Advocates, TURN, and Indicated Shippers Reply Brief). These parties contend that PG&E's "incremental approach" would mask the impact on depreciation expense and burden customers (Indicated Shippers Reply Brief). They argue the cost of rejecting PG&E's proposal is minimal compared to the burden on customers and that a broader array of options for addressing stranded cost risk should be considered in the Gas System Planning OIR (Indicated Shippers Reply Brief).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.18 seconds
# Prompt 52 complete.
#
# --- Running Prompt 53/60 ---
#
# GRC Assistant: Yes, PG&E proposes to retain and operate the Los Medanos gas storage facility (PG&E 2023 GRC, Exhibit 4, p.7-46; PG&E 2023 GRC, Alternate Proposed Decision). This is a change from their original Natural Gas Storage Strategy (NGSS) where they planned to sell or decommission it (PG&E 2023 GRC, Exhibit 4, p.7-46).
#
# The Commission, in a prior 2019 GT&S case, had approved a process for decommissioning the Los Medanos storage facility, requiring PG&E to address storage capacity uncertainties after the shutdown (PG&E 2023 GRC, Proposed Decision). However, PG&E now recommends retaining the facility due to a projected shortfall in gas withdrawal capacity and the relative cost-effectiveness of operating Los Medanos (PG&E 2023 GRC, Proposed Decision).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 2.08 seconds
# Prompt 53 complete.
#
# --- Running Prompt 54/60 ---
#
# GRC Assistant: Yes, the 2023 General Rate Case (GRC) includes forecasts with necessary funding to continue to safely operate the Diablo Canyon Power Plant (DCPP) through its remaining life, and to provide for its safe and orderly closure (PG&E 2023 GRC, Exhibit 4, p.15).
#
# **Additional Details:**
#
# *   The GRC covers a period that includes the retirement of DCPP in 2024 for Unit 1 and 2025 for Unit 2 (PG&E 2023 GRC, Exhibit 4, p.15).
# *   PG&E's rate case application was filed before the passage of Senate Bill 846, so the capital and expense forecasts for DCPP do not reflect a possible change in the operational status of the plant as contemplated by Senate Bill 846. PG&E's cost request reflects the shutdown dates of November 2024 (Unit 1) and August 2025 (Unit 2) (CPUC, Proposed Decision, A.21-06-021, p.802).
# *   A stipulation between TURN and PG&E provides a Nuclear Operations capital expenditure forecast based on PG&E’s forecast, with PG&E only requesting Commission authorized forecasts in this proceeding be recorded and recovered through the Diablo Canyon Retirement Balancing Account (CPUC, Proposed Decision, A.21-06-021, p.803).
# *   The capital expenditure forecast for Nuclear Operations is $11.0 million for 2023, $6.0 million for 2024, $1.0 million for 2025, and $0 million for 2026 (CPUC, Proposed Decision, A.21-06-021, p.803).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.18 seconds
# Prompt 54 complete.
#
# --- Running Prompt 55/60 ---
#
# GRC Assistant: The effective date for the 2023 GRC revenue requirement approved by the CPUC is January 1, 2023 (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)).
#
# **Details:**
#
# *   PG&E requested that the revenue requirement approved by the CPUC for 2023 be effective January 1, 2023, regardless of when the decision is issued (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M488/K540/488540929.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M488/K540/488540929.PDF)).
# *   The CPUC granted PG&E's unopposed motion to issue an order finding that January 1, 2023, shall be the effective date for the 2023 GRC revenue requirement adopted by the Commission (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)).
# *   The final decision includes in the rate change calculation the amount of the rates that would have been in effect dating back to January 1, 2023, even if the decision is issued late in 2023 (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M488/K540/488540929.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M488/K540/488540929.PDF)).
# *   The order is designed to keep PG&E, its ratepayers, shareholders, and other affected parties indifferent to the precise timing of the Commission’s final decision authorizing the 2023 GRC revenue requirement (PG&E 2023 GRC, [https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF](https://docs.cpuc.ca.gov/PublishedDocs/Efile/G000/M477/K459/477459460.PDF)).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.95 seconds
# Prompt 55 complete.
#
# --- Running Prompt 56/60 ---
#
# GRC Assistant: PG&E states that approximately 86 percent of the requested increases over 2022 adopted rates is to mitigate risk in its gas and electric operations (A2106021, 499773045.PDF, p.1).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.34 seconds
# Prompt 56 complete.
#
# --- Running Prompt 57/60 ---
#
# GRC Assistant: PG&E included an analysis of climate change in its 2023 GRC testimony for the first time as part of its commitment to California’s climate and clean energy goals. PG&E aims to reduce greenhouse gas emissions and support customers with programs and incentives for energy efficiency, clean energy transportation, solar energy, and battery storage (PG&E 2023 GRC, Exhibit PG&E-2, Chapter 1). PG&E's climate resilience work is structured around three pillars: incorporating forward-looking climate data into internal decision-making, collaborating with policymakers and regulators to advance climate adaptation policies, and working with local governments and communities on adaptation solutions (PG&E Opening Brief, p. 78). The utility established a Climate Resilience team in 2016 to assess the impact of climate change on PG&E’s assets and employees (PG&E 2023 GRC, Exhibit PG&E-2, Chapter 1).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.93 seconds
# Prompt 57 complete.
#
# --- Running Prompt 58/60 ---
#
# GRC Assistant: PG&E acknowledges the uncertainty in future gas capacity growth due to California's decarbonization policies, including restrictions on gas appliances in new construction (PG&E 2023 GRC, Exhibit PG&E-16, p. 11-37). To address this uncertainty, PG&E is:
#
# *   **Working with the California Energy Commission:** Collaborating to develop granular, location-based future gas demand forecasts under peak day conditions to reflect the impacts of decarbonization policies (PG&E 2023 GRC, Exhibit PG&E-16, p. 11-37).
# *   **Leveraging alternative solutions:** Using compressed natural gas (CNG), liquified natural gas (LNG), and manual field operations to ensure system reliability in localized or constrained regions (PG&E 2023 GRC, Exhibit PG&E-16, p. 11-37).
#
# PG&E proposed shifting to the Unit of Production (UoP) depreciation method to address concerns related to potential decreased throughput caused by California’s decarbonization goals (Reply Brief of the Indicated Shippers – Page 2). However, this proposal is being contested, with some parties arguing that the Gas Planning OIR (Order Instituting Rulemaking 20-01-007) is the appropriate forum to address this issue (Reply Brief of the Indicated Shippers – Page 2, 7).
#
# Some parties argue that PG&E's "incremental approach" would mask the considerable impact it would have on the depreciation expense and place a burden on customers (Reply Brief of the Indicated Shippers – Page 7). They suggest that the cost of rejecting PG&E’s proposal would be minimal compared to the increased burden on customers and that the Gas System Planning OIR is the appropriate venue to address the longer-term cost recovery issue and decarbonization goals (Reply Brief of the Indicated Shippers – Page 7).
#
# The Commission is expected to consider a broader array of options for addressing the stranded cost risk in the Gas System Planning OIR (A2106021).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.20 seconds
# Prompt 58 complete.
#
# --- Running Prompt 59/60 ---
#
# GRC Assistant: Yes, PG&E proposes to retain the Los Medanos gas storage facility, which it had previously planned to sell or decommission (PG&E 2023 GRC, Exhibit 3, Vol. 2, Ch. 7, p. 7-46). This proposal is based on a shortfall in gas withdrawal capacity and the cost-effectiveness of operating Los Medanos (PG&E 2023 GRC).
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.35 seconds
# Prompt 59 complete.
#
# --- Running Prompt 60/60 ---
#
# GRC Assistant: Yes, the 2023 GRC includes necessary funding to continue to safely operate DCPP through the remaining facility life, and to provide for its safe and orderly closure (PG&E 2023 GRC, Exhibit 4, p.15). PG&E's cost request in this rate case reflects the shutdown dates of November 2024 (Unit 1) and August 2025 (Unit 2) (CPUC Proposed Decision, A.21-06-021).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 1.16 seconds
# Prompt 60 complete.
#
# All responses and contexts saved to: C:\Users\Elijah\PycharmProjects\GRCResponder_tools\llm_output\test\llm_responses_with_context_qa_gemini_20250521_143250.txt

# %% [markdown]
# ---

# %%
from pathlib import Path
import chromadb
from chromadb.utils.embedding_functions import SentenceTransformerEmbeddingFunction
from langgraph.graph import MessagesState, StateGraph
from langchain_core.tools import tool
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage
from langgraph.prebuilt import ToolNode
from langgraph.graph import END
from langgraph.prebuilt import tools_condition
from langchain_core.documents import Document
from langchain.chat_models import init_chat_model
import time
import io
from contextlib import redirect_stdout
from datetime import datetime
from testing.response_eval_tools import set_api_key_from_path, initialize_evaluation_llm, evaluate_model_outputs_from_paths
from pathlib import Path
import json
from typing import List, Dict, Any, Optional, Union
import uuid
import pandas as pd
import re

from qa_pairs.qa_data_loader import load_static_demo_pairs
set_api_key_from_path(Path('./testing/gemini-key'))
llm = initialize_evaluation_llm()
llm_session = LLMChatSession()

# %%
import re
from pathlib import Path
from typing import List, Dict, Any

def parse_prompt_blocks(file_path: str) -> List[Dict[str, Any]]:
    path = Path(file_path)

    if not path.exists():
        raise FileNotFoundError(f"File not found: {file_path}")

    with open(path, 'r', encoding='utf-8') as f:
        file_content = f.read()

    delimiter_pattern = r'=================\s*Prompt\s+(\d+)\s*=================\n'

    # Split the file content by prompt secitons
    blocks = re.split(delimiter_pattern, file_content)

    # First element will be empty or any text before the first delimiter
    blocks = blocks[1:] if blocks[0].strip() == '' else blocks

    # Process the blocks (pairs of [prompt_number, content])
    results = []

    # Handle paired elements (every odd index is a prompt number, every even index is content)
    for i in range(0, len(blocks)-1, 2):
        prompt_num = int(blocks[i])
        content = blocks[i+1]

        # Extract the prompt text
        prompt_match = re.search(r'PROMPT:\n(.*?)\n\n', content, re.DOTALL)
        prompt_text = prompt_match.group(1) if prompt_match else "Prompt text not found"

        # Get the response content
        response = content[prompt_match.end():] if prompt_match else content

        results.append({
            "prompt_num": prompt_num,
            "prompt_text": prompt_text,
            "response": response,
            "full_block": f"================= Prompt {prompt_num} =================\n{content}"
        })

    return results

# %%
import json
import time
import random
import traceback
from typing import List, Dict, Any, Optional
from pathlib import Path
from google.api_core import exceptions as google_exceptions

def build_evaluation_prompt(model_output_text: str) -> str:
    prompt = f"""
    You are evaluating a retrieval-augmented generation (RAG) system. For each Q/A pair in the data below, you will:
    1. Assign a relevance score (0–5) based on how well the retrieved context matches the question.
       - 0: No relevance, the context is completely off.
       - 1: Very low relevance, context is weakly related.
       - 2: Some relevance, context contains some useful details, but is not fully aligned.
       - 3: Good relevance, context provides useful information that mostly answers the question.
       - 4: Very good relevance, context almost entirely answers the question, with minimal extra information.
       - 5: Perfect relevance, context directly and completely answers the question.

    2. Assign a usage score (0–5) based on whether the context was properly used in generating the answer:
       - 0: The context was not used at all.
       - 1: The context was partially used but not enough to affect the response.
       - 2: The context was mentioned but not effectively incorporated.
       - 3: The context was used, but there were gaps in how it was integrated.
       - 4: The context was effectively used, though some information might be missing.
       - 5: The context was fully integrated and used to generate the response.

    3. Optional: Identify and flag any hallucinations or unsupported claims. If the AI refers to information not found in the context, it should be noted.

    Please format the output as a JSON array with the following fields: "question", "relevance_score", "usage_score", "hallucination_notes".

    Here is the data to evaluate:
    {model_output_text}
    """
    return prompt


def build_accuracy_evaluation_prompt(question: str, original_answer: str, model_answer: str) -> str:
    prompt = f"""
    You are evaluating the accuracy of an AI assistant's answer compared to a reference answer.

    Question: {question}

    Reference Answer: {original_answer}

    AI Assistant's Answer: {model_answer}

    Please evaluate the accuracy of the AI Assistant's answer on a scale from 0 to 5:

    - 0: Completely incorrect or contradicts the reference answer.
    - 1: Mostly incorrect with minimal accurate elements.
    - 2: Partially correct but contains significant inaccuracies or missing critical information.
    - 3: Moderately accurate with some minor inaccuracies or omissions.
    - 4: Highly accurate with very minor omissions or imprecisions.
    - 5: Perfectly accurate, capturing all key information from the reference answer.

    Provide your assessment as a JSON object with the following fields:
    - "accuracy_score": The numeric score (0-5)
    - "reasoning": Brief explanation of your scoring decision
    - "key_differences": Notable differences between the reference and assistant's answer

    Evaluate based on semantic correctness, not exact wording. The AI Assistant's answer can be phrased differently and still be accurate if it conveys the same meaning.
    """
    return prompt


def evaluate_with_retry(prompt: str, llm) -> Optional[str]:
    success = False

    while not success:
        try:
            response = llm.invoke(prompt)
            success = True
            return response.content

        except google_exceptions.ResourceExhausted as e:
            error_string = str(e)

            retry_match = re.search(r'retry_delay\s*{\s*seconds:\s*(\d+)', error_string)
            if retry_match:
                retry_seconds = int(retry_match.group(1))

            print(f"Waiting for {retry_seconds:.1f} seconds before retrying...")

            time.sleep(retry_seconds)

def parse_json_response(response_text: str) -> List[Dict[str, Any]]:
    if not response_text:
        return []

    try:
        cleaned = str(response_text).strip()

        # Remove json code blocks
        cleaned = cleaned.replace("```json", "").replace("```", "").strip()

        json_match = re.search(r'\[\s*{.+}\s*\]', cleaned, re.DOTALL)
        if json_match:
            cleaned = json_match.group(0)

        # Load json
        metrics = json.loads(cleaned)

        return metrics

    except json.JSONDecodeError as e:
        print(f"Failed to parse response as JSON: {e}")
        print("Raw content:")
        print(response_text)
        return []


def extract_model_answer(block_response: str) -> str:
    # Try various patterns to extract the answer
    answer_patterns = [
        # Pattern: "Answer: [answer text]"
        r'(?:answer|response):\s*(.*?)(?:\n\n|\Z)',
        # Pattern: Q: [question] A: [answer]
        r'Q:.*?A:\s*(.*?)(?:\n\n|\Z)',
        # Pattern: "The answer is [answer text]"
        r'(?:the answer is|the response is)\s*(.*?)(?:\n\n|\Z)',
    ]

    for pattern in answer_patterns:
        match = re.search(pattern, block_response, re.IGNORECASE | re.DOTALL)
        if match:
            return match.group(1).strip()



def evaluate_answer_accuracy(question: str, original_answer: str, model_answer: str, llm) -> dict:
    prompt = build_accuracy_evaluation_prompt(question, original_answer, model_answer)

    response_content = evaluate_with_retry(prompt, llm)

    if not response_content:
        return {
            "accuracy_score": 0,
            "reasoning": "Failed to evaluate due to technical issues",
            "key_differences": "N/A"
        }

    try:
        # Clean up common JSON formatting issues
        result = parse_json_response(response_content)

        result["accuracy_score"] = result.get("accuracy_score", 0)
        result["reasoning"] = result.get("reasoning", "No reasoning provided")
        result["key_differences"] = result.get("key_differences", "No differences noted")

        return result

    except Exception as e:
        print(f"Failed to parse accuracy evaluation response: {e}")
        print("Raw content:")
        print(response_content)

        # Return a default result
        return {
            "accuracy_score": 0,
            "reasoning": "Failed to parse evaluation",
            "key_differences": "Error processing evaluation response"
        }


def save_evaluation_results(results: List[Dict[str, Any]], output_path: str) -> None:
    path = Path(output_path)

    path.parent.mkdir(parents=True, exist_ok=True)

    # Save the complete results
    with open(path, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"\nEvaluation results saved to: {path.resolve()}")

    csv_path = path.with_suffix('.csv')

    # Extract metrics into a flat structure
    flat_metrics = []

    for result in results:
        block_num = result['block_info']['prompt_num']

        for metric in result['evaluation_metrics']:
            flat_metric = {
                'prompt_num': block_num,
                'question': metric.get('question', 'N/A'),
                'relevance_score': metric.get('relevance_score', 'N/A'),
                'usage_score': metric.get('usage_score', 'N/A'),
                'answer_accuracy': metric.get('answer_accuracy', 'N/A'),
                'accuracy_reasoning': metric.get('accuracy_reasoning', 'N/A')[:200] + '...' if metric.get('accuracy_reasoning') and len(metric.get('accuracy_reasoning')) > 200 else metric.get('accuracy_reasoning', 'N/A'),
                'difficulty': metric.get('difficulty', 'N/A'),
                'document_id': metric.get('document_id', 'N/A'),
                'hallucination_notes': metric.get('hallucination_notes', '')
            }
            flat_metrics.append(flat_metric)

    df = pd.DataFrame(flat_metrics)
    df.to_csv(csv_path, index=False)
    print(f"Summary CSV saved to: {csv_path.resolve()}")


def evaluate_parsed_blocks(parsed_blocks: List[Dict[str, Any]], llm, original_qa_data: Optional[List[Dict[str, Any]]] = None, output_path: Optional[str] = None) -> List[Dict[str, Any]]:
    all_metrics = []
    results_with_block_info = []

    # Map original Q&A data by question for quick lookup if provided
    qa_lookup = {}
    if original_qa_data:
        # Create a lookup by normalizing questions (lowercase, remove punctuation)
        for idx, qa_item in enumerate(original_qa_data):
            # Create normalized question for matching
            norm_q = re.sub(r'[^\w\s]', '', qa_item['question'].lower())
            norm_q = re.sub(r'\s+', ' ', norm_q).strip()
            qa_lookup[norm_q] = (idx, qa_item)

    for i, block in enumerate(parsed_blocks):
        print(f"\nEvaluating block {i+1}/{len(parsed_blocks)} (Prompt #{block['prompt_num']})...")

        # Build evaluation prompt using the full_block content
        prompt = build_evaluation_prompt(block['full_block'])

        # Evaluate with retry
        response_content = evaluate_with_retry(prompt, llm)

        if response_content:
            metrics = parse_json_response(response_content)

            if metrics:
                for metric in metrics:
                    metric['prompt_num'] = block['prompt_num']

                    # If we have original Q&A data, try to match and calculate accuracy
                    if qa_lookup:
                        norm_q = re.sub(r'[^\w\s]', '', metric['question'].lower())
                        norm_q = re.sub(r'\s+', ' ', norm_q).strip()


                        idx, qa_item = qa_lookup[norm_q]
                        matched_qa = (idx, qa_item)


                        idx, qa_item = matched_qa
                        metric['original_answer'] = qa_item['answer']
                        metric['original_qa_index'] = idx
                        metric['difficulty'] = qa_item.get('difficulty', 'unknown')
                        metric['document_id'] = qa_item.get('document_identification', 'unknown')

                        model_answer = extract_model_answer(block['response'])

                        # LLM accuracy evaluation
                        print(f"  Evaluating answer accuracy for question: '{metric['question'][:50]}...'")
                        accuracy_result = evaluate_answer_accuracy(
                            metric['question'],
                            qa_item['answer'],
                            model_answer,
                            llm
                        )

                        metric['answer_accuracy'] = accuracy_result['accuracy_score']
                        metric['accuracy_reasoning'] = accuracy_result['reasoning']
                        metric['accuracy_key_differences'] = accuracy_result['key_differences']

                all_metrics.extend(metrics)

                results_with_block_info.append({
                    'block_info': block,
                    'evaluation_metrics': metrics,
                    'raw_response': response_content
                })

                print(f"Successfully evaluated block {i+1}. Found {len(metrics)} metric entries.")
            else:
                print(f"Failed to parse metrics for block {i+1}.")
        else:
            print(f"Failed to evaluate block {i+1} after multiple retries.")

    if output_path and results_with_block_info:
        save_evaluation_results(results_with_block_info, output_path)

    return all_metrics

# %%
# Evaluate the parsed blocks
input_file = "./llm_output/test/llm_responses_with_context_qa_gemini_20250521_143250.txt"
output_file = "./llm_output/evaluations/FIXED_RETRIEVAL.json"
parsed_blocks = parse_prompt_blocks(input_file)
print(f"Found {len(parsed_blocks)} prompt blocks to evaluate.")

original_qa_data = test_data['qa_pairs']

evaluation_metrics = evaluate_parsed_blocks(parsed_blocks, llm, original_qa_data, output_file)

# Calculate overall statistics
if evaluation_metrics:
    relevance_scores = [m.get('relevance_score', 0) for m in evaluation_metrics if isinstance(m.get('relevance_score'), (int, float))]
    usage_scores = [m.get('usage_score', 0) for m in evaluation_metrics if isinstance(m.get('usage_score'), (int, float))]
    accuracy_scores = [m.get('answer_accuracy', 0) for m in evaluation_metrics if isinstance(m.get('answer_accuracy'), (int, float))]

    if relevance_scores:
        avg_relevance = sum(relevance_scores) / len(relevance_scores)
        print(f"\nAverage relevance score: {avg_relevance:.2f}/5")

    if usage_scores:
        avg_usage = sum(usage_scores) / len(usage_scores)
        print(f"Average usage score: {avg_usage:.2f}/5")

    if accuracy_scores:
        avg_accuracy = sum(accuracy_scores) / len(accuracy_scores)
        print(f"Average answer accuracy: {avg_accuracy:.2f}/5")

    hallucinations = sum(1 for m in evaluation_metrics if m.get('hallucination_notes') and m.get('hallucination_notes').strip())
    print(f"Number of entries with hallucinations: {hallucinations}/{len(evaluation_metrics)}")

    # Group metrics by difficulty if available
    difficulty_groups = {}
    for metric in evaluation_metrics:
        difficulty = metric.get('difficulty', 'unknown')
        if difficulty not in difficulty_groups:
            difficulty_groups[difficulty] = []
        difficulty_groups[difficulty].append(metric)

    # Print stats by difficulty
    print("\nMetrics by difficulty:")
    for difficulty, metrics in difficulty_groups.items():
        if metrics:
            avg_rel = sum(m.get('relevance_score', 0) for m in metrics if isinstance(m.get('relevance_score'), (int, float))) / len(metrics)
            avg_use = sum(m.get('usage_score', 0) for m in metrics if isinstance(m.get('usage_score'), (int, float))) / len(metrics)
            avg_acc = sum(m.get('answer_accuracy', 0) for m in metrics if isinstance(m.get('answer_accuracy'), (int, float))) / len(metrics)
            print(f"  {difficulty.capitalize()} ({len(metrics)} questions):")
            print(f"    Relevance: {avg_rel:.2f}/5")
            print(f"    Usage: {avg_use:.2f}/5")
            print(f"    Accuracy: {avg_acc:.2f}/5")
# Out:
# Found 60 prompt blocks to evaluate.
#
# Evaluating block 1/60 (Prompt #1)...
#   Evaluating answer accuracy for question: 'Who is the witness for the CSO Closure and Transfo...'
# Successfully evaluated block 1. Found 1 metric entries.
#
# Evaluating block 2/60 (Prompt #2)...
#   Evaluating answer accuracy for question: 'When did PG&E file its application to close its 65...'
# Successfully evaluated block 2. Found 1 metric entries.
#
# Evaluating block 3/60 (Prompt #3)...
#   Evaluating answer accuracy for question: 'Why did PG&E propose transitioning its CSO workfor...'
# Successfully evaluated block 3. Found 1 metric entries.
#
# Evaluating block 4/60 (Prompt #4)...
#   Evaluating answer accuracy for question: 'How did PG&E reassign its CSO workforce in respons...'
# Successfully evaluated block 4. Found 1 metric entries.
#
# Evaluating block 5/60 (Prompt #5)...
#   Evaluating answer accuracy for question: 'Yes/No: By the end of 2021, did 98% of exclusive C...'
# Successfully evaluated block 5. Found 1 metric entries.
#
# Evaluating block 6/60 (Prompt #6)...
#   Evaluating answer accuracy for question: 'Yes/No: Will PG&E submit its last CSO Annual Repor...'
# Successfully evaluated block 6. Found 1 metric entries.
#
# Evaluating block 7/60 (Prompt #7)...
#   Evaluating answer accuracy for question: 'What communication methods will PG&E use to inform...'
# Successfully evaluated block 7. Found 1 metric entries.
#
# Evaluating block 8/60 (Prompt #8)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 19
# }
# ].
#   Evaluating answer accuracy for question: 'Why did PG&E include partnerships with community-b...'
# Waiting for 17.0 seconds before retrying...
# Successfully evaluated block 8. Found 1 metric entries.
#
# Evaluating block 9/60 (Prompt #9)...
#   Evaluating answer accuracy for question: 'Yes/No: Will PG&E post signage at the closed CSO l...'
# Successfully evaluated block 9. Found 1 metric entries.
#
# Evaluating block 10/60 (Prompt #10)...
#   Evaluating answer accuracy for question: 'How will PG&E measure and report the performance o...'
# Successfully evaluated block 10. Found 1 metric entries.
#
# Evaluating block 11/60 (Prompt #11)...
#   Evaluating answer accuracy for question: 'Which parties entered into the Memorandum of Under...'
# Successfully evaluated block 11. Found 1 metric entries.
#
# Evaluating block 12/60 (Prompt #12)...
#   Evaluating answer accuracy for question: 'How does PG&E’s CSO Closure and Transformation Pro...'
# Successfully evaluated block 12. Found 1 metric entries.
#
# Evaluating block 13/60 (Prompt #13)...
#   Evaluating answer accuracy for question: 'Who is the witness for the CSO Closure and Transfo...'
# Successfully evaluated block 13. Found 1 metric entries.
#
# Evaluating block 14/60 (Prompt #14)...
#   Evaluating answer accuracy for question: 'When did PG&E file its application to close its 65...'
# Successfully evaluated block 14. Found 1 metric entries.
#
# Evaluating block 15/60 (Prompt #15)...
#   Evaluating answer accuracy for question: 'Why did PG&E propose transitioning its CSO workfor...'
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ].
# Successfully evaluated block 15. Found 1 metric entries.
#
# Evaluating block 16/60 (Prompt #16)...
# Waiting for 38.0 seconds before retrying...
#   Evaluating answer accuracy for question: 'How did PG&E reassign its CSO workforce in respons...'
# Successfully evaluated block 16. Found 1 metric entries.
#
# Evaluating block 17/60 (Prompt #17)...
#   Evaluating answer accuracy for question: 'Yes/No: By the end of 2021, did 98% of exclusive C...'
# Successfully evaluated block 17. Found 1 metric entries.
#
# Evaluating block 18/60 (Prompt #18)...
#   Evaluating answer accuracy for question: 'Yes/No: Will PG&E submit its last CSO Annual Repor...'
# Successfully evaluated block 18. Found 1 metric entries.
#
# Evaluating block 19/60 (Prompt #19)...
#   Evaluating answer accuracy for question: 'What communication methods will PG&E use to inform...'
# Successfully evaluated block 19. Found 1 metric entries.
#
# Evaluating block 20/60 (Prompt #20)...
#   Evaluating answer accuracy for question: 'Why did PG&E include partnerships with community-b...'
# Successfully evaluated block 20. Found 1 metric entries.
#
# Evaluating block 21/60 (Prompt #21)...
#   Evaluating answer accuracy for question: 'Yes/No: Will PG&E post signage at the closed CSO l...'
# Successfully evaluated block 21. Found 1 metric entries.
#
# Evaluating block 22/60 (Prompt #22)...
#   Evaluating answer accuracy for question: 'How will PG&E measure and report the performance o...'
# Successfully evaluated block 22. Found 1 metric entries.
#
# Evaluating block 23/60 (Prompt #23)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ].
#   Evaluating answer accuracy for question: 'Which parties entered into the Memorandum of Under...'
# Successfully evaluated block 23. Found 1 metric entries.
#
# Evaluating block 24/60 (Prompt #24)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 36
# }
# ].
#   Evaluating answer accuracy for question: 'How does PG&E's CSO Closure and Transformation Pro...'
# Waiting for 34.0 seconds before retrying...
# Successfully evaluated block 24. Found 1 metric entries.
#
# Evaluating block 25/60 (Prompt #25)...
#   Evaluating answer accuracy for question: 'Under which rule did PG&E submit its motion reques...'
# Successfully evaluated block 25. Found 1 metric entries.
#
# Evaluating block 26/60 (Prompt #26)...
#   Evaluating answer accuracy for question: 'As of the filing of this motion, for how long have...'
# Successfully evaluated block 26. Found 1 metric entries.
#
# Evaluating block 27/60 (Prompt #27)...
#   Evaluating answer accuracy for question: 'Why does PG&E argue that reopening the CSOs prior ...'
# Successfully evaluated block 27. Found 1 metric entries.
#
# Evaluating block 28/60 (Prompt #28)...
#   Evaluating answer accuracy for question: 'What pre-pandemic CSO usage trends did PG&E cite t...'
# Successfully evaluated block 28. Found 1 metric entries.
#
# Evaluating block 29/60 (Prompt #29)...
#   Evaluating answer accuracy for question: 'Yes/No: Does the motion state that 98% of exclusiv...'
# Successfully evaluated block 29. Found 1 metric entries.
#
# Evaluating block 30/60 (Prompt #30)...
#   Evaluating answer accuracy for question: 'Which statutory provision does PG&E cite to confir...'
# Successfully evaluated block 30. Found 1 metric entries.
#
# Evaluating block 31/60 (Prompt #31)...
#   Evaluating answer accuracy for question: 'Under which rule did PG&E submit its motion reques...'
# Successfully evaluated block 31. Found 1 metric entries.
#
# Evaluating block 32/60 (Prompt #32)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 39
# }
# ].
#   Evaluating answer accuracy for question: 'As of the filing of this motion, for how long have...'
# Waiting for 37.0 seconds before retrying...
# Successfully evaluated block 32. Found 1 metric entries.
#
# Evaluating block 33/60 (Prompt #33)...
#   Evaluating answer accuracy for question: 'Why does PG&E argue that reopening the CSOs prior ...'
# Successfully evaluated block 33. Found 1 metric entries.
#
# Evaluating block 34/60 (Prompt #34)...
#   Evaluating answer accuracy for question: 'What pre-pandemic CSO usage trends did PG&E cite t...'
# Successfully evaluated block 34. Found 1 metric entries.
#
# Evaluating block 35/60 (Prompt #35)...
#   Evaluating answer accuracy for question: 'Yes/No: Does the motion state that 98% of exclusiv...'
# Successfully evaluated block 35. Found 1 metric entries.
#
# Evaluating block 36/60 (Prompt #36)...
#   Evaluating answer accuracy for question: 'Which statutory provision does PG&E cite to confir...'
# Successfully evaluated block 36. Found 1 metric entries.
#
# Evaluating block 37/60 (Prompt #37)...
#   Evaluating answer accuracy for question: 'Which application number does Decision 25-03-008 a...'
# Successfully evaluated block 37. Found 1 metric entries.
#
# Evaluating block 38/60 (Prompt #38)...
#   Evaluating answer accuracy for question: 'On what date was Decision 25-03-008 issued?...'
# Successfully evaluated block 38. Found 1 metric entries.
#
# Evaluating block 39/60 (Prompt #39)...
#   Evaluating answer accuracy for question: 'What are the three layers of PG&E’s non-wildfire l...'
# Successfully evaluated block 39. Found 1 metric entries.
#
# Evaluating block 40/60 (Prompt #40)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 41
# }
# ].
#   Evaluating answer accuracy for question: 'Why did the Settling Parties request a decision by...'
# Waiting for 39.0 seconds before retrying...
# Successfully evaluated block 40. Found 1 metric entries.
#
# Evaluating block 41/60 (Prompt #41)...
#   Evaluating answer accuracy for question: 'How does the Decision justify that the self-insura...'
# Successfully evaluated block 41. Found 1 metric entries.
#
# Evaluating block 42/60 (Prompt #42)...
#   Evaluating answer accuracy for question: 'Yes/No: Were any responses filed opposing the Join...'
# Successfully evaluated block 42. Found 1 metric entries.
#
# Evaluating block 43/60 (Prompt #43)...
#   Evaluating answer accuracy for question: 'Which application number does Decision 25-03-008 a...'
# Successfully evaluated block 43. Found 1 metric entries.
#
# Evaluating block 44/60 (Prompt #44)...
#   Evaluating answer accuracy for question: 'On what date was Decision 25-03-008 issued?...'
# Successfully evaluated block 44. Found 1 metric entries.
#
# Evaluating block 45/60 (Prompt #45)...
#   Evaluating answer accuracy for question: 'What are the three layers of PG&E's non-wildfire l...'
# Successfully evaluated block 45. Found 1 metric entries.
#
# Evaluating block 46/60 (Prompt #46)...
#   Evaluating answer accuracy for question: 'Why did the Settling Parties request a decision by...'
# Successfully evaluated block 46. Found 1 metric entries.
#
# Evaluating block 47/60 (Prompt #47)...
#   Evaluating answer accuracy for question: 'How does the Decision justify that the self-insura...'
# Successfully evaluated block 47. Found 1 metric entries.
#
# Evaluating block 48/60 (Prompt #48)...
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 40
# }
# ].
#   Evaluating answer accuracy for question: 'Yes/No: Were any responses filed opposing the Join...'
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 37
# }
# ].
# Successfully evaluated block 48. Found 1 metric entries.
#
# Evaluating block 49/60 (Prompt #49)...
# Waiting for 35.0 seconds before retrying...
#   Evaluating answer accuracy for question: 'What is the effective date for the proposed rate i...'
# Successfully evaluated block 49. Found 1 metric entries.
#
# Evaluating block 50/60 (Prompt #50)...
#   Evaluating answer accuracy for question: 'Approximately what percentage of the requested rev...'
# Successfully evaluated block 50. Found 1 metric entries.
#
# Evaluating block 51/60 (Prompt #51)...
#   Evaluating answer accuracy for question: 'Why did PG&E include an analysis of climate change...'
# Successfully evaluated block 51. Found 1 metric entries.
#
# Evaluating block 52/60 (Prompt #52)...
#   Evaluating answer accuracy for question: 'How does PG&E plan to manage the expected decline ...'
# Successfully evaluated block 52. Found 1 metric entries.
#
# Evaluating block 53/60 (Prompt #53)...
#   Evaluating answer accuracy for question: 'Yes/No: Does PG&E propose to retain and operate th...'
# Successfully evaluated block 53. Found 1 metric entries.
#
# Evaluating block 54/60 (Prompt #54)...
#   Evaluating answer accuracy for question: 'Yes/No: Does the 2023 GRC forecast include funding...'
# Successfully evaluated block 54. Found 1 metric entries.
#
# Evaluating block 55/60 (Prompt #55)...
#   Evaluating answer accuracy for question: 'What is the effective date for the proposed rate i...'
# Successfully evaluated block 55. Found 1 metric entries.
#
# Evaluating block 56/60 (Prompt #56)...
#   Evaluating answer accuracy for question: 'Approximately what percentage of the requested rev...'
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 42
# }
# ].
# Successfully evaluated block 56. Found 1 metric entries.
#
# Evaluating block 57/60 (Prompt #57)...
# Waiting for 40.0 seconds before retrying...
#   Evaluating answer accuracy for question: 'Why did PG&E include an analysis of climate change...'
# Successfully evaluated block 57. Found 1 metric entries.
#
# Evaluating block 58/60 (Prompt #58)...
#   Evaluating answer accuracy for question: 'How does PG&E plan to manage the expected decline ...'
# Successfully evaluated block 58. Found 1 metric entries.
#
# Evaluating block 59/60 (Prompt #59)...
#   Evaluating answer accuracy for question: 'Yes/No: Does PG&E propose to retain and operate th...'
# Successfully evaluated block 59. Found 1 metric entries.
#
# Evaluating block 60/60 (Prompt #60)...
#   Evaluating answer accuracy for question: 'Yes/No: Does the 2023 GRC forecast include funding...'
# Successfully evaluated block 60. Found 1 metric entries.
#
# Evaluation results saved to: C:\Users\Elijah\PycharmProjects\GRCResponder_tools\llm_output\evaluations\FIXED_RETRIEVAL.json
# Summary CSV saved to: C:\Users\Elijah\PycharmProjects\GRCResponder_tools\llm_output\evaluations\FIXED_RETRIEVAL.csv
#
# Average relevance score: 4.57/5
# Average usage score: 4.52/5
# Average answer accuracy: 2.57/5
# Number of entries with hallucinations: 26/60
#
# Metrics by difficulty:
#   Easy (30 questions):
#     Relevance: 4.20/5
#     Usage: 4.07/5
#     Accuracy: 2.47/5
#   Medium (18 questions):
#     Relevance: 4.89/5
#     Usage: 4.94/5
#     Accuracy: 2.50/5
#   Hard (12 questions):
#     Relevance: 5.00/5
#     Usage: 5.00/5
#     Accuracy: 2.92/5

# %%
test_list
# Out:
# ['Who is the witness for the CSO Closure and Transformation Proposal?',
#  'When did PG&E file its application to close its 65 Customer Service Offices?',
#  'Why did PG&E propose transitioning its CSO workforce to proactive customer outreach?',
#  'How did PG&E reassign its CSO workforce in response to the COVID-19 pandemic?',
#  'Yes/No: By the end of 2021, did 98% of exclusive CSO customers make payments through other channels?',
#  'Yes/No: Will PG&E submit its last CSO Annual Report on March 1, 2027 with data for 2026?',
#  'What communication methods will PG&E use to inform its customers within 90 days of the Commission’s approval of the CSO Closure and Transformation Proposal?',
#  'Why did PG&E include partnerships with community-based organizations in its CSO communications plan?',
#  'Yes/No: Will PG&E post signage at the closed CSO locations for at least one year?',
#  'How will PG&E measure and report the performance of its CSO Closure and Transformation Program?',
#  'Which parties entered into the Memorandum of Understanding in support of PG&E’s CSO Closure and Transformation Proposal?',
#  'How does PG&E’s CSO Closure and Transformation Proposal align with the CPUC’s Environmental and Social Justice (ESJ) Action Plan?',
#  'Who is the witness for the CSO Closure and Transformation Proposal?',
#  'When did PG&E file its application to close its 65 Customer Service Offices?',
#  'Why did PG&E propose transitioning its CSO workforce to proactive customer outreach?',
#  'How did PG&E reassign its CSO workforce in response to the COVID-19 pandemic?',
#  'Yes/No: By the end of 2021, did 98% of exclusive CSO customers make payments through other channels?',
#  'Yes/No: Will PG&E submit its last CSO Annual Report on March 1, 2027 with data for 2026?',
#  "What communication methods will PG&E use to inform its customers within 90 days of the Commission's approval of the CSO Closure and Transformation Proposal?",
#  'Why did PG&E include partnerships with community-based organizations in its CSO communications plan?',
#  'Yes/No: Will PG&E post signage at the closed CSO locations for at least one year?',
#  'How will PG&E measure and report the performance of its CSO Closure and Transformation Program?',
#  "Which parties entered into the Memorandum of Understanding in support of PG&E's CSO Closure and Transformation Proposal?",
#  "How does PG&E's CSO Closure and Transformation Proposal align with the CPUC's Environmental and Social Justice (ESJ) Action Plan?",
#  'Under which rule did PG&E submit its motion requesting an order to maintain the status quo?',
#  'As of the filing of this motion, for how long have PG&E’s Customer Service Offices been closed?',
#  'Why does PG&E argue that reopening the CSOs prior to a final decision would be detrimental?',
#  'What pre-pandemic CSO usage trends did PG&E cite to support its motion?',
#  'Yes/No: Does the motion state that 98% of exclusive CSO customers had migrated to alternative payment channels by the end of 2021?',
#  'Which statutory provision does PG&E cite to confirm the Commission’s authority to maintain the status quo?',
#  'Under which rule did PG&E submit its motion requesting an order to maintain the status quo?',
#  "As of the filing of this motion, for how long have PG&E's Customer Service Offices been closed?",
#  'Why does PG&E argue that reopening the CSOs prior to a final decision would be detrimental?',
#  'What pre-pandemic CSO usage trends did PG&E cite to support its motion?',
#  'Yes/No: Does the motion state that 98% of exclusive CSO customers had migrated to alternative payment channels by the end of 2021?',
#  "Which statutory provision does PG&E cite to confirm the Commission's authority to maintain the status quo?",
#  'Which application number does Decision 25-03-008 address?',
#  'On what date was Decision 25-03-008 issued?',
#  'What are the three layers of PG&E’s non-wildfire liability insurance and their coverage limits?',
#  'Why did the Settling Parties request a decision by mid-March 2025?',
#  'How does the Decision justify that the self-insurance framework is in the public interest?',
#  'Yes/No: Were any responses filed opposing the Joint Petition for Modification?',
#  'Which application number does Decision 25-03-008 address?',
#  'On what date was Decision 25-03-008 issued?',
#  "What are the three layers of PG&E's non-wildfire liability insurance and their coverage limits?",
#  'Why did the Settling Parties request a decision by mid-March 2025?',
#  'How does the Decision justify that the self-insurance framework is in the public interest?',
#  'Yes/No: Were any responses filed opposing the Joint Petition for Modification?',
#  'What is the effective date for the proposed rate increase in PG&E’s 2023 General Rate Case Application?',
#  'Approximately what percentage of the requested revenue requirement increase over 2022 adopted is dedicated to risk reduction in PG&E’s gas and electric operations?',
#  'Why did PG&E include an analysis of climate change in its 2023 GRC testimony for the first time?',
#  'How does PG&E plan to manage the expected decline in gas distribution throughput as California pursues decarbonization?',
#  'Yes/No: Does PG&E propose to retain and operate the Los Medanos storage facility rather than sell it?',
#  'Yes/No: Does the 2023 GRC forecast include funding for the retirement of the Diablo Canyon Power Plant?',
#  "What is the effective date for the proposed rate increase in PG&E's 2023 General Rate Case Application?",
#  "Approximately what percentage of the requested revenue requirement increase over 2022 adopted is dedicated to risk reduction in PG&E's gas and electric operations?",
#  'Why did PG&E include an analysis of climate change in its 2023 GRC testimony for the first time?',
#  'How does PG&E plan to manage the expected decline in gas distribution throughput as California pursues decarbonization?',
#  'Yes/No: Does PG&E propose to retain and operate the Los Medanos storage facility rather than sell it?',
#  'Yes/No: Does the 2023 GRC forecast include funding for the retirement of the Diablo Canyon Power Plant?']

# %% [markdown]
# # Simple Context Length Testing

# %%
llm_session = LLMChatSession(console_mode=True)

# %%
result = llm_session.query("Why did PG&E include partnerships with community-based organizations in its CSO communications plan?")
# Out:
# GRC Assistant: PG&E included partnerships with Community Based Organizations (CBOs) in its communications plan for several reasons, primarily to improve outreach to underserved communities and ensure vulnerable customers have access to important information. Here's a breakdown of the key motivations:
#
# *   **Improved Outreach to Underserved Communities:** PG&E aimed to enhance its outreach to underserved communities by collaborating with CBOs. These organizations can disseminate information in multiple languages about financial assistance and bill savings programs, rate options, wildfire safety-related topics, and emergency preparedness, thus helping to reach vulnerable customers (A2106021, 397495992.PDF, p. 3).
# *   **Engagement with Vulnerable Communities:** PG&E engaged with organizations like TURN (The Utility Reform Network), CforAT (Center for Accessible Technology), Cal Advocates, and NDC (National Diversity Coalition) to ensure that the voices of their constituents were heard in developing the CSO Closure and Transformation Proposal. This collaboration was intended as an example of engagement to ensure that vulnerable communities were properly considered (A2204016, 498525940.PDF, p. 15).
# *   **Compensation for Collaboration:** PG&E indicated that it would compensate CBOs for their collaboration in outreach efforts (A2204016, 498525940.PDF, p. 15).
#
# Would you like me to explore any aspect of this response in greater depth or address related regulatory considerations?
#
# Processing time: 3.03 seconds

# %%
clear_chat_history(llm_session.session_id)
# Out:
# {'status': 'success',
#  'message': 'Chat history cleared for session a0c070db-dc46-46b9-8c20-2ce6d0b7da1b'}

# %%
result = llm_session.query("Why did PG&E include partnerships with community-based organizations in its CSO communications plan?", k = 20)
# Out:
# GRC Assistant: I do not have access to the specifics of PG&E's CSO communications plan. However, I can use the retrieve tool to search for information regarding why PG&E might include partnerships with community-based organizations in its communications plan. What would you like me to search for?
#
# Processing time: 0.80 seconds

# %%
clear_chat_history(llm_session.session_id)
# Out:
# {'status': 'success',
#  'message': 'Chat history cleared for session a0c070db-dc46-46b9-8c20-2ce6d0b7da1b'}

# %%
result = llm_session.query("Why did PG&E include partnerships with community-based organizations in its CSO communications plan?", k = 50)
# Out:
# GRC Assistant: I do not have access to the specifics of PG&E's CSO communications plan. However, I can use a search query to retrieve information about why PG&E might include partnerships with community-based organizations in its communications plan. What query would you like me to use?
#
# Processing time: 0.82 seconds
